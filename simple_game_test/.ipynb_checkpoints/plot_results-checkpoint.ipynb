# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set(style="whitegrid")

# Load data
# domain_df = pd.read_excel("../results/domain_df_w_metrics.xlsx")
domain_df = pd.read_excel("../results/expanded_metrics_data.xlsx", sheet_name="domain_df")

domain_df_learned = domain_df[domain_df['overall_domain_learned'] == 1]
users_learned = domain_df_learned['user_id'].unique()


string_cols = ['domain', 'domain_name', 'experimental_condition', 'domain_order', 'user_id', 'group_id']

# Ensure string columns are string
for col in string_cols:
    if col in domain_df.columns:
        domain_df[col] = domain_df[col].astype(str)

# round_df = pd.read_excel("../results/round_df_w_metrics.xlsx")
round_df = pd.read_excel("../results/expanded_metrics_data.xlsx", sheet_name="round_df")
round_df_learned = round_df[round_df['user_id'].isin(users_learned)]


# string_cols = ['domain', 'domain_name', 'experimental_condition', 'domain_order', 'user_id', 'group_id']

# Order settings
condition_order = ['individual_belief_low', 'individual_belief_high', 'common_belief', 'joint_belief']
domain_order = ['augmented_taxi2', 'skateboard2']


# Dependent variables
domain_vars = ['avg_attn', 'avg_use', 'N_correct_final_tests',
               'avg_traj_regret_norm_final', 'avg_traj_regret_norm_diagnostic',
               'avg_est_regret_norm_final', 'avg_est_regret_norm_diagnostic', 'total_KC_rounds']

round_vars = ['demo_BEC_area', 'test_BEC_area', 'avg_traj_regret_norm',
              'avg_est_regret_norm', 'num_demos', 'num_tests',
              'proportion_correct_diagnostic_tests', 'lesson_learned']

domain_vars_boolean = ['overall_domain_learned', 'KC_0_learned', 'KC_1_learned', 'KC_2_learned']

traj_regret_vars = ['avg_traj_regret_norm_final', 'avg_traj_regret_norm_diagnostic', 'avg_traj_regret_norm']
est_regret_vars = ['avg_est_regret_norm_final', 'avg_est_regret_norm_diagnostic', 'avg_est_regret_norm']

# Binning for regret variables
combined_traj_regret = pd.concat([
    domain_df['avg_traj_regret_norm_final'],
    domain_df['avg_traj_regret_norm_diagnostic'],
    round_df['avg_traj_regret_norm']
])
combined_est_regret = pd.concat([
    domain_df['avg_est_regret_norm_final'],
    domain_df['avg_est_regret_norm_diagnostic'],
    round_df['avg_est_regret_norm']
])

traj_bins = np.array(np.histogram_bin_edges(combined_traj_regret.dropna(), bins=15))
est_bins = np.array(np.histogram_bin_edges(combined_est_regret.dropna(), bins=15))

# Scale factor
scale_factor = 240 / len(domain_df)

#######################   Functions    ####################

# CALCULATE Y-AXIS LIMITS FOR EACH VARIABLE
def calculate_ylimits_for_variables():
    """Calculate consistent y-axis limits for each variable across all datasets using mean + SE per condition per domain"""
    ylimits = {}
    
    # For domain variables
    for var in domain_vars:
        condition_domain_y_maxes = []
        condition_domain_y_mins = []
        
        print(f"\n=== Processing domain variable: {var} ===")
        
        # Check each dataset, domain, and condition combination
        domain_col = 'domain_name' if 'domain_name' in domain_df.columns else 'domain'
        for df in [domain_df, domain_df_learned]:
            if var in df.columns:
                for domain in df[domain_col].unique():
                    domain_subset = df[df[domain_col] == domain]
                    for condition in condition_order:
                        condition_data = domain_subset[domain_subset['experimental_condition'] == condition][var].dropna()
                        if len(condition_data) > 0:
                            mean_val = np.mean(condition_data)
                            se_val = np.std(condition_data) / np.sqrt(len(condition_data))
                            
                            print(f"  {domain}-{condition}: mean={mean_val:.4f}, SE={se_val:.4f}, n={len(condition_data)}")
                            
                            # Use a more robust threshold for negative means (avoid tiny negative values due to rounding)
                            has_negative_mean = mean_val < -0.001  # Only treat as negative if clearly negative
                            
                            if has_negative_mean:
                                # For condition-domain combinations with clearly negative means
                                condition_domain_y_min = mean_val - 2 * se_val
                                condition_domain_y_mins.append(condition_domain_y_min)
                                print(f"    -> Treating as NEGATIVE: y_min = {condition_domain_y_min:.4f}")
                            else:
                                # For condition-domain combinations with positive or near-zero means
                                condition_domain_y_max = mean_val + 2 * se_val
                                condition_domain_y_maxes.append(condition_domain_y_max)
                                print(f"    -> Treating as POSITIVE: y_max = {condition_domain_y_max:.4f}")
        
        # Get all values for fallback limits
        all_values = []
        if var in domain_df.columns:
            all_values.extend(domain_df[var].dropna().tolist())
        if var in domain_df_learned.columns:
            all_values.extend(domain_df_learned[var].dropna().tolist())
        
        if all_values:
            # Determine final y limits based on what we found
            if condition_domain_y_mins and not condition_domain_y_maxes:
                # Only clearly negative means found
                most_negative = min(condition_domain_y_mins) * 1.1
                y_max = abs(most_negative) * 0.1  # 10% of the magnitude for proper bar display
                y_min = most_negative
                ylimits[var] = (y_min, y_max)
                print(f"  -> FINAL: All negative means, y_range = ({y_min:.4f}, {y_max:.4f})")
            elif condition_domain_y_maxes and not condition_domain_y_mins:
                # Only positive/near-zero means found
                y_min = max(0, min(all_values) * 0.95)
                y_max = max(condition_domain_y_maxes) * 1.1
                ylimits[var] = (y_min, y_max)
                print(f"  -> FINAL: All positive means, y_range = ({y_min:.4f}, {y_max:.4f})")
            elif condition_domain_y_mins and condition_domain_y_maxes:
                # Mixed: some negative, some positive means
                y_min = min(condition_domain_y_mins) * 1.1
                y_max = max(condition_domain_y_maxes) * 1.1
                ylimits[var] = (y_min, y_max)
                print(f"  -> FINAL: Mixed means, y_range = ({y_min:.4f}, {y_max:.4f})")
            else:
                # Fallback to raw data limits
                y_min = min(all_values) * 1.05 if min(all_values) < 0 else max(0, min(all_values) * 0.95)
                y_max = max(all_values) * 1.05
                ylimits[var] = (y_min, y_max)
                print(f"  -> FINAL: Fallback, y_range = ({y_min:.4f}, {y_max:.4f})")
    
    # For round variables
    for var in round_vars:
        condition_domain_y_maxes = []
        condition_domain_y_mins = []
        
        print(f"\n=== Processing round variable: {var} ===")
        
        # Check each dataset, domain, and condition combination
        domain_col = 'domain_name' if 'domain_name' in round_df.columns else 'domain'
        for df in [round_df, round_df_learned]:
            if var in df.columns:
                for domain in df[domain_col].unique():
                    domain_subset = df[df[domain_col] == domain]
                    for condition in condition_order:
                        condition_data = domain_subset[domain_subset['experimental_condition'] == condition][var].dropna()
                        if len(condition_data) > 0:
                            mean_val = np.mean(condition_data)
                            se_val = np.std(condition_data) / np.sqrt(len(condition_data))
                            
                            print(f"  {domain}-{condition}: mean={mean_val:.4f}, SE={se_val:.4f}, n={len(condition_data)}")
                            
                            # Use a more robust threshold for negative means (avoid tiny negative values due to rounding)
                            has_negative_mean = mean_val < -0.001  # Only treat as negative if clearly negative
                            
                            if has_negative_mean:
                                # For condition-domain combinations with clearly negative means
                                condition_domain_y_min = mean_val - 2 * se_val
                                condition_domain_y_mins.append(condition_domain_y_min)
                                print(f"    -> Treating as NEGATIVE: y_min = {condition_domain_y_min:.4f}")
                            else:
                                # For condition-domain combinations with positive or near-zero means
                                condition_domain_y_max = mean_val + 2 * se_val
                                condition_domain_y_maxes.append(condition_domain_y_max)
                                print(f"    -> Treating as POSITIVE: y_max = {condition_domain_y_max:.4f}")
        
        # Get all values for fallback limits
        all_values = []
        if var in round_df.columns:
            all_values.extend(round_df[var].dropna().tolist())
        if var in round_df_learned.columns:
            all_values.extend(round_df_learned[var].dropna().tolist())
        
        if all_values:
            # Determine final y limits based on what we found
            if condition_domain_y_mins and not condition_domain_y_maxes:
                # Only clearly negative means found
                most_negative = min(condition_domain_y_mins) * 1.1
                y_max = abs(most_negative) * 0.1  # 10% of the magnitude for proper bar display
                y_min = most_negative
                ylimits[var] = (y_min, y_max)
                print(f"  -> FINAL: All negative means, y_range = ({y_min:.4f}, {y_max:.4f})")
            elif condition_domain_y_maxes and not condition_domain_y_mins:
                # Only positive/near-zero means found
                y_min = max(0, min(all_values) * 0.95)
                y_max = max(condition_domain_y_maxes) * 1.1
                ylimits[var] = (y_min, y_max)
                print(f"  -> FINAL: All positive means, y_range = ({y_min:.4f}, {y_max:.4f})")
            elif condition_domain_y_mins and condition_domain_y_maxes:
                # Mixed: some negative, some positive means
                y_min = min(condition_domain_y_mins) * 1.1
                y_max = max(condition_domain_y_maxes) * 1.1
                ylimits[var] = (y_min, y_max)
                print(f"  -> FINAL: Mixed means, y_range = ({y_min:.4f}, {y_max:.4f})")
            else:
                # Fallback to raw data limits
                y_min = min(all_values) * 1.05 if min(all_values) < 0 else max(0, min(all_values) * 0.95)
                y_max = max(all_values) * 1.05
                ylimits[var] = (y_min, y_max)
                print(f"  -> FINAL: Fallback, y_range = ({y_min:.4f}, {y_max:.4f})")
    
    # For boolean variables (counts) - check by condition and domain
    for var in domain_vars_boolean:
        condition_domain_counts = []
        domain_col = 'domain_name' if 'domain_name' in domain_df.columns else 'domain'
        
        for df in [domain_df, domain_df_learned]:
            if var in df.columns:
                for domain in df[domain_col].unique():
                    domain_subset = df[df[domain_col] == domain]
                    for condition in condition_order:
                        condition_subset = domain_subset[domain_subset['experimental_condition'] == condition]
                        if len(condition_subset) > 0:
                            count = condition_subset[var].sum()
                            condition_domain_counts.append(count)
        
        if condition_domain_counts:
            y_max = max(condition_domain_counts) * 1.2  # Take max count across all condition-domain combinations + 20% padding
            ylimits[var + '_count'] = (0, y_max)
        else:
            ylimits[var + '_count'] = (0, 10)  # Default fallback
    
    return ylimits


# Calculate y-limits
y_limits = calculate_ylimits_for_variables()

# Check discreteness
def is_discrete(series):
    return pd.api.types.is_integer_dtype(series) or series.nunique() < 4

# 1. Overall histograms
def plot_overall_histograms(df, variables, title_prefix):
    for var in variables:
        data = df[var].dropna()
        weights = np.ones_like(data) * scale_factor
        discrete = is_discrete(data)
        print(f"Variable: {var}, Discrete: {discrete}")

        bins = None
        if var in traj_regret_vars:
            bins = traj_bins
        elif var in est_regret_vars:
            bins = est_bins

        df_plot = pd.DataFrame({var: data, "weights": weights})

        plt.figure(figsize=(6, 4))
        if bins is not None:
            sns.histplot(
                data=df_plot,
                x=var,
                weights="weights",
                discrete=discrete,
                bins=bins,
                palette="muted"
            )
        else:
            sns.histplot(
            data=df_plot,
            x=var,
            weights="weights",
            discrete=discrete,
            palette="muted"
        )
        plt.title(f"{title_prefix}: {var}")
        plt.xlabel(var)
        plt.ylabel("Count")
        plt.tight_layout()
        plt.show()

# plot_overall_histograms(domain_df, domain_vars, "Domain Metrics")
# plot_overall_histograms(round_df, round_vars, "Round Metrics")


# 2. Histograms split by domain
def plot_histograms_by_domain(df, variables, title_prefix):
    df = df.copy()
    df['weights'] = scale_factor  # ensure scale_factor is defined externally

    domain_col = 'domain_name' if 'domain_name' in df.columns else 'domain'
    print(f"Plotting by domain column: {domain_col}, domains: {df[domain_col].unique()}")

    for var in variables:
        print(f"\n--- Variable: {var} ---")

        discrete = is_discrete(df[var])

        bins = None
        if var in traj_regret_vars:
            bins = traj_bins
        elif var in est_regret_vars:
            bins = est_bins

        g = sns.FacetGrid(df, col=domain_col, margin_titles=True,
                          height=4, aspect=1.2, sharey=False)

        plot_args = dict(x=var, weights='weights', discrete=discrete,
                         color=sns.color_palette("muted")[0], stat='count')

        if bins is not None:
            plot_args['bins'] = bins

        g.map_dataframe(sns.histplot, **plot_args)
        g.set_axis_labels(var, "Count")
        g.fig.subplots_adjust(top=0.85)
        g.fig.suptitle(f"{title_prefix}: {var}", fontsize=14)

        plt.tight_layout()
        plt.show()


# print('Domain df:', type(domain_df['domain_name'].iloc[0]))
# plot_histograms_by_domain(domain_df, domain_vars, "Domain Metrics")
# plot_histograms_by_domain(round_df, round_vars, "Round Metrics")



# 3. Histograms by domain and condition
def plot_histograms_by_domain_condition(df, variables, title_prefix):
    df = df.copy()
    df['weights'] = scale_factor
    for var in variables:
        discrete = is_discrete(df[var])

        bins = None
        if var in traj_regret_vars:
            bins = traj_bins
        elif var in est_regret_vars:
            bins = est_bins

        domain_col = 'domain_name' if 'domain_name' in df.columns else 'domain'

        g = sns.FacetGrid(df, col=domain_col, row="experimental_condition",
                          margin_titles=True, height=3, aspect=1.2)
        if bins is not None:
            g.map_dataframe(
                sns.histplot,
                x=var,
                weights='weights',
                discrete=discrete,
                bins=bins,
                color=sns.color_palette("muted")[0]
            )
        else:
            g.map_dataframe(
                sns.histplot,
                x=var,
                weights='weights',
                discrete=discrete,
                color=sns.color_palette("muted")[0]
            )
        g.fig.suptitle(f"{title_prefix}: {var}", y=1.02)
        for ax in g.axes.flat:
            ax.set_ylabel("Count")
        plt.tight_layout()
        plt.show()


# plot_histograms_by_domain_condition(domain_df, domain_vars, "Domain Metrics")
# plot_histograms_by_domain_condition(round_df, round_vars, "Round Metrics")


# 4. Bar plots with error bars by condition
def plot_bar_with_error(df, variables, title_prefix):
    domain_col = 'domain_name' if 'domain_name' in df.columns else 'domain'
    unique_domains = df[domain_col].unique()

    for var in variables:
        for domain in unique_domains:
            df_subset = df[(df[domain_col] == domain)]
            plt.figure(figsize=(6, 4))
            # sns.barplot(data=df_subset, x="experimental_condition", y=var, order=condition_order,
            #             errorbar='se')
            sns.barplot(data=df_subset, x="experimental_condition", y=var, order=condition_order)
                
            # Set consistent y-axis limits
            if var in y_limits:
                plt.ylim(y_limits[var])
            
            
            plt.title(f"{title_prefix}: {var} ({domain}) by Condition") 
            plt.xticks(rotation=45)
            plt.xlabel("Condition")
            plt.ylabel(var)
            plt.tight_layout()
            plt.show()

plot_bar_with_error(domain_df, domain_vars, "Domain Metrics")
plot_bar_with_error(round_df, round_vars, "Round Metrics")

plot_bar_with_error(domain_df_learned, domain_vars, "Domain Metrics (Fully Learned)")
plot_bar_with_error(round_df_learned, round_vars, "Round Metrics (Fully Learned)")



def plot_bar_charts_boolean(df, variables, title_prefix):
    domain_col = 'domain_name' if 'domain_name' in df.columns else 'domain'
    unique_domains = df[domain_col].unique()



    for var in variables:
        print(f"\n--- Variable: {var} ---")
        
        for domain in unique_domains:
            df_subset = df[df[domain_col] == domain]

            # Group and count True values per condition
            count_df = df_subset.groupby("experimental_condition")[var].sum().reindex(condition_order)
            count_df = count_df.reset_index().rename(columns={var: 'count'})
            print(count_df)

            plt.figure(figsize=(6, 4))
            sns.barplot(data=count_df, x="experimental_condition", y="count", order=condition_order)
            
            # Set consistent y-axis limits
            count_key = var + '_count'
            if count_key in y_limits:
                plt.ylim(y_limits[count_key])
            
            plt.title(f"{title_prefix}: Count of {var} = True ({domain})")
            plt.xticks(rotation=45)
            plt.xlabel("Condition")
            plt.ylabel("Count")
            plt.tight_layout()
            plt.show()


plot_bar_charts_boolean(domain_df, domain_vars_boolean, "Domain Metrics")
plot_bar_charts_boolean(domain_df_learned, domain_vars_boolean, "Domain Metrics (Fully Learned)")
# Out:
# === Processing domain variable: avg_attn ===
#   at-individual_belief_low: mean=3.9425, SE=0.1016, n=29
#     -> Treating as POSITIVE: y_max = 4.1457
#   at-individual_belief_high: mean=4.1867, SE=0.1179, n=25
#     -> Treating as POSITIVE: y_max = 4.4224
#   at-common_belief: mean=4.0385, SE=0.0894, n=26
#     -> Treating as POSITIVE: y_max = 4.2173
#   at-joint_belief: mean=4.3056, SE=0.1019, n=24
#     -> Treating as POSITIVE: y_max = 4.5094
#   sb-individual_belief_low: mean=4.0690, SE=0.0866, n=29
#     -> Treating as POSITIVE: y_max = 4.2422
#   sb-individual_belief_high: mean=3.8772, SE=0.2004, n=19
#     -> Treating as POSITIVE: y_max = 4.2779
#   sb-common_belief: mean=4.0256, SE=0.1024, n=26
#     -> Treating as POSITIVE: y_max = 4.2305
#   sb-joint_belief: mean=4.2500, SE=0.0916, n=28
#     -> Treating as POSITIVE: y_max = 4.4333
#   at-individual_belief_low: mean=4.0741, SE=0.2014, n=9
#     -> Treating as POSITIVE: y_max = 4.4768
#   at-individual_belief_high: mean=4.2619, SE=0.1312, n=14
#     -> Treating as POSITIVE: y_max = 4.5243
#   at-common_belief: mean=3.9524, SE=0.1707, n=7
#     -> Treating as POSITIVE: y_max = 4.2939
#   at-joint_belief: mean=4.2857, SE=0.1253, n=14
#     -> Treating as POSITIVE: y_max = 4.5364
#   sb-individual_belief_low: mean=3.9375, SE=0.1258, n=16
#     -> Treating as POSITIVE: y_max = 4.1890
#   sb-individual_belief_high: mean=4.1905, SE=0.2415, n=7
#     -> Treating as POSITIVE: y_max = 4.6734
#   sb-common_belief: mean=4.1667, SE=0.1716, n=10
#     -> Treating as POSITIVE: y_max = 4.5099
#   sb-joint_belief: mean=4.3056, SE=0.1142, n=12
#     -> Treating as POSITIVE: y_max = 4.5341
#   -> FINAL: All positive means, y_range = (1.5833, 5.1408)
#
# === Processing domain variable: avg_use ===
#   at-individual_belief_low: mean=2.5862, SE=0.1357, n=29
#     -> Treating as POSITIVE: y_max = 2.8575
#   at-individual_belief_high: mean=2.7600, SE=0.2079, n=25
#     -> Treating as POSITIVE: y_max = 3.1757
#   at-common_belief: mean=2.8590, SE=0.1191, n=26
#     -> Treating as POSITIVE: y_max = 3.0972
#   at-joint_belief: mean=2.8472, SE=0.2397, n=24
#     -> Treating as POSITIVE: y_max = 3.3267
#   sb-individual_belief_low: mean=2.7816, SE=0.1153, n=29
#     -> Treating as POSITIVE: y_max = 3.0121
#   sb-individual_belief_high: mean=3.7018, SE=0.2074, n=19
#     -> Treating as POSITIVE: y_max = 4.1166
#   sb-common_belief: mean=2.7308, SE=0.1369, n=26
#     -> Treating as POSITIVE: y_max = 3.0046
#   sb-joint_belief: mean=3.2976, SE=0.1870, n=28
#     -> Treating as POSITIVE: y_max = 3.6716
#   at-individual_belief_low: mean=2.3333, SE=0.2869, n=9
#     -> Treating as POSITIVE: y_max = 2.9071
#   at-individual_belief_high: mean=2.6190, SE=0.2305, n=14
#     -> Treating as POSITIVE: y_max = 3.0800
#   at-common_belief: mean=2.6667, SE=0.2428, n=7
#     -> Treating as POSITIVE: y_max = 3.1523
#   at-joint_belief: mean=2.3810, SE=0.2583, n=14
#     -> Treating as POSITIVE: y_max = 2.8976
#   sb-individual_belief_low: mean=2.9583, SE=0.1715, n=16
#     -> Treating as POSITIVE: y_max = 3.3013
#   sb-individual_belief_high: mean=3.5238, SE=0.3001, n=7
#     -> Treating as POSITIVE: y_max = 4.1240
#   sb-common_belief: mean=2.7667, SE=0.1767, n=10
#     -> Treating as POSITIVE: y_max = 3.1201
#   sb-joint_belief: mean=3.1389, SE=0.2404, n=12
#     -> Treating as POSITIVE: y_max = 3.6197
#   -> FINAL: All positive means, y_range = (0.9500, 4.5364)
#
# === Processing domain variable: N_correct_final_tests ===
#   at-individual_belief_low: mean=3.4138, SE=0.3666, n=29
#     -> Treating as POSITIVE: y_max = 4.1470
#   at-individual_belief_high: mean=5.0800, SE=0.1953, n=25
#     -> Treating as POSITIVE: y_max = 5.4706
#   at-common_belief: mean=2.5385, SE=0.3535, n=26
#     -> Treating as POSITIVE: y_max = 3.2454
#   at-joint_belief: mean=4.7917, SE=0.2499, n=24
#     -> Treating as POSITIVE: y_max = 5.2914
#   sb-individual_belief_low: mean=3.0690, SE=0.3195, n=29
#     -> Treating as POSITIVE: y_max = 3.7080
#   sb-individual_belief_high: mean=3.1579, SE=0.2498, n=19
#     -> Treating as POSITIVE: y_max = 3.6575
#   sb-common_belief: mean=2.9615, SE=0.3826, n=26
#     -> Treating as POSITIVE: y_max = 3.7268
#   sb-joint_belief: mean=2.4286, SE=0.2547, n=28
#     -> Treating as POSITIVE: y_max = 2.9380
#   at-individual_belief_low: mean=4.0000, SE=0.4157, n=9
#     -> Treating as POSITIVE: y_max = 4.8315
#   at-individual_belief_high: mean=5.2857, SE=0.2354, n=14
#     -> Treating as POSITIVE: y_max = 5.7564
#   at-common_belief: mean=2.8571, SE=0.6524, n=7
#     -> Treating as POSITIVE: y_max = 4.1620
#   at-joint_belief: mean=5.2143, SE=0.2065, n=14
#     -> Treating as POSITIVE: y_max = 5.6273
#   sb-individual_belief_low: mean=3.5000, SE=0.4507, n=16
#     -> Treating as POSITIVE: y_max = 4.4014
#   sb-individual_belief_high: mean=3.1429, SE=0.3741, n=7
#     -> Treating as POSITIVE: y_max = 3.8910
#   sb-common_belief: mean=2.5000, SE=0.6964, n=10
#     -> Treating as POSITIVE: y_max = 3.8928
#   sb-joint_belief: mean=2.4167, SE=0.3624, n=12
#     -> Treating as POSITIVE: y_max = 3.1416
#   -> FINAL: All positive means, y_range = (0.0000, 6.3321)
#
# === Processing domain variable: avg_traj_regret_norm_final ===
#   at-individual_belief_low: mean=-0.4433, SE=0.0577, n=29
#     -> Treating as NEGATIVE: y_min = -0.5587
#   at-individual_belief_high: mean=-0.0767, SE=0.0238, n=25
#     -> Treating as NEGATIVE: y_min = -0.1243
#   at-common_belief: mean=-0.4737, SE=0.0659, n=26
#     -> Treating as NEGATIVE: y_min = -0.6055
#   at-joint_belief: mean=-0.0943, SE=0.0231, n=24
#     -> Treating as NEGATIVE: y_min = -0.1405
#   sb-individual_belief_low: mean=-0.5300, SE=0.0627, n=29
#     -> Treating as NEGATIVE: y_min = -0.6554
#   sb-individual_belief_high: mean=-0.3090, SE=0.0937, n=19
#     -> Treating as NEGATIVE: y_min = -0.4964
#   sb-common_belief: mean=-0.4063, SE=0.0577, n=26
#     -> Treating as NEGATIVE: y_min = -0.5217
#   sb-joint_belief: mean=-0.6450, SE=0.1432, n=28
#     -> Treating as NEGATIVE: y_min = -0.9313
#   at-individual_belief_low: mean=-0.3814, SE=0.1122, n=9
#     -> Treating as NEGATIVE: y_min = -0.6057
#   at-individual_belief_high: mean=-0.0468, SE=0.0169, n=14
#     -> Treating as NEGATIVE: y_min = -0.0805
#   at-common_belief: mean=-0.5238, SE=0.1306, n=7
#     -> Treating as NEGATIVE: y_min = -0.7849
#   at-joint_belief: mean=-0.0534, SE=0.0178, n=14
#     -> Treating as NEGATIVE: y_min = -0.0889
#   sb-individual_belief_low: mean=-0.5090, SE=0.0846, n=16
#     -> Treating as NEGATIVE: y_min = -0.6781
#   sb-individual_belief_high: mean=-0.2458, SE=0.1239, n=7
#     -> Treating as NEGATIVE: y_min = -0.4935
#   sb-common_belief: mean=-0.3323, SE=0.0761, n=10
#     -> Treating as NEGATIVE: y_min = -0.4844
#   sb-joint_belief: mean=-0.5909, SE=0.1702, n=12
#     -> Treating as NEGATIVE: y_min = -0.9313
#   -> FINAL: All negative means, y_range = (-1.0245, 0.1024)
#
# === Processing domain variable: avg_traj_regret_norm_diagnostic ===
#   at-individual_belief_low: mean=-0.1055, SE=0.0113, n=29
#     -> Treating as NEGATIVE: y_min = -0.1280
#   at-individual_belief_high: mean=-0.1097, SE=0.0241, n=25
#     -> Treating as NEGATIVE: y_min = -0.1578
#   at-common_belief: mean=-0.1121, SE=0.0176, n=26
#     -> Treating as NEGATIVE: y_min = -0.1474
#   at-joint_belief: mean=-0.0782, SE=0.0165, n=24
#     -> Treating as NEGATIVE: y_min = -0.1112
#   sb-individual_belief_low: mean=-0.0754, SE=0.0108, n=29
#     -> Treating as NEGATIVE: y_min = -0.0969
#   sb-individual_belief_high: mean=-0.0665, SE=0.0178, n=19
#     -> Treating as NEGATIVE: y_min = -0.1021
#   sb-common_belief: mean=-0.1099, SE=0.0129, n=26
#     -> Treating as NEGATIVE: y_min = -0.1358
#   sb-joint_belief: mean=-0.0889, SE=0.0201, n=28
#     -> Treating as NEGATIVE: y_min = -0.1290
#   at-individual_belief_low: mean=-0.0952, SE=0.0178, n=9
#     -> Treating as NEGATIVE: y_min = -0.1307
#   at-individual_belief_high: mean=-0.0632, SE=0.0111, n=14
#     -> Treating as NEGATIVE: y_min = -0.0854
#   at-common_belief: mean=-0.1103, SE=0.0177, n=7
#     -> Treating as NEGATIVE: y_min = -0.1457
#   at-joint_belief: mean=-0.0292, SE=0.0100, n=14
#     -> Treating as NEGATIVE: y_min = -0.0493
#   sb-individual_belief_low: mean=-0.0539, SE=0.0107, n=16
#     -> Treating as NEGATIVE: y_min = -0.0752
#   sb-individual_belief_high: mean=-0.0257, SE=0.0047, n=7
#     -> Treating as NEGATIVE: y_min = -0.0351
#   sb-common_belief: mean=-0.1105, SE=0.0228, n=10
#     -> Treating as NEGATIVE: y_min = -0.1560
#   sb-joint_belief: mean=-0.0244, SE=0.0034, n=12
#     -> Treating as NEGATIVE: y_min = -0.0312
#   -> FINAL: All negative means, y_range = (-0.1736, 0.0174)
#
# === Processing domain variable: avg_est_regret_norm_final ===
#   at-individual_belief_low: mean=-0.3790, SE=0.0516, n=29
#     -> Treating as NEGATIVE: y_min = -0.4822
#   at-individual_belief_high: mean=-0.0521, SE=0.0153, n=25
#     -> Treating as NEGATIVE: y_min = -0.0826
#   at-common_belief: mean=-0.5024, SE=0.0592, n=26
#     -> Treating as NEGATIVE: y_min = -0.6209
#   at-joint_belief: mean=-0.1906, SE=0.1073, n=24
#     -> Treating as NEGATIVE: y_min = -0.4051
#   sb-individual_belief_low: mean=-0.5212, SE=0.0599, n=29
#     -> Treating as NEGATIVE: y_min = -0.6410
#   sb-individual_belief_high: mean=-0.5549, SE=0.1518, n=19
#     -> Treating as NEGATIVE: y_min = -0.8584
#   sb-common_belief: mean=-0.5090, SE=0.0566, n=26
#     -> Treating as NEGATIVE: y_min = -0.6222
#   sb-joint_belief: mean=-0.9987, SE=0.2325, n=28
#     -> Treating as NEGATIVE: y_min = -1.4638
#   at-individual_belief_low: mean=-0.2833, SE=0.0860, n=9
#     -> Treating as NEGATIVE: y_min = -0.4553
#   at-individual_belief_high: mean=-0.0360, SE=0.0181, n=14
#     -> Treating as NEGATIVE: y_min = -0.0722
#   at-common_belief: mean=-0.5659, SE=0.1292, n=7
#     -> Treating as NEGATIVE: y_min = -0.8242
#   at-joint_belief: mean=-0.0769, SE=0.0285, n=14
#     -> Treating as NEGATIVE: y_min = -0.1339
#   sb-individual_belief_low: mean=-0.5230, SE=0.0738, n=16
#     -> Treating as NEGATIVE: y_min = -0.6705
#   sb-individual_belief_high: mean=-0.4797, SE=0.2032, n=7
#     -> Treating as NEGATIVE: y_min = -0.8860
#   sb-common_belief: mean=-0.4510, SE=0.0823, n=10
#     -> Treating as NEGATIVE: y_min = -0.6155
#   sb-joint_belief: mean=-0.7218, SE=0.2083, n=12
#     -> Treating as NEGATIVE: y_min = -1.1383
#   -> FINAL: All negative means, y_range = (-1.6102, 0.1610)
#
# === Processing domain variable: avg_est_regret_norm_diagnostic ===
#   at-individual_belief_low: mean=-0.1633, SE=0.0164, n=29
#     -> Treating as NEGATIVE: y_min = -0.1961
#   at-individual_belief_high: mean=-3950419125237.5132, SE=3870604450785.3057, n=25
#     -> Treating as NEGATIVE: y_min = -11691628026808.1250
#   at-common_belief: mean=-0.1510, SE=0.0180, n=26
#     -> Treating as NEGATIVE: y_min = -0.1870
#   at-joint_belief: mean=-0.0908, SE=0.0267, n=24
#     -> Treating as NEGATIVE: y_min = -0.1442
#   sb-individual_belief_low: mean=-0.1930, SE=0.0193, n=29
#     -> Treating as NEGATIVE: y_min = -0.2315
#   sb-individual_belief_high: mean=-0.3633, SE=0.0549, n=19
#     -> Treating as NEGATIVE: y_min = -0.4731
#   sb-common_belief: mean=-0.1824, SE=0.0317, n=26
#     -> Treating as NEGATIVE: y_min = -0.2459
#   sb-joint_belief: mean=-0.2918, SE=0.0541, n=28
#     -> Treating as NEGATIVE: y_min = -0.4000
#   at-individual_belief_low: mean=-0.1115, SE=0.0240, n=9
#     -> Treating as NEGATIVE: y_min = -0.1596
#   at-individual_belief_high: mean=-0.0438, SE=0.0114, n=14
#     -> Treating as NEGATIVE: y_min = -0.0666
#   at-common_belief: mean=-0.1514, SE=0.0339, n=7
#     -> Treating as NEGATIVE: y_min = -0.2192
#   at-joint_belief: mean=-0.0251, SE=0.0115, n=14
#     -> Treating as NEGATIVE: y_min = -0.0482
#   sb-individual_belief_low: mean=-0.2123, SE=0.0221, n=16
#     -> Treating as NEGATIVE: y_min = -0.2566
#   sb-individual_belief_high: mean=-0.3887, SE=0.1046, n=7
#     -> Treating as NEGATIVE: y_min = -0.5980
#   sb-common_belief: mean=-0.1437, SE=0.0293, n=10
#     -> Treating as NEGATIVE: y_min = -0.2024
#   sb-joint_belief: mean=-0.2377, SE=0.0706, n=12
#     -> Treating as NEGATIVE: y_min = -0.3789
#   -> FINAL: All negative means, y_range = (-12860790829488.9395, 1286079082948.8940)
#
# === Processing domain variable: total_KC_rounds ===
#   at-individual_belief_low: mean=10.0690, SE=0.2841, n=29
#     -> Treating as POSITIVE: y_max = 10.6371
#   at-individual_belief_high: mean=7.9600, SE=0.4214, n=25
#     -> Treating as POSITIVE: y_max = 8.8027
#   at-common_belief: mean=7.0769, SE=0.3726, n=26
#     -> Treating as POSITIVE: y_max = 7.8221
#   at-joint_belief: mean=6.5000, SE=0.4330, n=24
#     -> Treating as POSITIVE: y_max = 7.3660
#   sb-individual_belief_low: mean=9.0345, SE=0.4036, n=29
#     -> Treating as POSITIVE: y_max = 9.8416
#   sb-individual_belief_high: mean=9.5789, SE=0.3594, n=19
#     -> Treating as POSITIVE: y_max = 10.2978
#   sb-common_belief: mean=8.6154, SE=0.3175, n=26
#     -> Treating as POSITIVE: y_max = 9.2504
#   sb-joint_belief: mean=9.3929, SE=0.3168, n=28
#     -> Treating as POSITIVE: y_max = 10.0264
#   at-individual_belief_low: mean=9.0000, SE=0.5443, n=9
#     -> Treating as POSITIVE: y_max = 10.0887
#   at-individual_belief_high: mean=7.5000, SE=0.5416, n=14
#     -> Treating as POSITIVE: y_max = 8.5833
#   at-common_belief: mean=7.4286, SE=1.1756, n=7
#     -> Treating as POSITIVE: y_max = 9.7797
#   at-joint_belief: mean=5.4286, SE=0.5221, n=14
#     -> Treating as POSITIVE: y_max = 6.4728
#   sb-individual_belief_low: mean=8.3750, SE=0.6242, n=16
#     -> Treating as POSITIVE: y_max = 9.6234
#   sb-individual_belief_high: mean=8.8571, SE=0.7674, n=7
#     -> Treating as POSITIVE: y_max = 10.3920
#   sb-common_belief: mean=7.3000, SE=0.3755, n=10
#     -> Treating as POSITIVE: y_max = 8.0510
#   sb-joint_belief: mean=9.0833, SE=0.4924, n=12
#     -> Treating as POSITIVE: y_max = 10.0682
#   -> FINAL: All positive means, y_range = (2.8500, 11.7008)
#
# === Processing round variable: demo_BEC_area ===
#   sb-individual_belief_low: mean=2.4251, SE=0.1916, n=54
#     -> Treating as POSITIVE: y_max = 2.8082
#   sb-individual_belief_high: mean=1.4883, SE=0.0791, n=429
#     -> Treating as POSITIVE: y_max = 1.6464
#   sb-common_belief: mean=1.8064, SE=0.2134, n=72
#     -> Treating as POSITIVE: y_max = 2.2333
#   sb-joint_belief: mean=2.7615, SE=0.0943, n=401
#     -> Treating as POSITIVE: y_max = 2.9500
#   at-individual_belief_low: mean=3.7740, SE=0.2370, n=60
#     -> Treating as POSITIVE: y_max = 4.2480
#   at-individual_belief_high: mean=3.2322, SE=0.1073, n=408
#     -> Treating as POSITIVE: y_max = 3.4467
#   at-common_belief: mean=3.6449, SE=0.1496, n=60
#     -> Treating as POSITIVE: y_max = 3.9440
#   at-joint_belief: mean=3.4580, SE=0.1274, n=256
#     -> Treating as POSITIVE: y_max = 3.7127
#   at-individual_belief_low: mean=3.8015, SE=0.3828, n=32
#     -> Treating as POSITIVE: y_max = 4.5671
#   at-individual_belief_high: mean=3.5296, SE=0.1924, n=120
#     -> Treating as POSITIVE: y_max = 3.9143
#   at-common_belief: mean=4.0910, SE=0.6328, n=4
#     -> Treating as POSITIVE: y_max = 5.3567
#   at-joint_belief: mean=3.4739, SE=0.1787, n=123
#     -> Treating as POSITIVE: y_max = 3.8313
#   sb-individual_belief_low: mean=2.7689, SE=0.1869, n=38
#     -> Treating as POSITIVE: y_max = 3.1428
#   sb-individual_belief_high: mean=1.4575, SE=0.1295, n=148
#     -> Treating as POSITIVE: y_max = 1.7165
#   sb-common_belief: mean=2.2943, SE=0.5484, n=7
#     -> Treating as POSITIVE: y_max = 3.3912
#   sb-joint_belief: mean=2.6373, SE=0.1358, n=200
#     -> Treating as POSITIVE: y_max = 2.9089
#   -> FINAL: All positive means, y_range = (0.0000, 5.8923)
#
# === Processing round variable: test_BEC_area ===
#   sb-individual_belief_low: mean=0.7188, SE=0.1735, n=54
#     -> Treating as POSITIVE: y_max = 1.0659
#   sb-individual_belief_high: mean=0.5025, SE=0.0555, n=429
#     -> Treating as POSITIVE: y_max = 0.6134
#   sb-common_belief: mean=0.6569, SE=0.1763, n=72
#     -> Treating as POSITIVE: y_max = 1.0095
#   sb-joint_belief: mean=1.5092, SE=0.1080, n=401
#     -> Treating as POSITIVE: y_max = 1.7253
#   at-individual_belief_low: mean=2.3125, SE=0.3346, n=60
#     -> Treating as POSITIVE: y_max = 2.9816
#   at-individual_belief_high: mean=2.0931, SE=0.1256, n=408
#     -> Treating as POSITIVE: y_max = 2.3443
#   at-common_belief: mean=1.5988, SE=0.2677, n=60
#     -> Treating as POSITIVE: y_max = 2.1343
#   at-joint_belief: mean=2.1906, SE=0.1593, n=256
#     -> Treating as POSITIVE: y_max = 2.5093
#   at-individual_belief_low: mean=2.7054, SE=0.4892, n=32
#     -> Treating as POSITIVE: y_max = 3.6838
#   at-individual_belief_high: mean=2.2386, SE=0.2413, n=120
#     -> Treating as POSITIVE: y_max = 2.7211
#   at-common_belief: mean=1.8988, SE=1.2657, n=4
#     -> Treating as POSITIVE: y_max = 4.4301
#   at-joint_belief: mean=2.1432, SE=0.2272, n=123
#     -> Treating as POSITIVE: y_max = 2.5976
#   sb-individual_belief_low: mean=0.9898, SE=0.2328, n=38
#     -> Treating as POSITIVE: y_max = 1.4555
#   sb-individual_belief_high: mean=0.4838, SE=0.0859, n=148
#     -> Treating as POSITIVE: y_max = 0.6557
#   sb-common_belief: mean=0.1006, SE=0.0260, n=7
#     -> Treating as POSITIVE: y_max = 0.1526
#   sb-joint_belief: mean=1.4726, SE=0.1508, n=200
#     -> Treating as POSITIVE: y_max = 1.7743
#   -> FINAL: All positive means, y_range = (0.0000, 4.8731)
#
# === Processing round variable: avg_traj_regret_norm ===
#   sb-individual_belief_low: mean=-0.0286, SE=0.0064, n=46
#     -> Treating as NEGATIVE: y_min = -0.0415
#   sb-individual_belief_high: mean=-0.0625, SE=0.0093, n=206
#     -> Treating as NEGATIVE: y_min = -0.0811
#   sb-common_belief: mean=-0.0738, SE=0.0220, n=41
#     -> Treating as NEGATIVE: y_min = -0.1178
#   sb-joint_belief: mean=-0.0871, SE=0.0125, n=292
#     -> Treating as NEGATIVE: y_min = -0.1122
#   at-individual_belief_low: mean=-0.0906, SE=0.0177, n=43
#     -> Treating as NEGATIVE: y_min = -0.1260
#   at-individual_belief_high: mean=-0.1187, SE=0.0151, n=242
#     -> Treating as NEGATIVE: y_min = -0.1489
#   at-common_belief: mean=-0.2118, SE=0.0498, n=34
#     -> Treating as NEGATIVE: y_min = -0.3115
#   at-joint_belief: mean=-0.0953, SE=0.0143, n=176
#     -> Treating as NEGATIVE: y_min = -0.1238
#   at-individual_belief_low: mean=-0.0992, SE=0.0223, n=32
#     -> Treating as NEGATIVE: y_min = -0.1439
#   at-individual_belief_high: mean=-0.0658, SE=0.0104, n=120
#     -> Treating as NEGATIVE: y_min = -0.0865
#   at-common_belief: mean=-0.1731, SE=0.1499, n=4
#     -> Treating as NEGATIVE: y_min = -0.4729
#   at-joint_belief: mean=-0.0538, SE=0.0100, n=99
#     -> Treating as NEGATIVE: y_min = -0.0738
#   sb-individual_belief_low: mean=-0.0249, SE=0.0064, n=38
#     -> Treating as NEGATIVE: y_min = -0.0377
#   sb-individual_belief_high: mean=-0.0588, SE=0.0097, n=147
#     -> Treating as NEGATIVE: y_min = -0.0782
#   sb-common_belief: mean=-0.0096, SE=0.0058, n=7
#     -> Treating as NEGATIVE: y_min = -0.0212
#   sb-joint_belief: mean=-0.0438, SE=0.0091, n=200
#     -> Treating as NEGATIVE: y_min = -0.0620
#   -> FINAL: All negative means, y_range = (-0.5201, 0.0520)
#
# === Processing round variable: avg_est_regret_norm ===
#   sb-individual_belief_low: mean=-0.0027, SE=0.0859, n=46
#     -> Treating as NEGATIVE: y_min = -0.1745
#   sb-individual_belief_high: mean=0.0258, SE=0.0711, n=206
#     -> Treating as POSITIVE: y_max = 0.1680
#   sb-common_belief: mean=-0.2958, SE=0.5748, n=41
#     -> Treating as NEGATIVE: y_min = -1.4454
#   sb-joint_belief: mean=0.0756, SE=0.0497, n=292
#     -> Treating as POSITIVE: y_max = 0.1751
#   at-individual_belief_low: mean=0.0227, SE=0.0782, n=41
#     -> Treating as POSITIVE: y_max = 0.1792
#   at-individual_belief_high: mean=-7345820687424.9668, SE=67723474172010.1172, n=242
#     -> Treating as NEGATIVE: y_min = -142792769031445.1875
#   at-common_belief: mean=-0.0630, SE=0.0805, n=33
#     -> Treating as NEGATIVE: y_min = -0.2241
#   at-joint_belief: mean=-0.0605, SE=0.0345, n=173
#     -> Treating as NEGATIVE: y_min = -0.1294
#   at-individual_belief_low: mean=-0.0565, SE=0.0330, n=30
#     -> Treating as NEGATIVE: y_min = -0.1225
#   at-individual_belief_high: mean=-0.0226, SE=0.0131, n=120
#     -> Treating as NEGATIVE: y_min = -0.0487
#   at-common_belief: mean=-0.1389, SE=0.1203, n=4
#     -> Treating as NEGATIVE: y_min = -0.3795
#   at-joint_belief: mean=0.0120, SE=0.0113, n=99
#     -> Treating as POSITIVE: y_max = 0.0346
#   sb-individual_belief_low: mean=-0.0957, SE=0.0906, n=38
#     -> Treating as NEGATIVE: y_min = -0.2768
#   sb-individual_belief_high: mean=0.0469, SE=0.0772, n=147
#     -> Treating as POSITIVE: y_max = 0.2014
#   sb-common_belief: mean=-0.0802, SE=0.1210, n=7
#     -> Treating as NEGATIVE: y_min = -0.3223
#   sb-joint_belief: mean=0.1099, SE=0.0554, n=200
#     -> Treating as POSITIVE: y_max = 0.2207
#   -> FINAL: Mixed means, y_range = (-157072045934589.7188, 0.2428)
#
# === Processing round variable: num_demos ===
#   sb-individual_belief_low: mean=2.0556, SE=0.1061, n=54
#     -> Treating as POSITIVE: y_max = 2.2678
#   sb-individual_belief_high: mean=2.1189, SE=0.0265, n=429
#     -> Treating as POSITIVE: y_max = 2.1718
#   sb-common_belief: mean=2.3750, SE=0.1119, n=72
#     -> Treating as POSITIVE: y_max = 2.5987
#   sb-joint_belief: mean=2.0909, SE=0.0411, n=407
#     -> Treating as POSITIVE: y_max = 2.1731
#   at-individual_belief_low: mean=1.6500, SE=0.0616, n=60
#     -> Treating as POSITIVE: y_max = 1.7732
#   at-individual_belief_high: mean=1.7059, SE=0.0226, n=408
#     -> Treating as POSITIVE: y_max = 1.7510
#   at-common_belief: mean=1.7500, SE=0.0559, n=60
#     -> Treating as POSITIVE: y_max = 1.8618
#   at-joint_belief: mean=1.7266, SE=0.0310, n=256
#     -> Treating as POSITIVE: y_max = 1.7885
#   at-individual_belief_low: mean=1.5938, SE=0.0868, n=32
#     -> Treating as POSITIVE: y_max = 1.7674
#   at-individual_belief_high: mean=1.6917, SE=0.0422, n=120
#     -> Treating as POSITIVE: y_max = 1.7760
#   at-common_belief: mean=1.7500, SE=0.2165, n=4
#     -> Treating as POSITIVE: y_max = 2.1830
#   at-joint_belief: mean=1.7480, SE=0.0454, n=123
#     -> Treating as POSITIVE: y_max = 1.8388
#   sb-individual_belief_low: mean=1.8158, SE=0.1107, n=38
#     -> Treating as POSITIVE: y_max = 2.0373
#   sb-individual_belief_high: mean=2.2162, SE=0.0483, n=148
#     -> Treating as POSITIVE: y_max = 2.3128
#   sb-common_belief: mean=2.2857, SE=0.1707, n=7
#     -> Treating as POSITIVE: y_max = 2.6272
#   sb-joint_belief: mean=2.1200, SE=0.0594, n=200
#     -> Treating as POSITIVE: y_max = 2.2388
#   -> FINAL: All positive means, y_range = (0.9500, 2.8899)
#
# === Processing round variable: num_tests ===
#   sb-individual_belief_low: mean=2.3333, SE=0.0642, n=54
#     -> Treating as POSITIVE: y_max = 2.4616
#   sb-individual_belief_high: mean=2.1608, SE=0.0211, n=429
#     -> Treating as POSITIVE: y_max = 2.2030
#   sb-common_belief: mean=2.5000, SE=0.0962, n=72
#     -> Treating as POSITIVE: y_max = 2.6925
#   sb-joint_belief: mean=2.3243, SE=0.0385, n=407
#     -> Treating as POSITIVE: y_max = 2.4013
#   at-individual_belief_low: mean=1.6000, SE=0.0632, n=60
#     -> Treating as POSITIVE: y_max = 1.7265
#   at-individual_belief_high: mean=1.5735, SE=0.0252, n=408
#     -> Treating as POSITIVE: y_max = 1.6239
#   at-common_belief: mean=1.5500, SE=0.0642, n=60
#     -> Treating as POSITIVE: y_max = 1.6785
#   at-joint_belief: mean=1.5547, SE=0.0369, n=256
#     -> Treating as POSITIVE: y_max = 1.6285
#   at-individual_belief_low: mean=1.5625, SE=0.0877, n=32
#     -> Treating as POSITIVE: y_max = 1.7379
#   at-individual_belief_high: mean=1.5167, SE=0.0471, n=120
#     -> Treating as POSITIVE: y_max = 1.6109
#   at-common_belief: mean=1.2500, SE=0.2165, n=4
#     -> Treating as POSITIVE: y_max = 1.6830
#   at-joint_belief: mean=1.5691, SE=0.0552, n=123
#     -> Treating as POSITIVE: y_max = 1.6796
#   sb-individual_belief_low: mean=2.2632, SE=0.0714, n=38
#     -> Treating as POSITIVE: y_max = 2.4060
#   sb-individual_belief_high: mean=2.2568, SE=0.0395, n=148
#     -> Treating as POSITIVE: y_max = 2.3358
#   sb-common_belief: mean=2.2857, SE=0.1707, n=7
#     -> Treating as POSITIVE: y_max = 2.6272
#   sb-joint_belief: mean=2.3550, SE=0.0529, n=200
#     -> Treating as POSITIVE: y_max = 2.4607
#   -> FINAL: All positive means, y_range = (0.9500, 2.9617)
#
# === Processing round variable: proportion_correct_diagnostic_tests ===
#   sb-individual_belief_low: mean=0.5833, SE=0.0567, n=54
#     -> Treating as POSITIVE: y_max = 0.6967
#   sb-individual_belief_high: mean=0.3862, SE=0.0202, n=429
#     -> Treating as POSITIVE: y_max = 0.4265
#   sb-common_belief: mean=0.3380, SE=0.0453, n=72
#     -> Treating as POSITIVE: y_max = 0.4286
#   sb-joint_belief: mean=0.5407, SE=0.0204, n=407
#     -> Treating as POSITIVE: y_max = 0.5815
#   at-individual_belief_low: mean=0.5000, SE=0.0589, n=60
#     -> Treating as POSITIVE: y_max = 0.6179
#   at-individual_belief_high: mean=0.3991, SE=0.0223, n=408
#     -> Treating as POSITIVE: y_max = 0.4438
#   at-common_belief: mean=0.3333, SE=0.0536, n=60
#     -> Treating as POSITIVE: y_max = 0.4405
#   at-joint_belief: mean=0.4941, SE=0.0294, n=256
#     -> Treating as POSITIVE: y_max = 0.5529
#   at-individual_belief_low: mean=0.5938, SE=0.0810, n=32
#     -> Treating as POSITIVE: y_max = 0.7558
#   at-individual_belief_high: mean=0.6597, SE=0.0404, n=120
#     -> Treating as POSITIVE: y_max = 0.7405
#   at-common_belief: mean=0.7500, SE=0.2165, n=4
#     -> Treating as POSITIVE: y_max = 1.1830
#   at-joint_belief: mean=0.6531, SE=0.0406, n=123
#     -> Treating as POSITIVE: y_max = 0.7343
#   sb-individual_belief_low: mean=0.6842, SE=0.0623, n=38
#     -> Treating as POSITIVE: y_max = 0.8088
#   sb-individual_belief_high: mean=0.6340, SE=0.0289, n=148
#     -> Treating as POSITIVE: y_max = 0.6918
#   sb-common_belief: mean=0.8095, SE=0.1323, n=7
#     -> Treating as POSITIVE: y_max = 1.0740
#   sb-joint_belief: mean=0.7216, SE=0.0245, n=200
#     -> Treating as POSITIVE: y_max = 0.7707
#   -> FINAL: All positive means, y_range = (0.0000, 1.3013)
#
# === Processing round variable: lesson_learned ===
#   sb-individual_belief_low: mean=0.4259, SE=0.0673, n=54
#     -> Treating as POSITIVE: y_max = 0.5605
#   sb-individual_belief_high: mean=0.2517, SE=0.0210, n=429
#     -> Treating as POSITIVE: y_max = 0.2937
#   sb-common_belief: mean=0.1944, SE=0.0466, n=72
#     -> Treating as POSITIVE: y_max = 0.2877
#   sb-joint_belief: mean=0.3686, SE=0.0239, n=407
#     -> Treating as POSITIVE: y_max = 0.4164
#   at-individual_belief_low: mean=0.4167, SE=0.0636, n=60
#     -> Treating as POSITIVE: y_max = 0.5440
#   at-individual_belief_high: mean=0.3260, SE=0.0232, n=408
#     -> Treating as POSITIVE: y_max = 0.3724
#   at-common_belief: mean=0.2333, SE=0.0546, n=60
#     -> Treating as POSITIVE: y_max = 0.3425
#   at-joint_belief: mean=0.4336, SE=0.0310, n=256
#     -> Treating as POSITIVE: y_max = 0.4955
#   at-individual_belief_low: mean=0.5312, SE=0.0882, n=32
#     -> Treating as POSITIVE: y_max = 0.7077
#   at-individual_belief_high: mean=0.6000, SE=0.0447, n=120
#     -> Treating as POSITIVE: y_max = 0.6894
#   at-common_belief: mean=0.7500, SE=0.2165, n=4
#     -> Treating as POSITIVE: y_max = 1.1830
#   at-joint_belief: mean=0.6016, SE=0.0441, n=123
#     -> Treating as POSITIVE: y_max = 0.6899
#   sb-individual_belief_low: mean=0.5263, SE=0.0810, n=38
#     -> Treating as POSITIVE: y_max = 0.6883
#   sb-individual_belief_high: mean=0.3986, SE=0.0402, n=148
#     -> Treating as POSITIVE: y_max = 0.4791
#   sb-common_belief: mean=0.7143, SE=0.1707, n=7
#     -> Treating as POSITIVE: y_max = 1.0558
#   sb-joint_belief: mean=0.5350, SE=0.0353, n=200
#     -> Treating as POSITIVE: y_max = 0.6055
#   -> FINAL: All positive means, y_range = (0.0000, 1.3013)

# %% [markdown]
# ## ANOVA

# %%
import pingouin as pg

# Prepare for Mixed ANOVA
# We need data in long format: one row per observation per variable
domain_long = domain_df.copy()

# Filter to only relevant columns
id_vars = ['user_id', 'group_id', 'experimental_condition', 'domain_name', 'overall_domain_learned']
domain_long = domain_long[id_vars + domain_vars]

# Melt into long format for repeated-measures
domain_long_melted = domain_long.melt(
    id_vars=['user_id', 'experimental_condition', 'domain_name', 'overall_domain_learned'],
    value_vars=domain_vars,
    var_name='measure',
    value_name='value'
)

# Run mixed ANOVA for each dependent measure
anova_results = []

for measure in domain_vars:
    df_measure = domain_long_melted[domain_long_melted['measure'] == measure].copy()
    
    # Run RM Mixed ANOVA: between = experimental_condition, within = domain_name, subject = user_id
    try:
        aov = pg.mixed_anova(
            dv='value',
            within='domain_name',
            between='experimental_condition',
            subject='user_id',
            data=df_measure
        )
        aov['measure'] = measure
        anova_results.append(aov)
    except Exception as e:
        print(f"ANOVA failed for {measure}: {e}")

# Concatenate results
anova_results_df = pd.concat(anova_results, ignore_index=True)
# Show top of results
print(anova_results_df.head())

# Save results to file
anova_results_df.to_csv("rm_mixed_anova_results.csv", index=False)
# Out:
#                    Source        SS  DF1  DF2        MS          F     p-unc  \
# 0  experimental_condition  0.697128    3   49  0.232376   0.372941  0.772872
# 1             domain_name  0.655136    1   49  0.655136   3.856351  0.055245
# 2             Interaction  1.298275    3   49  0.432758   2.547360  0.066594
# 3  experimental_condition  1.489183    3   49  0.496394   0.318816  0.811703
# 4             domain_name  6.708595    1   49  6.708595  12.400969  0.000939
#
#         np2  eps   measure
# 0  0.022323  NaN  avg_attn
# 1  0.072959  1.0  avg_attn
# 2  0.134919  NaN  avg_attn
# 3  0.019146  NaN   avg_use
# 4  0.201967  1.0   avg_use

# %%
from pingouin import pairwise_tukey

# Collect Tukey results
tukey_results = []

for var in domain_long_melted['measure'].unique():
    sub_df = domain_long_melted[domain_long_melted['measure'] == var]

    try:
        tukey = pairwise_tukey(
            data=sub_df,
            dv='value',
            between='experimental_condition'
        )
        tukey['measure'] = var
        tukey_results.append(tukey)
    except Exception as e:
        print(f"Tukey failed for {var}: {e}")

# Combine all Tukey results
tukey_df = pd.concat(tukey_results, ignore_index=True)

# Save to CSV
tukey_df.to_csv("tukey_pairwise_comparisons.csv", index=False)

# Optional: show summary
print(tukey_df.head())
# Out:
#                         A                       B   mean(A)   mean(B)  \
# 0           common_belief  individual_belief_high  4.355087  4.053030
# 1           common_belief   individual_belief_low  4.355087  4.137246
# 2           common_belief            joint_belief  4.355087  4.275641
# 3  individual_belief_high   individual_belief_low  4.053030  4.137246
# 4  individual_belief_high            joint_belief  4.053030  4.275641
#
#        diff        se         T   p-tukey    hedges   measure
# 0  0.302057  0.148380  2.035695  0.179400  0.415581  avg_attn
# 1  0.217842  0.157141  1.386283  0.509814  0.334722  avg_attn
# 2  0.079446  0.143585  0.553305  0.945533  0.138475  avg_attn
# 3 -0.084215  0.144489 -0.582850  0.937122 -0.119997  avg_attn
# 4 -0.222611  0.129617 -1.717456  0.318086 -0.352869  avg_attn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# --- 1. Heat map between domain-level variables (correlation matrix)
def plot_correlation_heatmap(df, variables, title):
    corr = df[variables].corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True, cbar_kws={"shrink": .8})
    plt.title(title)
    plt.tight_layout()
    plt.show()

# --- 2. Heat maps split by experimental condition
def plot_heatmap_by_condition(df, variables, condition_col='experimental_condition'):
    for cond in df[condition_col].unique():
        sub_df = df[df[condition_col] == cond]
        if len(sub_df) > 2:
            plot_correlation_heatmap(sub_df, variables, f"Correlation Heatmap ({cond})")

# --- 3. Trends in BEC convergence (test vs demo BEC area over rounds)
def plot_bec_convergence(round_df):
    plt.figure(figsize=(8, 5))
    sns.lineplot(data=round_df, x='round_num', y='demo_BEC_area', label='Demo BEC Area')
    sns.lineplot(data=round_df, x='round_num', y='test_BEC_area', label='Test BEC Area')
    plt.title("BEC Area Convergence Over Rounds")
    plt.xlabel("Round Number")
    plt.ylabel("BEC Area")
    plt.legend()
    plt.tight_layout()
    plt.show()

# --- 4. Trends in regret convergence over rounds
def plot_regret_convergence(round_df):
    plt.figure(figsize=(8, 5))
    sns.lineplot(data=round_df, x='round_num', y='avg_traj_regret_norm', label='Trajectory Regret')
    sns.lineplot(data=round_df, x='round_num', y='avg_est_regret_norm', label='Estimation Regret')
    plt.title("Regret Convergence Over Rounds")
    plt.xlabel("Round Number")
    plt.ylabel("Normalized Regret")
    plt.legend()
    plt.tight_layout()
    plt.show()

# --- 5. Regret convergence by Knowledge Component (KC)
def plot_regret_convergence_by_KC(round_df):
    if 'KC' not in round_df.columns:
        print("No 'KC' column found in round_df.")
        return
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=round_df, x='round_num', y='avg_traj_regret_norm', hue='KC')
    plt.title("Trajectory Regret Convergence by KC")
    plt.xlabel("Round Number")
    plt.ylabel("Normalized Trajectory Regret")
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(10, 6))
    sns.lineplot(data=round_df, x='round_num', y='avg_est_regret_norm', hue='KC')
    plt.title("Estimation Regret Convergence by KC")
    plt.xlabel("Round Number")
    plt.ylabel("Normalized Estimation Regret")
    plt.tight_layout()
    plt.show()

# Run plots
plot_correlation_heatmap(domain_df, domain_vars, "Domain-Level Variable Correlation")
plot_heatmap_by_condition(domain_df, domain_vars)
plot_bec_convergence(round_df)
plot_regret_convergence(round_df)

# Check if 'KC' column exists for KC-specific plot
plot_regret_convergence_by_KC(round_df)
# Out:
# No 'KC' column found in round_df.

# %%
if 'kc_id' in round_df.columns:
    round_df['kc_id'] = round_df['kc_id'].astype(str)

    # Sample up to 4 rounds per KC
    sampled_round_df = round_df.groupby('kc_id', group_keys=False).apply(lambda x: x.nsmallest(4, 'round_num'))

    print(sampled_round_df)

    # Trajectory regret plot by KC
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=sampled_round_df, x='round_num', y='avg_traj_regret_norm', hue='kc_id')
    plt.title("Trajectory Regret Convergence by KC (Max 4 Rounds Each)")
    plt.xlabel("Round Number")
    plt.ylabel("Normalized Trajectory Regret")
    plt.tight_layout()
    plt.show()

    # Estimation regret plot by KC
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=sampled_round_df, x='round_num', y='avg_est_regret_norm', hue='kc_id')
    plt.title("Estimation Regret Convergence by KC (Max 4 Rounds Each)")
    plt.xlabel("Round Number")
    plt.ylabel("Normalized Estimation Regret")
    plt.tight_layout()
    plt.show()
else:
    print("No 'kc_id' column found in round_df.")
# Out:
#      user_id group_id domain  round_num  N_correct_diagnostic_tests  \
# 0       62_2     20_2     sb          1                           1
# 1       64_2     20_2     sb          1                           0
# 2       65_2     20_2     sb          1                           0
# 12      61_2     21_2     at          1                           0
# 75     105_2     33_2     at          2                           0
# 76     106_2     33_2     at          2                           2
# 77     107_2     33_2     at          2                           0
# 606    109_1     30_1     at          2                           0
# 615    109_1     30_1     at          3                           0
# 616    110_1     30_1     at          3                           1
# 617    114_1     30_1     at          3                           1
# 1024   157_1     45_1     sb          3                           2
#
#       proportion_correct_diagnostic_tests  lesson_learned  demo_BEC_area  \
# 0                                0.500000           False       3.224734
# 1                                0.000000           False       3.224734
# 2                                0.000000           False       3.224734
# 12                               0.000000           False       3.360262
# 75                               0.000000           False       3.360262
# 76                               1.000000            True       3.360262
# 77                               0.000000           False       3.360262
# 606                              0.000000           False       3.360262
# 615                              0.000000           False       6.283185
# 616                              1.000000            True       6.283185
# 617                              1.000000            True       6.283185
# 1024                             0.666667           False       0.000047
#
#       test_BEC_area  avg_traj_regret_norm  ...  \
# 0          0.166282                   NaN  ...
# 1          0.166282                   NaN  ...
# 2          0.166282                   NaN  ...
# 12         0.437338                   NaN  ...
# 75         0.437338             -0.216667  ...
# 76         0.437338              0.000000  ...
# 77         0.437338             -0.216667  ...
# 606        0.437338                   NaN  ...
# 615        6.283185                   NaN  ...
# 616        6.283185              0.000000  ...
# 617        6.283185              0.000000  ...
# 1024       0.000047             -0.079190  ...
#
#                            group_intersection_model_pos  \
# 0     [array([[[-0.97017708,  0.0024276 , -0.2423851...
# 1     [array([[[-0.97017708,  0.0024276 , -0.2423851...
# 2     [array([[[-0.97017708,  0.0024276 , -0.2423851...
# 12    [array([[[-0.85121467,  0.3343402 , -0.4045370...
# 75    [array([[[-0.92975666,  0.06527793, -0.3623414...
# 76    [array([[[-0.92975666,  0.06527793, -0.3623414...
# 77    [array([[[-0.92975666,  0.06527793, -0.3623414...
# 606   [array([[[-0.83268611,  0.48476258, -0.2676547...
# 615   [array([[[-0.82390365,  0.53072025, -0.1987933...
# 616   [array([[[-0.82390365,  0.53072025, -0.1987933...
# 617   [array([[[-0.82390365,  0.53072025, -0.1987933...
# 1024  [array([[[ 0.95545129,  0.26228827, -0.1353429...
#
#                        group_intersection_model_weights  \
# 0     [array([0.00098717, 0.00098717, 0.00098717, .....
# 1     [array([0.00098717, 0.00098717, 0.00098717, .....
# 2     [array([0.00098717, 0.00098717, 0.00098717, .....
# 12    [array([0.00098717, 0.00098717, 0.00098717, .....
# 75    [array([0.00330033, 0.00330033, 0.00330033, 0....
# 76    [array([0.00330033, 0.00330033, 0.00330033, 0....
# 77    [array([0.00330033, 0.00330033, 0.00330033, 0....
# 606   [array([0.00309598, 0.00309598, 0.00309598, 0....
# 615   [array([0.01020408, 0.01020408, 0.01020408, 0....
# 616   [array([0.01020408, 0.01020408, 0.01020408, 0....
# 617   [array([0.01020408, 0.01020408, 0.01020408, 0....
# 1024  [array([0.00065189, 0.00065189, 0.00065189, .....
#
#                                         group_knowledge  round  num_demos  \
# 0     [{'p1': [[array([[ 0,  0, -1]])]], 'p2': [[arr...      1          2
# 1     [{'p1': [[array([[ 0,  0, -1]])]], 'p2': [[arr...      1          2
# 2     [{'p1': [[array([[ 0,  0, -1]])]], 'p2': [[arr...      1          2
# 12    [{'p1': [[array([[ 0,  0, -1]])]], 'p2': [[arr...      1          2
# 75    [{'p1': [[array([[ 1,  0, -4]]), array([[-1,  ...      2          2
# 76    [{'p1': [[array([[ 1,  0, -4]]), array([[-1,  ...      2          2
# 77    [{'p1': [[array([[ 1,  0, -4]]), array([[-1,  ...      2          2
# 606   [{'p1': [[array([[ 1,  0, -4]]), array([[-1,  ...      2          2
# 615   [{'p1': [[array([[ 1,  0, -4]]), array([[-1,  ...      3          1
# 616   [{'p1': [[array([[ 1,  0, -4]]), array([[-1,  ...      3          1
# 617   [{'p1': [[array([[ 1,  0, -4]]), array([[-1,  ...      3          1
# 1024  [{'p1': [[array([[0, 5, 2]]), array([[ 0, -2, ...      3          3
#
#       num_tests                                   demo_constraints  \
# 0             2          [[[0, 1, 0]], [[0, 5, 2]], [[0, -2, -1]]]
# 1             2          [[[0, 1, 0]], [[0, 5, 2]], [[0, -2, -1]]]
# 2             2          [[[0, 1, 0]], [[0, 5, 2]], [[0, -2, -1]]]
# 12            1         [[[-1, 0, 0]], [[-1, 0, 2]], [[1, 0, -4]]]
# 75            2       [[[0, 1, 2]], [[0, -1, -10]], [[0, -1, -4]]]
# 76            2       [[[0, 1, 2]], [[0, -1, -10]], [[0, -1, -4]]]
# 77            2       [[[0, 1, 2]], [[0, -1, -10]], [[0, -1, -4]]]
# 606           2       [[[0, 1, 2]], [[0, -1, -10]], [[0, -1, -4]]]
# 615           1                                      [[[1, 1, 0]]]
# 616           1                                      [[[1, 1, 0]]]
# 617           1                                      [[[1, 1, 0]]]
# 1024          3  [[[-6, 2, -5]], [[-6, 4, -3]], [[0, 1, 0]], [[...
#
#                                 test_constraints  experimental_condition  \
# 0                   [[[0, 5, 2]], [[0, -2, -1]]]            joint_belief
# 1                   [[[0, 5, 2]], [[0, -2, -1]]]            joint_belief
# 2                   [[[0, 5, 2]], [[0, -2, -1]]]            joint_belief
# 12                  [[[1, 0, -4]], [[-1, 0, 2]]]   individual_belief_low
# 75                  [[[0, 1, 2]], [[0, -1, -4]]]   individual_belief_low
# 76                  [[[0, 1, 2]], [[0, -1, -4]]]   individual_belief_low
# 77                  [[[0, 1, 2]], [[0, -1, -4]]]   individual_belief_low
# 606                 [[[0, 1, 2]], [[0, -1, -4]]]            joint_belief
# 615                                [[[1, 1, 0]]]            joint_belief
# 616                                [[[1, 1, 0]]]            joint_belief
# 617                                [[[1, 1, 0]]]            joint_belief
# 1024  [[[3, -3, 1]], [[-6, 4, -3]], [[5, 2, 5]]]  individual_belief_high
#
#      domain_order
# 0           sb-at
# 1           sb-at
# 2           sb-at
# 12          at-sb
# 75          at-sb
# 76          at-sb
# 77          at-sb
# 606         sb-at
# 615         sb-at
# 616         sb-at
# 617         sb-at
# 1024        at-sb
#
# [12 rows x 42 columns]
