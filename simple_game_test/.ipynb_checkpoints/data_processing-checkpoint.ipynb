# %% [markdown]
# ## Process database files

# %%
## Setup
import sqlite3
from typing import List
import os, sys
import dill as pickle
from pathlib import Path
from datetime import datetime
import ast
import copy


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import array
import seaborn as sns

import logging
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger()


# Add the directory where 'app/' lives to sys.path
root_path = Path.cwd().resolve()
if str(root_path) not in sys.path:
    sys.path.insert(0, str(root_path))

logger.info(f"Added to sys.path:  {root_path}")
logger.info(f"sys.path[-1]: {sys.path[-1]}")

try:
    from app.group_teaching.codes.simple_rl.utils import mdp_helpers
    from app.group_teaching.codes.simple_rl.planning import ValueIteration
    from app.group_teaching.codes.simple_rl.utils.make_mdp import make_custom_mdp
    from app.group_teaching.codes.policy_summarization.BEC_helpers import calc_solid_angles
    logger.info("Imported simple_rl successfully")
except Exception as e:
    logger.info(f"Failed to import simple_rl: {e}")

logger.info(f"Functions in mdp_helpers: {dir(mdp_helpers)}")
# Out:
# Added to sys.path:  /home/sureshkj/Projects/flask_closed_loop_teaching/simple_game_test
# sys.path[-1]: /home/sureshkj/.ipython
# Loaded packages....
# Db, migrate, login initialized....
# Socketio initialized....
# Models loaded....
# Routes: Loaded flask apps...
# Routes: Loaded "App"...
# Routes: Loaded python apps...
# /home/sureshkj/anaconda3/envs/aug_taxi/lib/python3.9/site-packages/tensorflow/python/framework/dtypes.py:246: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# Warning: OpenAI gym not installed.
# Routes: Loaded group teaching apps...
# Global db lock:  <unlocked _thread.lock object at 0x7abf70faea50>
# Routes loaded....
# Migrate initialized....
# Login initialized....
# Using 24 processes
# Lock initialized....
# Conditions initialized....
# Groups initialized....
# Db committed....
# Imported simple_rl successfully
# Functions in mdp_helpers: ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'colored', 'np', 'rollout_policy', 'rollout_policy_recursive']
# Tables:
# ['alembic_version', 'domain', 'domain_params', 'group', 'in_person_condition', 'online_condition', 'round', 'trial', 'user']
# Exporting table: alembic_version
# version_num
# Exporting table: domain
# id | timestamp | user_id | group_id | domain_name | attn1 | attn2 | attn3 | use1 | use2 | use3 | understanding | engagement_short_answer | reward_ft_weights
# Exporting table: domain_params
# domain_name | min_subset_constraints_record | env_record | traj_record | traj_features_record | mdp_features_record | consistent_state_count | min_BEC_constraints
# Exporting table: group
# id | user_ids | status | timestamp | current_round | round_data | members | member_user_ids | num_members | num_active_members | members_statuses | members_EOR | members_last_test | ind_member_models | group_union_model | group_intersection_model | models_update_iteration | group_knowledge | first_round_status | experimental_condition | domain_1 | domain_2 | curr_progress | join_timestamps
# Exporting table: in_person_condition
# id | trials | trial_1 | trial_2 | trial_3 | trial_4 | trial_5 | count
# Exporting table: online_condition
# id | trials | feedback_type | no_feedback_trial | feedback_trial | count
# Exporting table: round
# id | domain | domain_progress | status | group_id | round_num | members_statuses | kc_id | min_KC_constraints | variable_filter | nonzero_counter | min_BEC_constraints_running | prior_min_BEC_constraints_running | visited_env_traj_idxs | round_info | last_round | ind_member_models_pos | ind_member_models_weights | group_union_model_pos | group_union_model_weights | group_intersection_model_pos | group_intersection_model_weights | group_knowledge
# Exporting table: trial
# id | timestamp | user_id | group_code | duration_ms | domain | interaction_type | group | round | iteration | subiteration | likert | moves | coordinates | is_opt_response | mdp_parameters | human_model | is_first_time | num_visits | engagement_short_answer | improvement_short_answer | final_score | all_scores
# Exporting table: user
# id | username | password_hash | condition_id | online_condition_id | in_person_condition_id | study_type | feedback_counts | training | code | consent | age | gender | ethnicity | education | browser | final_feedback | num_trials_completed | attention_check | study_completed | curr_progress | curr_progress_time | loop_condition | domain_1 | domain_2 | interaction_type | iteration | subiteration | last_activity | last_activity_time | round | last_iter_in_round | last_test_in_round | group | group_code | group_member_id
# Database converted to Excel file: ../results/full_study_data.xlsx
# Tables:
# ['alembic_version', 'domain', 'domain_params', 'group', 'in_person_condition', 'online_condition', 'round', 'trial', 'user']
# Exporting table: alembic_version
# version_num
# Exporting table: domain
# id | timestamp | user_id | group_id | domain_name | attn1 | attn2 | attn3 | use1 | use2 | use3 | understanding | engagement_short_answer | reward_ft_weights
# Exporting table: domain_params
# domain_name | min_subset_constraints_record | env_record | traj_record | traj_features_record | mdp_features_record | consistent_state_count | min_BEC_constraints
# Exporting table: group
# id | user_ids | status | timestamp | current_round | round_data | members | member_user_ids | num_members | num_active_members | members_statuses | members_EOR | members_last_test | ind_member_models | group_union_model | group_intersection_model | models_update_iteration | group_knowledge | first_round_status | experimental_condition | domain_1 | domain_2 | curr_progress | join_timestamps
# Exporting table: in_person_condition
# id | trials | trial_1 | trial_2 | trial_3 | trial_4 | trial_5 | count
# Exporting table: online_condition
# id | trials | feedback_type | no_feedback_trial | feedback_trial | count
# Exporting table: round
# id | domain | domain_progress | status | group_id | round_num | members_statuses | kc_id | min_KC_constraints | variable_filter | nonzero_counter | min_BEC_constraints_running | prior_min_BEC_constraints_running | visited_env_traj_idxs | round_info | last_round | ind_member_models_pos | ind_member_models_weights | group_union_model_pos | group_union_model_weights | group_intersection_model_pos | group_intersection_model_weights | group_knowledge
# Exporting table: trial
# id | timestamp | user_id | group_code | duration_ms | domain | interaction_type | group | round | iteration | subiteration | likert | moves | coordinates | is_opt_response | mdp_parameters | human_model | is_first_time | num_visits | engagement_short_answer | improvement_short_answer | final_score | all_scores
# Exporting table: user
# id | username | password_hash | condition_id | online_condition_id | in_person_condition_id | study_type | feedback_counts | training | code | consent | age | gender | ethnicity | education | browser | final_feedback | num_trials_completed | attention_check | study_completed | curr_progress | curr_progress_time | loop_condition | domain_1 | domain_2 | interaction_type | iteration | subiteration | last_activity | last_activity_time | round | last_iter_in_round | last_test_in_round | group | group_code | group_member_id
# Database converted to Excel file: ../results/full_study_data.xlsx
# Tables:
# ['alembic_version', 'domain', 'domain_params', 'group', 'in_person_condition', 'online_condition', 'round', 'trial', 'user']
# Exporting table: alembic_version
# version_num
# Exporting table: domain
# id | timestamp | user_id | group_id | domain_name | attn1 | attn2 | attn3 | use1 | use2 | use3 | understanding | engagement_short_answer | reward_ft_weights
# Exporting table: domain_params
# domain_name | min_subset_constraints_record | env_record | traj_record | traj_features_record | mdp_features_record | consistent_state_count | min_BEC_constraints
# Exporting table: group
# id | user_ids | status | timestamp | current_round | round_data | members | member_user_ids | num_members | num_active_members | members_statuses | members_EOR | members_last_test | ind_member_models | group_union_model | group_intersection_model | models_update_iteration | group_knowledge | first_round_status | experimental_condition | domain_1 | domain_2 | curr_progress | join_timestamps
# Exporting table: in_person_condition
# id | trials | trial_1 | trial_2 | trial_3 | trial_4 | trial_5 | count
# Exporting table: online_condition
# id | trials | feedback_type | no_feedback_trial | feedback_trial | count
# Exporting table: round
# id | domain | domain_progress | status | group_id | round_num | members_statuses | kc_id | min_KC_constraints | variable_filter | nonzero_counter | min_BEC_constraints_running | prior_min_BEC_constraints_running | visited_env_traj_idxs | round_info | last_round | ind_member_models_pos | ind_member_models_weights | group_union_model_pos | group_union_model_weights | group_intersection_model_pos | group_intersection_model_weights | group_knowledge
# Exporting table: trial
# id | timestamp | user_id | group_code | duration_ms | domain | interaction_type | group | round | iteration | subiteration | likert | moves | coordinates | is_opt_response | mdp_parameters | human_model | is_first_time | num_visits | engagement_short_answer | improvement_short_answer | final_score | all_scores
# Exporting table: user
# id | username | password_hash | condition_id | online_condition_id | in_person_condition_id | study_type | feedback_counts | training | code | consent | age | gender | ethnicity | education | browser | final_feedback | num_trials_completed | attention_check | study_completed | curr_progress | curr_progress_time | loop_condition | domain_1 | domain_2 | interaction_type | iteration | subiteration | last_activity | last_activity_time | round | last_iter_in_round | last_test_in_round | group | group_code | group_member_id
# Database converted to Excel file: ../results/full_study_data.xlsx
# Tables:
# ['alembic_version', 'domain', 'domain_params', 'group', 'in_person_condition', 'online_condition', 'round', 'trial', 'user']
# Exporting table: alembic_version
# version_num
# Exporting table: domain
# id | timestamp | user_id | group_id | domain_name | attn1 | attn2 | attn3 | use1 | use2 | use3 | understanding | engagement_short_answer | reward_ft_weights
# Exporting table: domain_params
# domain_name | min_subset_constraints_record | env_record | traj_record | traj_features_record | mdp_features_record | consistent_state_count | min_BEC_constraints
# Exporting table: group
# id | user_ids | status | timestamp | current_round | round_data | members | member_user_ids | num_members | num_active_members | members_statuses | members_EOR | members_last_test | ind_member_models | group_union_model | group_intersection_model | models_update_iteration | group_knowledge | first_round_status | experimental_condition | domain_1 | domain_2 | curr_progress | join_timestamps
# Exporting table: in_person_condition
# id | trials | trial_1 | trial_2 | trial_3 | trial_4 | trial_5 | count
# Exporting table: online_condition
# id | trials | feedback_type | no_feedback_trial | feedback_trial | count
# Exporting table: round
# id | domain | domain_progress | status | group_id | round_num | members_statuses | kc_id | min_KC_constraints | variable_filter | nonzero_counter | min_BEC_constraints_running | prior_min_BEC_constraints_running | visited_env_traj_idxs | round_info | last_round | ind_member_models_pos | ind_member_models_weights | group_union_model_pos | group_union_model_weights | group_intersection_model_pos | group_intersection_model_weights | group_knowledge
# Exporting table: trial
# id | timestamp | user_id | group_code | duration_ms | domain | interaction_type | group | round | iteration | subiteration | likert | moves | coordinates | is_opt_response | mdp_parameters | human_model | is_first_time | num_visits | engagement_short_answer | improvement_short_answer | final_score | all_scores
# Exporting table: user
# id | username | password_hash | condition_id | online_condition_id | in_person_condition_id | study_type | feedback_counts | training | code | consent | age | gender | ethnicity | education | browser | final_feedback | num_trials_completed | attention_check | study_completed | curr_progress | curr_progress_time | loop_condition | domain_1 | domain_2 | interaction_type | iteration | subiteration | last_activity | last_activity_time | round | last_iter_in_round | last_test_in_round | group | group_code | group_member_id
# Database converted to Excel file: ../results/full_study_data.xlsx
# Processing DB: ../data/app_db_bf_04_17_1.db
# Db:
# ../data/app_db_bf_04_17_1.db
# Table names:
# ['round', 'group', 'trial', 'domain', 'domain_params', 'condition', 'online_condition', 'in_person_condition', 'user', 'demo', 'survey']
# Valid groups:
# ['58', '46', '53', '57', '30', '31', '27', '28', '54', '59', '24', '47', '50', '89', '48', '86', '51', '29', '45', '55', '56', '79', '90', '34', '32', '49', '44', '87', '78', '33', '88', '52', '60']
# Valid users:
# ['160', '289', '104', '180', '175', '101', '206', '107', '288', '169', '173', '185', '203', '194', '100', '102', '168', '156', '200', '300', '299', '121', '98', '178', '191', '120', '285', '204', '112', '188', '89', '172', '110', '163', '287', '111', '181', '90', '167', '197', '115', '192', '294', '302', '292', '207', '261', '297', '284', '296', '164', '165', '262', '161', '117', '157', '119', '298', '196', '174', '187', '195', '170', '182', '154', '263', '286', '108', '176', '205', '114', '303', '199', '193', '116', '109', '103', '106', '162', '179', '184', '183', '202', '295', '113', '105', '155', '118', '290', '259', '186', '190', '198', '258', '166', '189', '99', '91', '301', '171']
# Read table 'round'
# Filtering table round with column group_id
# Table:
# round
# Column:
# group_id
# Length of df:
# 1501
# Appended 1501 rows to table 'round'
# Read table 'group'
# Filtering table group with column id
# Table:
# group
# Column:
# id
# Length of df:
# 33
# Appended 33 rows to table 'group'
# Read table 'trial'
# Filtering table trial with column group
# Table:
# trial
# Column:
# user_id
# Table:
# trial
# Column:
# group
# Length of df:
# 5656
# Appended 5656 rows to table 'trial'
# Read table 'domain'
# Filtering table domain with column group_id
# Table:
# domain
# Column:
# user_id
# Table:
# domain
# Column:
# group_id
# Length of df:
# 140
# Appended 140 rows to table 'domain'
# Read table 'domain_params'
# Length of df:
# 2
# Appended 2 rows to table 'domain_params'
# Read table 'condition'
# Length of df:
# 0
# Read table 'online_condition'
# Length of df:
# 8
# Appended 8 rows to table 'online_condition'
# Read table 'in_person_condition'
# Length of df:
# 4
# Appended 4 rows to table 'in_person_condition'
# Read table 'user'
# Filtering table user with column group
# Table:
# user
# Column:
# id
# Table:
# user
# Column:
# group
# Length of df:
# 97
# Appended 97 rows to table 'user'
# Read table 'demo'
# Table:
# demo
# Column:
# user_id
# Length of df:
# 0
# Read table 'survey'
# Table:
# survey
# Column:
# user_id
# Length of df:
# 0
# Processing DB: ../data/app_db_bf_06_02_p2.db
# Db:
# ../data/app_db_bf_06_02_p2.db
# Table names:
# ['alembic_version', 'condition', 'domain', 'domain_params', 'group', 'in_person_condition', 'online_condition', 'round', 'trial', 'user', 'demo', 'survey']
# Valid groups:
# ['42', '58', '35', '53', '57', '31', '54', '59', '40', '95', '21', '43', '93', '37', '39', '55', '90', '34', '41', '38', '32', '98', '20', '33', '97', '94', '91', '52', '36']
# Valid users:
# ['65', '104', '180', '101', '107', '169', '173', '185', '62', '100', '102', '168', '121', '98', '124', '178', '135', '120', '127', '285', '67', '112', '172', '110', '163', '111', '181', '133', '167', '115', '294', '292', '284', '129', '164', '61', '165', '274', '117', '122', '281', '280', '177', '170', '182', '279', '64', '293', '286', '108', '270', '125', '114', '272', '128', '283', '271', '126', '134', '116', '109', '103', '106', '162', '179', '131', '184', '273', '183', '295', '113', '132', '123', '105', '282', '290', '291', '66', '63', '166', '275', '99', '130', '171']
# Read table 'alembic_version'
# Length of df:
# 1
# Appended 1 rows to table 'alembic_version'
# Read table 'condition'
# Length of df:
# 0
# Read table 'domain'
# Filtering table domain with column group_id
# Table:
# domain
# Column:
# user_id
# Table:
# domain
# Column:
# group_id
# Length of df:
# 86
# Read existing table 'domain'
# Appended 86 rows to table 'domain'
# Read table 'domain_params'
# Length of df:
# 2
# Read existing table 'domain_params'
# Appended 2 rows to table 'domain_params'
# Read table 'group'
# Filtering table group with column id
# Table:
# group
# Column:
# id
# Length of df:
# 29
# Read existing table 'group'
# Appended 29 rows to table 'group'
# Read table 'in_person_condition'
# Length of df:
# 4
# Read existing table 'in_person_condition'
# Appended 4 rows to table 'in_person_condition'
# Read table 'online_condition'
# Length of df:
# 8
# Read existing table 'online_condition'
# Appended 8 rows to table 'online_condition'
# Read table 'round'
# Filtering table round with column group_id
# Table:
# round
# Column:
# group_id
# Length of df:
# 992
# Read existing table 'round'
# Appended 992 rows to table 'round'
# Read table 'trial'
# Filtering table trial with column group
# Table:
# trial
# Column:
# user_id
# Table:
# trial
# Column:
# group
# Length of df:
# 3597
# Read existing table 'trial'
# Appended 3597 rows to table 'trial'
# Read table 'user'
# Filtering table user with column group
# Table:
# user
# Column:
# id
# Table:
# user
# Column:
# group
# Length of df:
# 74
# Read existing table 'user'
# Appended 74 rows to table 'user'
# Read table 'demo'
# Table:
# demo
# Column:
# user_id
# Length of df:
# 0
# Read table 'survey'
# Table:
# survey
# Column:
# user_id
# Length of df:
# 0
# Merged database created at: ../data/full_data_06_04.db
# Tables:
# ['round', 'group', 'trial', 'domain', 'domain_params', 'online_condition', 'in_person_condition', 'user', 'alembic_version']
# Exporting table: round
# id | domain | domain_progress | status | group_id | round_num | members_statuses | kc_id | min_KC_constraints | variable_filter | nonzero_counter | min_BEC_constraints_running | prior_min_BEC_constraints_running | visited_env_traj_idxs | round_info | last_round | ind_member_models_pos | ind_member_models_weights | group_union_model_pos | group_union_model_weights | group_intersection_model_pos | group_intersection_model_weights | group_knowledge
# Exporting table: group
# id | user_ids | status | timestamp | current_round | round_data | members | member_user_ids | num_members | num_active_members | members_statuses | members_EOR | members_last_test | ind_member_models | group_union_model | group_intersection_model | models_update_iteration | group_knowledge | first_round_status | experimental_condition | domain_1 | domain_2 | curr_progress
# Exporting table: trial
# id | timestamp | user_id | group_code | duration_ms | domain | interaction_type | group | round | iteration | subiteration | likert | moves | coordinates | is_opt_response | mdp_parameters | human_model | is_first_time | num_visits | engagement_short_answer | improvement_short_answer | final_score | all_scores
# Exporting table: domain
# id | timestamp | user_id | group_id | domain_name | attn1 | attn2 | attn3 | use1 | use2 | use3 | understanding | engagement_short_answer | reward_ft_weights
# Exporting table: domain_params
# domain_name | min_subset_constraints_record | env_record | traj_record | traj_features_record | mdp_features_record | consistent_state_count | min_BEC_constraints
# Exporting table: online_condition
# id | trials | feedback_type | no_feedback_trial | feedback_trial | count
# Exporting table: in_person_condition
# id | trials | trial_1 | trial_2 | trial_3 | trial_4 | trial_5 | count
# Exporting table: user
# id | username | password_hash | condition_id | online_condition_id | in_person_condition_id | study_type | feedback_counts | training | code | consent | age | gender | ethnicity | education | browser | final_feedback | num_trials_completed | attention_check | study_completed | curr_progress | curr_progress_time | loop_condition | domain_1 | domain_2 | interaction_type | iteration | subiteration | last_activity | last_activity_time | round | last_iter_in_round | last_test_in_round | group | group_code | group_member_id
# Exporting table: alembic_version
# version_num
# Database converted to Excel file: ../results/output_full_data_06_04.xlsx
# Processing DB: ../data/app_db_bf_06_02_p2.db
# Db:
# ../data/app_db_bf_06_02_p2.db
# Table names:
# ['alembic_version', 'condition', 'domain', 'domain_params', 'group', 'in_person_condition', 'online_condition', 'round', 'trial', 'user', 'demo', 'survey']
# Valid groups:
# ['42', '58', '35', '53', '57', '31', '54', '59', '40', '95', '21', '43', '93', '37', '39', '55', '90', '34', '41', '38', '32', '98', '20', '33', '97', '94', '91', '52', '36']
# Valid users:
# ['65', '104', '180', '101', '107', '169', '173', '185', '62', '100', '102', '168', '121', '98', '124', '178', '135', '120', '127', '285', '67', '112', '172', '110', '163', '111', '181', '133', '167', '115', '294', '292', '284', '129', '164', '61', '165', '274', '117', '122', '281', '280', '177', '170', '182', '279', '64', '293', '286', '108', '270', '125', '114', '272', '128', '283', '271', '126', '134', '116', '109', '103', '106', '162', '179', '131', '184', '273', '183', '295', '113', '132', '123', '105', '282', '290', '291', '66', '63', '166', '275', '99', '130', '171']
# Read table 'alembic_version'
# Length of df:
# 1
# Appended 1 rows to table 'alembic_version'
# Read table 'condition'
# Length of df:
# 0
# Read table 'domain'
# Filtering table domain with column group_id
# Table:
# domain
# Column:
# user_id
# Table:
# domain
# Column:
# group_id
# Length of df:
# 86
# Appended 86 rows to table 'domain'
# Read table 'domain_params'
# Length of df:
# 2
# Appended 2 rows to table 'domain_params'
# Read table 'group'
# Filtering table group with column id
# Table:
# group
# Column:
# id
# Length of df:
# 29
# Appended 29 rows to table 'group'
# Read table 'in_person_condition'
# Length of df:
# 4
# Appended 4 rows to table 'in_person_condition'
# Read table 'online_condition'
# Length of df:
# 8
# Appended 8 rows to table 'online_condition'
# Read table 'round'
# Filtering table round with column group_id
# Table:
# round
# Column:
# group_id
# Length of df:
# 992
# Appended 992 rows to table 'round'
# Read table 'trial'
# Filtering table trial with column group
# Table:
# trial
# Column:
# user_id
# Table:
# trial
# Column:
# group
# Length of df:
# 3597
# Appended 3597 rows to table 'trial'
# Read table 'user'
# Filtering table user with column group
# Table:
# user
# Column:
# id
# Table:
# user
# Column:
# group
# Length of df:
# 74
# Appended 74 rows to table 'user'
# Read table 'demo'
# Table:
# demo
# Column:
# user_id
# Length of df:
# 0
# Read table 'survey'
# Table:
# survey
# Column:
# user_id
# Length of df:
# 0
# Processing DB: ../data/app_db_bf_04_17_1.db
# Db:
# ../data/app_db_bf_04_17_1.db
# Table names:
# ['round', 'group', 'trial', 'domain', 'domain_params', 'condition', 'online_condition', 'in_person_condition', 'user', 'demo', 'survey']
# Valid groups:
# ['58', '46', '53', '57', '30', '31', '27', '28', '54', '59', '24', '47', '50', '89', '48', '86', '51', '29', '45', '55', '56', '79', '90', '34', '32', '49', '44', '87', '78', '33', '88', '52', '60']
# Valid users:
# ['160', '289', '104', '180', '175', '101', '206', '107', '288', '169', '173', '185', '203', '194', '100', '102', '168', '156', '200', '300', '299', '121', '98', '178', '191', '120', '285', '204', '112', '188', '89', '172', '110', '163', '287', '111', '181', '90', '167', '197', '115', '192', '294', '302', '292', '207', '261', '297', '284', '296', '164', '165', '262', '161', '117', '157', '119', '298', '196', '174', '187', '195', '170', '182', '154', '263', '286', '108', '176', '205', '114', '303', '199', '193', '116', '109', '103', '106', '162', '179', '184', '183', '202', '295', '113', '105', '155', '118', '290', '259', '186', '190', '198', '258', '166', '189', '99', '91', '301', '171']
# Read table 'round'
# Filtering table round with column group_id
# Table:
# round
# Column:
# group_id
# Length of df:
# 1501
# Read existing table 'round'
# Appended 1501 rows to table 'round'
# Read table 'group'
# Filtering table group with column id
# Table:
# group
# Column:
# id
# Length of df:
# 33
# Read existing table 'group'
# Appended 33 rows to table 'group'
# Read table 'trial'
# Filtering table trial with column group
# Table:
# trial
# Column:
# user_id
# Table:
# trial
# Column:
# group
# Length of df:
# 5656
# Read existing table 'trial'
# Appended 5656 rows to table 'trial'
# Read table 'domain'
# Filtering table domain with column group_id
# Table:
# domain
# Column:
# user_id
# Table:
# domain
# Column:
# group_id
# Length of df:
# 140
# Read existing table 'domain'
# Appended 140 rows to table 'domain'
# Read table 'domain_params'
# Length of df:
# 2
# Read existing table 'domain_params'
# Appended 2 rows to table 'domain_params'
# Read table 'condition'
# Length of df:
# 0
# Read table 'online_condition'
# Length of df:
# 8
# Read existing table 'online_condition'
# Appended 8 rows to table 'online_condition'
# Read table 'in_person_condition'
# Length of df:
# 4
# Read existing table 'in_person_condition'
# Appended 4 rows to table 'in_person_condition'
# Read table 'user'
# Filtering table user with column group
# Table:
# user
# Column:
# id
# Table:
# user
# Column:
# group
# Length of df:
# 97
# Read existing table 'user'
# Appended 97 rows to table 'user'
# Read table 'demo'
# Table:
# demo
# Column:
# user_id
# Length of df:
# 0
# Read table 'survey'
# Table:
# survey
# Column:
# user_id
# Length of df:
# 0
# Merged database created at: ../data/full_data_06_04.db
# Tables:
# ['alembic_version', 'domain', 'domain_params', 'group', 'in_person_condition', 'online_condition', 'round', 'trial', 'user']
# Exporting table: alembic_version
# version_num
# Exporting table: domain
# id | timestamp | user_id | group_id | domain_name | attn1 | attn2 | attn3 | use1 | use2 | use3 | understanding | engagement_short_answer | reward_ft_weights
# Exporting table: domain_params
# domain_name | min_subset_constraints_record | env_record | traj_record | traj_features_record | mdp_features_record | consistent_state_count | min_BEC_constraints
# Exporting table: group
# id | user_ids | status | timestamp | current_round | round_data | members | member_user_ids | num_members | num_active_members | members_statuses | members_EOR | members_last_test | ind_member_models | group_union_model | group_intersection_model | models_update_iteration | group_knowledge | first_round_status | experimental_condition | domain_1 | domain_2 | curr_progress | join_timestamps
# Exporting table: in_person_condition
# id | trials | trial_1 | trial_2 | trial_3 | trial_4 | trial_5 | count
# Exporting table: online_condition
# id | trials | feedback_type | no_feedback_trial | feedback_trial | count
# Exporting table: round
# id | domain | domain_progress | status | group_id | round_num | members_statuses | kc_id | min_KC_constraints | variable_filter | nonzero_counter | min_BEC_constraints_running | prior_min_BEC_constraints_running | visited_env_traj_idxs | round_info | last_round | ind_member_models_pos | ind_member_models_weights | group_union_model_pos | group_union_model_weights | group_intersection_model_pos | group_intersection_model_weights | group_knowledge
# Exporting table: trial
# id | timestamp | user_id | group_code | duration_ms | domain | interaction_type | group | round | iteration | subiteration | likert | moves | coordinates | is_opt_response | mdp_parameters | human_model | is_first_time | num_visits | engagement_short_answer | improvement_short_answer | final_score | all_scores
# Exporting table: user
# id | username | password_hash | condition_id | online_condition_id | in_person_condition_id | study_type | feedback_counts | training | code | consent | age | gender | ethnicity | education | browser | final_feedback | num_trials_completed | attention_check | study_completed | curr_progress | curr_progress_time | loop_condition | domain_1 | domain_2 | interaction_type | iteration | subiteration | last_activity | last_activity_time | round | last_iter_in_round | last_test_in_round | group | group_code | group_member_id
# Database converted to Excel file: ../results/output_full_data_06_04.xlsx

# %%
## Combine all the different sql databases and filter only valid user data

def find_valid_user_and_group_ids(conn, table_name='user'):
    try:
        user_df = pd.read_sql(f"SELECT * FROM {table_name}", conn)
    except Exception as e:
        print(f"Failed to read '{table_name}': {e}")
        return [], []

    group_col = 'group'
    user_df['group_id'] = user_df.get(group_col, pd.Series([-1]*len(user_df))).copy()
    user_df['group_id'] = user_df['group_id'].fillna(-1).astype(int).astype(str)
    user_df.loc[user_df['group_id'] == '-1', 'group_id'] = ''

    user_df['id'] = user_df['id'].fillna(-1).astype(int).astype(str)
    user_df.loc[user_df['id'] == '-1', 'id'] = ''


    username_col = next((col for col in ['username', 'user_name', 'user_id'] if col in user_df.columns), None)
    if username_col:
        user_df[username_col] = user_df[username_col].astype(str)
        filtered_users = user_df[user_df[username_col].str.len() > 15].copy()
    else:
        filtered_users = user_df.copy()

    if 'curr_progress_time' in filtered_users.columns:
        filtered_users['curr_progress_time'] = pd.to_datetime(
            filtered_users['curr_progress_time'], errors='coerce'
        )
        filtered_users = filtered_users[filtered_users['curr_progress_time'] >= pd.Timestamp('2025-04-01')]


    valid_user_ids = filtered_users['id'].astype(str).tolist()
    valid_group_ids = filtered_users['group_id'].tolist()
    valid_group_ids = [x for x in valid_group_ids if x != '']


    return list(set(valid_user_ids)), list(set(valid_group_ids))



def merge_sqlite_dbs(db_paths: List[str], output_path: str = "merged_valid.sqlite"):
    
    if len(db_paths) < 1:
        raise ValueError("Provide at least one database path.")

    output_conn = sqlite3.connect(output_path)
    group_suffix = len(db_paths)
    for db_path in db_paths:
        
        conn = sqlite3.connect(db_path)

        print(f"\n Processing DB: {db_path}")
        table_names = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)['name'].tolist()
        print('Db: ', db_path, 'Table names: ', table_names)

        valid_users, valid_groups = find_valid_user_and_group_ids(conn)

        if not valid_groups:
            print(f" No valid users/groups found in {db_path}, skipping this DB.")
            conn.close()
            continue

        print("Valid groups:", valid_groups)
        print("Valid users:", valid_users)

        for table in table_names:
            if table != 'group':
                try:
                    df = pd.read_sql(f"SELECT * FROM {table}", conn)
                    print(f" Read table '{table}'")
                except Exception as e:
                    print(f" Could not read table '{table}': {e}", flush=True)
                    continue
            else:
                try:
                    df = pd.read_sql(f'SELECT * FROM "{table}"', conn)
                    print(f" Read table '{table}'")
                except Exception as e:
                    print(f" Could not read table '{table}': {e}", flush=True)
                    continue
            
            # Filter by group if such column exists
            group_col = next((col for col in ['group', 'group_id'] if col in df.columns), None)
            if group_col:
                print(f"Filtering table {table} with column {group_col}")
                df[group_col] = pd.to_numeric(df[group_col], errors='coerce')  # turns 'nan', 'inf', etc. into np.nan
                df[group_col] = df[group_col].fillna('').apply(lambda x: str(int(x)) if x != '' else '')

                # print('Groups list:', df[group_col].unique())
                df = df[df[group_col].isin(valid_groups)]

            elif table == 'group':
                print(f"Filtering table {table} with column id")
                df['id'] = pd.to_numeric(df['id'], errors='coerce')  # turns 'nan', 'inf', etc. into np.nan
                df['id'] = df['id'].fillna('').apply(lambda x: str(int(x)) if x != '' else '')

                # print('Groups list:', df['id'].unique())
                df = df[df['id'].isin(valid_groups)]


            # --- Apply group_id modifier across all relevant fields ---
            for col in df.columns:
                if col in ['group', 'group_id', 'user_id'] or (table == 'group' and col=='id') or (table == 'user' and col=='id'):
                    print('Table:', table, 'Column:', col)
                    df[col] = df[col].apply(lambda x: f"{x}_{group_suffix}" if x else '')
                        
            
            
            print('Length of df: ', len(df))

            if df.empty:
                continue

            # Align columns with existing (if exists)
            try:
                existing = pd.read_sql(f'SELECT * FROM "{table}" LIMIT 0', output_conn)
                print(f" Read existing table '{table}'")
                df = df[[col for col in df.columns if col in existing.columns]]
            except:
                pass

            df.to_sql(table, output_conn, if_exists='append', index=False)
            print(f" Appended {len(df)} rows to table '{table}'", flush=True)


        group_suffix -= 1

        conn.close()

    output_conn.close()
    print(f"\n Merged database created at: {output_path}", flush=True)

######################################

## Convert db files to excel for easy viz and quick debugs


def print_table_data(database_file):
    try:
        
        print("Database file exists:", os.path.exists(database_file))

        
        # Connect to the database
        conn = sqlite3.connect(database_file)
        cursor = conn.cursor()

        # Fetch all table names
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        # cursor.execute("SELECT * FROM [group]")   # Since group is a reserved keyword, you need to escape it in queries.
        # cursor.execute("SELECT * FROM [1]")  


        tables = cursor.fetchall()

        if not tables:
            print("No tables found in the database.")
            return

        # Iterate through each table and print its data
        for table in tables:
            table_name = table[0]
            print(f"\nTable: {table_name}")
            cursor.execute(f"SELECT * FROM [{table_name}]")
            rows = cursor.fetchall()

            # Fetch column names
            column_names = [description[0] for description in cursor.description]
            print(" | ".join(column_names))  # Print column headers


    except sqlite3.Error as e:
        print(f"Database error: {e}")
    except Exception as e:
        print(f"Unexpected error: {e}")
    finally:
        # Close the database connection
        if conn:
            conn.close()


            
def read_table_with_pickle_handling(cursor, table_name):
    """Read a table and deserialize any pickled byte columns."""
    cursor.execute(f'SELECT * FROM [{table_name}]')
    rows = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]

    processed_rows = []
    for row in rows:
        processed_row = []
        for value in row:
            if isinstance(value, bytes):
                try:
                    processed_value = pickle.loads(value)
                except (pickle.UnpicklingError, EOFError, AttributeError):
                    processed_value = value
            else:
                processed_value = value
            processed_row.append(processed_value)
        processed_rows.append(processed_row)

    df = pd.DataFrame(processed_rows, columns=columns)
    return df



def convert_db_to_dataframes(database_file: str) -> Dict[str, pd.DataFrame]:
    """Return a dictionary of table_name -> DataFrame for all tables in the database."""
    dataframes = {}
    try:
        conn = sqlite3.connect(database_file)
        cursor = conn.cursor()

        # Get all table names
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()

        if not tables:
            print("No tables found in the database.")
            return dataframes

        for table in tables:
            table_name = table[0]
            print(f"Reading table: {table_name}")
            try:
                df = read_table_with_pickle_handling(cursor, table_name)
                dataframes[table_name] = df
            except Exception as e:
                print(f"Failed to read table '{table_name}': {e}")
    except Exception as e:
        print(f"Error reading database: {e}")
    finally:
        conn.close()
    
    return dataframes



def convert_db_to_excel(database_file: str, output_excel_file: str, save_pickles: bool = False):
    """Convert a database to an Excel file, optionally saving tables as pickles."""
    dataframes = convert_db_to_dataframes(database_file)

    if not dataframes:
        print("No valid dataframes to write.")
        return

    os.makedirs(os.path.dirname(output_excel_file), exist_ok=True)

    with pd.ExcelWriter(output_excel_file, engine='openpyxl') as writer:
        for table_name, df in dataframes.items():
            print(f"Exporting table: {table_name} | Rows: {len(df)}")
            df.to_excel(writer, sheet_name=table_name[:31], index=False)  # Excel sheet name max length = 31
            if save_pickles:
                df.to_pickle(f"{table_name}.pkl")
    
    
    
    print(f"Exported database to Excel: {output_excel_file}")

#################################################################


databases = ['../data/app_db_bf_06_02_p2.db', '../data/app_db_bf_04_17_1.db']

merge_sqlite_dbs(databases, output_path='../data/full_data_06_04.db')

# Replace 'app.db' with your database file and 'output.xlsx' with the desired Excel file name
convert_db_to_excel('../data/full_data_06_04.db', '../results/output_full_data_06_04.xlsx')

# %%
def rollout_policy_recursive_2(mdp, agent, cur_state, trajs, cur_traj=[], cur_action_seq=[], max_depth=25, max_num_of_trajs=np.inf,  visited_states=None, max_repeats=4):
    # cap the maximum number of recursive trajectories that'll be returned (can be unreasonable to enumerate all
    # equally rewarding trajectories sometimes)
    
    if visited_states is None:
        visited_states = {}

    state_key = str(cur_state)

    visited_states[state_key] = visited_states.get(state_key, 0) + 1
    
    if visited_states[state_key] > max_repeats:
        # print(f"State {cur_state} visited too often. Aborting this branch.")
        return
    
    if len(trajs) > max_num_of_trajs:
        # print("Max number of trajectories reached.")
        return

    if cur_state.is_terminal() or len(cur_traj) >= max_depth:
        # print("Terminal state reached or max depth reached.")
        trajs.append(cur_traj)
        return

    # print('Getting maxq actions for state: {}'.format(cur_state))
    maxq_actions = agent.get_max_q_actions(cur_state)
    took_step = False
    for action in maxq_actions:
        # print('cur action seq: {}'.format(cur_action_seq))
        # print('maxq actions: {}'.format(maxq_actions))
        # print('action: {}'.format(action))

        # mdp has a memory of its current state that needs to be adjusted accordingly
        mdp.set_curr_state(cur_state)

        # deepcopy of state occurs within transition function
        reward, next_state = mdp.execute_agent_action(action)

        if next_state != cur_state:
            took_step = True
            next_traj = cur_traj.copy()
            next_traj.append((cur_state, action, next_state))
            next_action_seq = cur_action_seq.copy() # for debugging
            next_action_seq.append(action)

            rollout_policy_recursive_2(mdp, agent, next_state, trajs, cur_traj=next_traj, cur_action_seq=next_action_seq, visited_states=visited_states)

        if not took_step:
            print('No actions available for state: {}'.format(cur_state))

    return trajs

# %%
import os
import pickle

# Choose domain
domain = 'sb'  # or 'at'
mdp_class = 'augmented_taxi2' if domain == 'at' else 'skateboard2'

# Iterate through all 64 environments
for idx in range(64):
    filename = f"./app/group_teaching/models/{mdp_class}/gt_policies/wt_vi_traj_params_env{str(idx).zfill(5)}.pickle"
    if not os.path.exists(filename):
        print(f"Missing file for env {idx}")
        continue
    try:
        with open(filename, 'rb') as f:
            data = pickle.load(f)
            mdp_dict = data[0][3]
            print(f"env_idx: {idx:02d} | mdp_dict: {mdp_dict}")
    except Exception as e:
        print(f"Error reading {filename}: {e}")

# %%
def match_by_common_keys(dict1, dict2):
    common_keys = set(dict1.keys()) & set(dict2.keys())
    print(f"Common keys: {common_keys}")
    for key in common_keys:
        if dict1[key] != dict2[key]:
            return False
    return True


# Loop through all 64 environment files
def check_env_files(mdp_class, target_dict):
    
    print(f"Checking for matching environment files for {mdp_class}...")
    
    for idx in range(64):
        file_path = f"./app/group_teaching/models/{mdp_class}/gt_policies/wt_vi_traj_params_env{str(idx).zfill(5)}.pickle"

        if not os.path.exists(file_path):
            continue
        try:
            with open(file_path, 'rb') as f:
                data = pickle.load(f)
                candidate_mdp_dict = data[0][3]
                print(f"env_idx: {idx:02d} | candidate_mdp_dict: {candidate_mdp_dict}")
                if match_by_common_keys(target_dict, candidate_mdp_dict):
                    print(f"Match found: env_idx = {idx}")
                    break
        except Exception as e:
            print(f"Error at env {idx}: {e}")
    
    return idx

    

def normalize_reward_weights(weights):
    if isinstance(weights, str):
        weights = ast.literal_eval(weights)

    normalized_weights = np.array([[float(weights[0]), float(weights[1]), -1]])

    return normalized_weights / np.linalg.norm(normalized_weights[0, :], ord=2)



def check_rewards_correct_sign(final_test_data):

    sb_gt_weights = np.array([[0.59565914, 0.3519804, -0.72201107]])
    at_gt_weights = np.array([[-0.63599873, 0.74199852, -0.21199958]])

    if final_test_data['domain'] == 'at':
        gt_weights = at_gt_weights
    elif final_test_data['domain'] == 'sb':
        gt_weights = sb_gt_weights

    final_test_data['scaled_reward_ft_weights'] = normalize_reward_weights(final_test_data['reward_ft_weights'])

    gt_sign = np.sign(gt_weights)

    if (np.sign(final_test_data['scaled_reward_ft_weights']) == gt_sign).all():
        correct_sign = True
    else:
        correct_sign = False

    return correct_sign



def load_mdp_from_file(domain, env_idx):
    if domain == 'at':
        mdp_class = 'augmented_taxi2'
    elif domain == 'sb':
        mdp_class = 'skateboard2'
    else:
        raise ValueError(f"Unknown domain: {domain}")

    base_dir = os.getcwd()
    filename = f"{base_dir}/app/group_teaching/models/{mdp_class}/gt_policies/wt_vi_traj_params_env{str(env_idx).zfill(5)}.pickle"
    
    with open(filename, 'rb') as f:
        wt_vi_traj_env = pickle.load(f)
    
    mdp = wt_vi_traj_env[0][1].mdp
    agent = wt_vi_traj_env[0][1]

    return mdp, agent



def parse_trial_mdp_info(domain, trial_str):

    # 
    if domain == 'at':
        mdp_class = 'augmented_taxi2'
    elif domain == 'sb':
        mdp_class = 'skateboard2'
    else:
        raise ValueError(f"Unknown domain: {domain}")
    
    try:
        # Convert string to dictionary
        trial_mdp_dict = ast.literal_eval(trial_str)

        print("Parsed trial_mdp_dict:", trial_mdp_dict)

        # Extract env_idx (assuming the first index is what you want)
        env_idx = trial_mdp_dict.get('env_traj_idxs', [None])[0]

        # Extract optimal and human moves
        opt_moves = trial_mdp_dict.get('opt_actions', [])

        return env_idx, opt_moves, trial_mdp_dict

    except Exception as e:
        # print(f"No env_idx found: {e}")

        # # try:
        # # Convert string to dictionary
        trial_mdp_dict = ast.literal_eval(trial_str)
        # env_idx = check_env_files(mdp_class, trial_mdp_dict)
        opt_moves = trial_mdp_dict.get('opt_actions', [])

        # print("Searching for closest matching env_idx:", env_idx)

        # return env_idx, opt_moves
        
        # except:
        #     print(f"Failed to parse trial info again: {e}")
        return None, opt_moves, trial_mdp_dict



def calc_opt_traj_from_mdp(mdp, cur_state, weights):

    vi_human = ValueIteration(mdp, sample_rate=1)
    vi_human.run_vi()
    best_reward_features = []
    best_human_traj = []
    if vi_human.stabilized:
        print("Value iteration converged.")
        # obtain all optimal trajectory rollouts according to the human's model (assuming that it's a reasonable policy that has converged)
        human_opt_trajs = rollout_policy_recursive_2(vi_human.mdp, vi_human, cur_state, [], max_num_of_trajs=1)

        print("Number of optimal trajectories:", len(human_opt_trajs))
        cur_best_reward = float('-inf')
        # select the human's possible trajectory that has the highest true reward (i.e. give the human's policy the benefit of the doubt)
        N = len(human_opt_trajs)
        id = 1
        for traj in human_opt_trajs:
            print('Calculating reward for trajectory:', id, 'of', N)
            mu_sb = mdp.accumulate_reward_features(traj, discount=True)  # the human and agent should be working with identical mdps
            reward_hyp = weights.dot(mu_sb.T)
            if reward_hyp > cur_best_reward:
                cur_best_reward = reward_hyp
                best_reward_features = mu_sb
                best_human_traj = traj
            id += 1

    return best_human_traj, best_reward_features



def get_traj_from_mdp(mdp, cur_state, moves_list, weights=None):
    if weights is not None:
        mdp.weights = weights
    
    trajectory = []

    for idx in range(len(moves_list)):
            # assumes that the user study only allows actions that change the state of the MDP
            reward, next_state = mdp.execute_agent_action(moves_list[idx])
            trajectory.append((cur_state, moves_list[idx], next_state))

            # deepcopy occurs within transition function
            cur_state = next_state
    
    return trajectory


def calculate_regret_metrics(trial_data):

    domain = trial_data['domain']

    sb_gt_weights = np.array([[0.59565914, 0.3519804, -0.72201107]])
    at_gt_weights = np.array([[-0.63599873, 0.74199852, -0.21199958]])

    if domain == 'at':
        gt_weights = at_gt_weights
        mdp_class = 'augmented_taxi2'
    elif domain == 'sb':
        gt_weights = sb_gt_weights
        mdp_class = 'skateboard2'
    
    env_idx, opt_moves, trial_mdp_dict = parse_trial_mdp_info(domain, trial_data['mdp_parameters'])
    human_moves = ast.literal_eval(trial_data['moves'])
    human_est_weights = normalize_reward_weights(trial_data['reward_ft_weights'])


    # mdp, agent = load_mdp_from_file(domain, env_idx)
    trial_mdp_dict['weights'] = gt_weights
    mdp = make_custom_mdp(mdp_class, trial_mdp_dict)

    cur_state = mdp.get_init_state()

    # opt_traj = mdp_helpers.rollout_policy(mdp, agent, cur_state=cur_state, action_seq=opt_moves)
    # human_traj = mdp_helpers.rollout_policy(mdp, agent, cur_state=cur_state, action_seq=human_moves)

    print('opt_moves:', opt_moves)

    ## Opt and human rewards under ground truth MDP
    opt_traj = get_traj_from_mdp(mdp, cur_state, opt_moves, weights=gt_weights)
    mdp.reset()
    human_traj = get_traj_from_mdp(mdp, cur_state, human_moves, weights=gt_weights)
    mdp.reset()
    print('opt_traj:', opt_traj)
   
    # Feature counts
    phi_opt = mdp.accumulate_reward_features(opt_traj, discount=True)
    mdp.reset()
    phi_human = mdp.accumulate_reward_features(human_traj, discount=True)
    mdp.reset()

    # Rewards
    human_reward_gt_mdp = gt_weights.dot(phi_human.T)
    opt_reward_gt_mdp = gt_weights.dot(phi_opt.T)

    print('gt_weights:', gt_weights)
    print('phi_opt:', phi_opt)
    print('phi_human:', phi_human)
    print('human_est_weights:', human_est_weights)


    ## Optimal and human rewards under human's expected MDP
    human_mdp = copy.copy(mdp)
    human_mdp.weights = human_est_weights

    est_traj, phi_est = calc_opt_traj_from_mdp(human_mdp, cur_state, human_est_weights)
    human_mdp.reset()

    print('est_traj:', est_traj)
    print('phi_est:', phi_est)

    # Rewards
    human_reward_est_mdp = human_est_weights.dot(phi_human.T)
    opt_reward_est_mdp = human_est_weights.dot(phi_est.T)


    

    # Regret metrics
    # traj_regret = np.dot(gt_weights.flatten(), (phi_opt - phi_human).flatten())

    traj_regret_norm = (opt_reward_gt_mdp - human_reward_gt_mdp)/opt_reward_gt_mdp + 1e-4
    est_regret_norm = (opt_reward_est_mdp - human_reward_est_mdp)/opt_reward_est_mdp + 1e-4

    


    # # Reward regret (compare optimal policy vs. policy from est_weights)
    # if len(phi_est)>0:
    #     reward_regret = np.dot(gt_weights.flatten(), (phi_opt - phi_est).flatten())
    #     internal_regret = np.dot(human_est_weights.flatten(), (phi_est - phi_human).flatten())
    # else:
    #     reward_regret = None
    #     internal_regret = None
    
    # cross_regret = np.dot(gt_weights.flatten(), phi_opt.flatten()) - np.dot(human_est_weights.flatten(), phi_human.flatten())
    # cosine_sim = np.dot(gt_weights.flatten(), human_est_weights.flatten()) / (
    #     np.linalg.norm(gt_weights) * np.linalg.norm(human_est_weights)
    # )

    # print('cosine_sim:', cosine_sim)
    # print('cross_regret:', cross_regret)

    if (np.sign(gt_weights) == np.sign(human_est_weights)).all():
        sign_match = True
    else:
        sign_match = False

    print('sign_match:', sign_match)

    return {
        "opt_reward_gt_mdp": opt_reward_gt_mdp,
        "human_reward_gt_mdp": human_reward_gt_mdp,
        "opt_reward_est_mdp": opt_reward_est_mdp,
        "human_reward_est_mdp": human_reward_est_mdp,
        "traj_regret_norm": traj_regret_norm,
        "est_regret_norm": est_regret_norm,
        "sign_agreement": sign_match,
        "phi_opt": phi_opt,
        "phi_human": phi_human,
        "phi_est": phi_est,
        "est_traj": est_traj
    }


def is_valid_weights(val):
    if isinstance(val, float) and np.isnan(val):
        return False
    if val is None:
        return False
    if hasattr(val, '__len__'):
        return len(val) > 0
    return False


def add_trial_regret_metrics(trial_df, existing_data=None):

    print('Adding trial regret metrics...')

    enriched_rows = []
    id = 0
    

    # compile regret data
    for _, row in trial_df.iterrows():
        
        if is_valid_weights(row['reward_ft_weights']):
            
            print('Reward_ft_weights:', row['reward_ft_weights'])
            
            # Check if regret is already processed for user+domain
            user_id = row['user_id']
            domain = row['domain']
            round_id = row['round']
            iteration = row['iteration']
            
            if existing_data is not None:
                user_existing = existing_data[existing_data['user_id']==user_id && existing_data['domain'] == domain \\
                                                 && existing_data['round'] == round_id && existing_data['iteration']==iteration]

            
            if user_existing is None:
                # Calculate regreat
                regret = calculate_regret_metrics(row)

                # print(regret)

                regret_flat = {
                    k: (
                        regret[k].tolist()
                        if isinstance(regret[k], np.ndarray)
                        else regret[k]
                    )
                    for k in regret
                }

                enriched_row = {**row.to_dict(), **regret_flat}
                
            else:
                enriched_row = {**user_existing.to_dict()}
            
            # append processed trial data w/ regret metrics
            enriched_rows.append(enriched_row)
            id += 1
                


    return pd.DataFrame(enriched_rows)



def process_domain_metrics(domain_df, group_df, trial_df_w_metrics):
    
    final_tests_df = trial_df_w_metrics[trial_df_w_metrics['interaction_type'] == 'final test'].copy()

    # there can be repetitions in data, so we need to find unique entries by user_id and domain. 
    # Note: Ensure that the domain_df has unique user_ids
    unique_domain_df = domain_df.drop_duplicates(subset=['user_id', 'domain_name'])
    
    # Create long format dataframe for domain metrics
    domain_metrics = []
    
    for _, row in unique_domain_df.iterrows():
        domain_name = row.get('domain_name')
        user_id = row.get('user_id')
        group_id = row.get('group_id')
        
        # Calculate average attention
        attn_cols = ['attn1', 'attn2', 'attn3']
        use_cols = ['use1', 'use2', 'use3']


        # calculate survey metrics
        attn_values = [row.get(col) for col in attn_cols if col in row and pd.notnull(row.get(col))]
        avg_attn = sum(attn_values) / len(attn_values) if attn_values else np.nan

        use_values = [row.get(col) for col in use_cols if col in row and pd.notnull(row.get(col))]
        avg_use = sum(use_values) / len(use_values) if use_values else np.nan


        # process final tests
        domain_tests = final_tests_df[(final_tests_df['user_id']==user_id) & (final_tests_df['domain']==domain_name)]

         # Count total tests
        total_tests = len(domain_tests)
            
        # Count correct tests (assuming is_opt_response indicates correctness)
        correct_tests = domain_tests['is_opt_response'].sum() if 'is_opt_response' in domain_tests.columns else 0


        
        # calculate average regret norms
        avg_traj_regret_norm_final = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['group_id'] == group_id) &
                                                (trial_df_w_metrics['domain'] == domain_name) &
                                                (trial_df_w_metrics['interaction_type'] == 'final test')
                                            ]['traj_regret_norm'].mean()
        
        avg_traj_regret_norm_diagnostic = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['group_id'] == group_id) &
                                                (trial_df_w_metrics['domain'] == domain_name) &
                                                (trial_df_w_metrics['interaction_type'] == 'diagnostic test')
                                            ]['traj_regret_norm'].mean()

        avg_est_regret_norm_final = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['group_id'] == group_id) &
                                                (trial_df_w_metrics['domain'] == domain_name) &
                                                (trial_df_w_metrics['interaction_type'] == 'final test')
                                            ]['est_regret_norm'].mean()
        
        avg_est_regret_norm_diagnostic = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['group_id'] == group_id) &
                                                (trial_df_w_metrics['domain'] == domain_name) &
                                                (trial_df_w_metrics['interaction_type'] == 'diagnostic test')
                                            ]['est_regret_norm'].mean()


        domain_metrics.append({'user_id': user_id,
                                'domain_name': domain_name,
                                'avg_attn': avg_attn,
                                'avg_use': avg_use,
                                'N_correct_final_tests': correct_tests,
                                'avg_traj_regret_norm_final': avg_traj_regret_norm_final,
                                'avg_traj_regret_norm_diagnostic': avg_traj_regret_norm_diagnostic,
                                'avg_est_regret_norm_final': avg_est_regret_norm_final,
                                'avg_est_regret_norm_diagnostic': avg_est_regret_norm_diagnostic})
    
    domain_metrics_df = pd.DataFrame(domain_metrics)

    domain_df_w_metrics = unique_domain_df.merge(
        domain_metrics_df,
        on=['user_id', 'domain_name'],
        how='left'
    )


    return domain_df_w_metrics




def process_final_tests(trial_df, group_df, valid_user_ids):

    final_tests_df = trial_df[trial_df['interaction_type'] == 'final test'].copy()
    
    # Determine difficulty based on iteration number
    if 'iteration' in final_tests_df.columns:
        # Map iterations to difficulty levels: 1-2 easy, 3-4 medium, 5-6 hard
        conditions = [
            (final_tests_df['iteration'] <= 2),
            (final_tests_df['iteration'] >= 3) & (final_tests_df['iteration'] <= 4),
            (final_tests_df['iteration'] >= 5) & (final_tests_df['iteration'] <= 6)
        ]
        
        choices = ['easy', 'medium', 'hard']
        
        final_tests_df['difficulty_level'] = np.select(conditions, choices, default='unknown')
        
        print(f"Assigned difficulty levels based on iteration values: "
            f"{final_tests_df['difficulty_level'].value_counts().to_dict()}")
    
    # # Create summary of final tests by domain and user
    # final_test_summary = []
    
    # for user_id in valid_user_ids:
    #     user_tests = final_tests_df[final_tests_df['user_id'] == user_id]
        
        
    #     if user_tests.empty:
    #         continue

    #     group_id = user_tests['group_id'].iloc[0]
            
        # for domain in user_tests['domain'].unique():
        #     domain_tests = user_tests[user_tests['domain'] == domain]
            
        #     # Count total tests
        #     total_tests = len(domain_tests)
            
        #     # Count correct tests (assuming is_opt_response indicates correctness)
        #     correct_tests = domain_tests['is_opt_response'].sum() if 'is_opt_response' in domain_tests.columns else 0
            
        #     # Track which difficulty levels were answered correctly
        #     correct_by_difficulty = {}
            
        #     for level in ['easy', 'medium', 'hard']:
        #         level_tests = domain_tests[domain_tests['difficulty_level'] == level]
        #         correct = level_tests['is_opt_response'].sum() if len(level_tests) > 0 else 0
        #         total = len(level_tests)
        #         [f"{level}_correct"] = correct
        #         # correccorrect_by_difficultyt_by_difficulty[f"{level}_total"] = total
            
        #     # Add to summary
        #     final_test_summary.append({
        #         'user_id': user_id,
        #         'group_id': group_id,
        #         'domain': domain,
        #         'total_tests': total_tests,
        #         'total_correct': correct_tests,
        #         **correct_by_difficulty
        #     })

    
    # final_test_summary_df = pd.DataFrame(final_test_summary)

    # group_conditions = group_df[['group_id', 'experimental_condition', 'domain_order']].copy()

    # # First update theuser dataframe with experimental condition
    # if 'group_id' in final_test_summary_df.columns:
    #     final_test_summary_df = final_test_summary_df.merge(
    #         group_conditions, 
    #         on='group_id',
    #         how='left'
    #     )

    # final_test_summary_df.to_excel('final_test_summary.xlsx', index=False)



def process_round_data(round_df, trial_df_w_metrics, user_df):
    
    round_df = round_df[round_df['status'] != 'final_tests_generated']  # remove final test rounds

    round_metrics = round_df.drop_duplicates(subset=['group_id', 'domain', 'round_num'])

#     round_metrics.to_excel('../results/round_data_no_dup.xlsx', index=False)

    # calculate number of demos, tests
    # Helper function to count demo/test interactions and correctness
    def extract_counts(round_info):
        if isinstance(round_info, str):
            try:
                interactions = ast.literal_eval(round_info)
            except Exception:
                return 0, 0, 0
        elif isinstance(round_info, list):
            interactions = round_info
        else:
            return 0, 0, 0

        num_demos = sum(1 for entry in interactions if entry.get('interaction type') == 'demo')
        test_entries = [entry for entry in interactions if entry.get('interaction type') == 'diagnostic test']
        num_tests = len(test_entries)

        return num_demos, num_tests
    
    # Remove entries that are None or only contain None values (even nested like [[None, None]])
    def is_valid_constraint(c):
        if c is None:
            return False
        flat = flatten(c)
        return any(x is not None for x in flat)

    def flatten(lst):
        # Flattens nested lists one level deep
        return [item for sublist in lst for item in (sublist if isinstance(sublist, list) else [sublist])]
    
    def flatten_two_levels(nested_list):
        return [item for sublist in nested_list for subsublist in sublist for item in subsublist]
    
    def flatten_one_level(constraint_list):
        return [inner[0] if isinstance(inner, list) and len(inner) == 1 else inner for inner in constraint_list]


    def flatten_one_more_level(nested_list):
        flattened = []
        for item in nested_list:
            if isinstance(item, list) and all(isinstance(sub, list) for sub in item):
                flattened.extend(item)  # flatten one level
            else:
                flattened.append(item)  # keep as is
        return flattened

    

    def extract_constraints(round_info):
        if isinstance(round_info, str):
            try:
                interactions = ast.literal_eval(round_info)
            except Exception:
                return [], []
        elif isinstance(round_info, list):
            interactions = round_info
        else:
            return [], []

        demo_constraints = [entry['params'].get('constraints') for entry in interactions if entry.get('interaction type') == 'demo']
        test_constraints = [entry['params'].get('constraints') for entry in interactions if entry.get('interaction type') == 'diagnostic test']

        if is_valid_constraint(demo_constraints):
            demo_constraints_flat = flatten_one_more_level(demo_constraints)
        else:
            demo_constraints_flat = demo_constraints
        
        if is_valid_constraint(test_constraints):
            test_constraints_flat = flatten_one_more_level(test_constraints)
        else:
            test_constraints_flat = test_constraints


        return demo_constraints_flat, test_constraints_flat



    # Apply the function to each row and create new columns
    round_metrics[['num_demos', 'num_tests']] = round_metrics['round_info'].apply(
        lambda x: pd.Series(extract_counts(x))
    )

    round_metrics[['demo_constraints', 'test_constraints']] = round_metrics['round_info'].apply(
        lambda x: pd.Series(extract_constraints(x))
    )
    print('N round metrics:', len(round_metrics))

#     round_metrics.to_excel('../results/round_metrics_2.xlsx', index=False)

    round_learning_metrics = []
    # Calculate round metrics
    for _, row in round_metrics.iterrows():
        group_id = row['group_id']
        domain = row['domain']
        round_num = row['round_num']

        user_ids = user_df[user_df['group'] == group_id]['id'].tolist()

        for user_id in user_ids:

            N_correct_diagnostic_tests = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['domain'] == domain) &
                                                (trial_df_w_metrics['round'] == round_num) &
                                                (trial_df_w_metrics['interaction_type'] == 'diagnostic test')
                                            ]['is_opt_response'].sum()
            
            proportion_correct_diagnostic_tests = N_correct_diagnostic_tests / row['num_tests']

            lesson_learned = True if proportion_correct_diagnostic_tests > 0.98 else False

            per_util_demos = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['domain'] == domain) &
                                                (trial_df_w_metrics['round'] == round_num) &
                                                (trial_df_w_metrics['interaction_type'] == 'demo')
                                            ]['likert'].mean()
            
            per_util_tests = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['domain'] == domain) &
                                                (trial_df_w_metrics['round'] == round_num) &
                                                (trial_df_w_metrics['interaction_type'] == 'diagnostic test')
                                            ]['likert'].mean()
            
            per_util_incorrect_tests = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['domain'] == domain) &
                                                (trial_df_w_metrics['round'] == round_num) &
                                                (trial_df_w_metrics['interaction_type'] == 'diagnostic test') &
                                                (trial_df_w_metrics['is_opt_response'] == 0)
                                            ]['likert'].mean()
            
            per_util_correct_tests = trial_df_w_metrics[
                                                (trial_df_w_metrics['user_id'] == user_id) &
                                                (trial_df_w_metrics['domain'] == domain) &
                                                (trial_df_w_metrics['round'] == round_num) &
                                                (trial_df_w_metrics['interaction_type'] == 'diagnostic test') &
                                                (trial_df_w_metrics['is_opt_response'] == 1)
                                            ]['likert'].mean()



            if is_valid_constraint(row['demo_constraints']):
                print('demo_constraints:', row['demo_constraints'])
                demo_BEC_area = float(calc_solid_angles([row['demo_constraints']])[0])
            else:
                demo_BEC_area = np.nan

            if is_valid_constraint(row['test_constraints']):
                print('test_constraints:', row['test_constraints'])
                test_BEC_area = float(calc_solid_angles([row['test_constraints']])[0])
            else:
                test_BEC_area = np.nan

            # calculate the proportion of particles in the BEC region (Later)


            # average regret norms
            avg_traj_regret_norm = trial_df_w_metrics[
                                                    (trial_df_w_metrics['user_id'] == user_id) &
                                                    (trial_df_w_metrics['domain'] == domain) &
                                                    (trial_df_w_metrics['round'] == round_num) &
                                                    (trial_df_w_metrics['interaction_type'] == 'diagnostic test')
                                                ]['traj_regret_norm'].mean()
            avg_est_regret_norm = trial_df_w_metrics[
                                                    (trial_df_w_metrics['user_id'] == user_id) &
                                                    (trial_df_w_metrics['domain'] == domain) &
                                                    (trial_df_w_metrics['round'] == round_num) &
                                                    (trial_df_w_metrics['interaction_type'] == 'diagnostic test')
                                                ]['est_regret_norm'].mean()

            round_learning_metrics.append({
                'user_id': user_id,
                'group_id': group_id,
                'domain': domain,
                'round_num': round_num,
                'N_correct_diagnostic_tests': N_correct_diagnostic_tests,
                'proportion_correct_diagnostic_tests': proportion_correct_diagnostic_tests,
                'lesson_learned': lesson_learned,
                'demo_BEC_area': demo_BEC_area,
                'test_BEC_area': test_BEC_area,
                'avg_traj_regret_norm': avg_traj_regret_norm,
                'avg_est_regret_norm': avg_est_regret_norm,
                'per_util_demos': per_util_demos,
                'per_util_tests': per_util_tests,
                'per_util_incorrect_tests': per_util_incorrect_tests,
                'per_util_correct_tests': per_util_correct_tests
            })

    round_learning_metrics_df = pd.DataFrame(round_learning_metrics)
    print('N round learning metrics:', len(round_learning_metrics_df))


    # Merge with round_df
    round_learning_metrics_df = round_learning_metrics_df.merge(
        round_metrics,
        on=['group_id', 'domain', 'round_num'],
        how='left'
    )
    print('Merged round metrics shape:', round_learning_metrics_df.shape)

    return round_learning_metrics_df



def process_kc_data(round_df, domain_df_w_metrics, group_df, user_df):
    
    group_conditions = group_df[['group_id', 'experimental_condition', 'domain_order']].copy()

    
    if 'kc_id' in round_df.columns and 'round' in round_df.columns:
        print('Analyzing rounds by kc_id...')
        
        # Count the number of unique rounds for each domain-kc_id combination
        kc_round_counts = (round_df
                        .groupby(['group_id', 'domain', 'kc_id'])
                        .size()
                        .reset_index(name='count'))
        
        # Then limit the count to a maximum of 4
        kc_round_counts['count'] = kc_round_counts['count'].apply(lambda x: min(x, 4))

        # Merge experimental condition from group_df
        # Merge experimental condition with kc_round_counts
        kc_round_counts = kc_round_counts.merge(
            group_conditions,
            on='group_id',
            how='left'
        )
        print(f"Merged experimental conditions with kc_round_counts. Shape: {kc_round_counts.shape}")

        ################################
        # Save the enhanced kc_round_counts dataframe
        kc_round_counts.to_excel('kc_round_counts.xlsx', index=False)


        # Calculate total rounds per user
        print('Calculating total rounds taken by each user...')
        
        # First, we need to link users to their groups
        user_group_mapping = user_df[['id', 'group_id']].drop_duplicates()
        user_group_mapping.rename(columns={'id': 'user_id'}, inplace=True)
        
        # Get rounds per group and domain from kc_round_counts
        # Sum up counts for all KCs to get total rounds per group and domain
        group_domain_rounds = kc_round_counts.groupby(['group_id', 'domain'])['count'].sum().reset_index()
        group_domain_rounds.rename(columns={'count': 'total_rounds'}, inplace=True)
        
        # Create a mapping from groups to total rounds by domain
        print(f"Group-domain total rounds shape: {group_domain_rounds.shape}")
        
        # # Now create a user-level summary by merging with user_group_mapping
        # user_total_rounds = user_group_mapping.merge(
        #     group_domain_rounds,
        #     on='group_id',
        #     how='left'
        # )

        # user_total_rounds.to_excel('user_total_rounds.xlsx', index=False)

        domain_df_w_metrics = domain_df_w_metrics.merge(
                            group_domain_rounds,
                            on=['group_id', 'domain']
        )
        
        return domain_df_w_metrics




def add_learning_metrics(domain_df, round_df):
    
    round_df['domain_name'] = round_df['domain'].copy()

    # Only keep relevant columns
    lesson_df = round_df[['user_id', 'group_id', 'domain_name', 'kc_id', 'round', 'lesson_learned']].copy()

    def analyze_learning(group):
        group = group.sort_values('round')
        group = group.head(4)  # Only consider up to 4 rounds
        learned = False
        learned_at_index = None
        unlearned = False
        N_rounds = len(group)

        # if group['user_id'].iloc[0] == '106_2':
        #     print(group)

        if group['lesson_learned'].iloc[-1] == True:
            learned = True
            first_learned_idx = group[group['lesson_learned']].index[0]
            learned_at_index = group.index.get_loc(first_learned_idx) + 1
            post_learning = group[group['round'] >= group.loc[first_learned_idx, 'round']]
            if not post_learning['lesson_learned'].all():
                unlearned = True

        return pd.Series({
            'learned': learned,
            'unlearned': unlearned,
            'number_rounds': N_rounds
        })

    # Step 1: Analyze learning per KC
    summary = lesson_df.groupby(['user_id', 'group_id', 'domain_name', 'kc_id']).apply(analyze_learning).reset_index()

    # Step 2: Pivot to wide format
    pivoted = summary.pivot(index=['user_id', 'group_id', 'domain_name'],
                            columns='kc_id',
                            values=['learned', 'unlearned', 'number_rounds'])

    pivoted.columns = [f"KC_{kc}_{stat}" for stat, kc in pivoted.columns]
    pivoted = pivoted.reset_index()

    # Step 3: Compute domain-level summary
    def compute_overall_flags(row):
        kc_learned = [row.get(f"KC_{i}_learned") for i in range(3)]
        kc_unlearned = [row.get(f"KC_{i}_unlearned") for i in range(3)]
        kc_rounds = [row.get(f"KC_{i}_number_rounds") for i in range(3)]
        
        learned = int(all(val == True for val in kc_learned if pd.notna(val)))
        unlearned = int(any(val == True for val in kc_unlearned if pd.notna(val)))
        total_rounds = sum(val for val in kc_rounds if pd.notna(val))

        return pd.Series({
            'overall_domain_learned': learned,
            'overall_domain_unlearned': unlearned,
            'total_KC_rounds': total_rounds
        })

    overall_flags = pivoted.apply(compute_overall_flags, axis=1)
    pivoted = pd.concat([pivoted, overall_flags], axis=1)

    # Step 4: Merge with domain_df
    merged = pd.merge(domain_df, pivoted, how='left', on=['user_id', 'group_id', 'domain_name'])

    return merged


def compute_domain_order(row):
    if row.get('domain_1') == 'at':
        return 'at-sb'
    elif row.get('domain_1') == 'sb':
        return 'sb-at'
    else:
        return 'unknown'

# %%
def process_bf_data(file_path):
    """
    Process the data according to specified requirements.
    
    Parameters:
    file_path (str): Path to the Excel file containing the data
    
    Returns:
    dict: Dictionary containing the processed dataframes
    """

    print("Running process_bf_data...", flush=True)
    
    if filename.startswith('output_'):
        file_prefix = file_path[len('output_'):]
    else:
        file_prefix = file_path

    # Read all sheets from the Excel file
    excel_file = pd.ExcelFile(file_path)

    # parse relevant data into dataframes
    print('Parsing all data...', flush=True)
    
    user_df = excel_file.parse('user')
    
    domain_df = excel_file.parse('domain')

    domain_df['group_id'] = domain_df['group_id'].fillna(-1)  # Handle any NaN values first
    domain_df['group_id'] = domain_df['group_id'].astype(int).astype(str)
    domain_df.loc[domain_df['group_id'] == '-1', 'group_id'] = ''

    domain_df['user_id'] = domain_df['user_id'].fillna(-1)  # Handle any NaN values first
    domain_df['user_id'] = domain_df['user_id'].astype(int).astype(str)
    domain_df.loc[domain_df['user_id'] == '-1', 'user_id'] = ''
    #########

    trial_df = excel_file.parse('trial')
    trial_df['group_id'] = trial_df['group'].copy()
    
    trial_df['group_id'] = trial_df['group_id'].fillna(-1)  # Handle any NaN values first
    trial_df['group_id'] = trial_df['group_id'].astype(int).astype(str)
    trial_df.loc[trial_df['group_id'] == '-1', 'group_id'] = ''

    trial_df['user_id'] = trial_df['user_id'].fillna(-1)  # Handle any NaN values first
    trial_df['user_id'] = trial_df['user_id'].astype(int).astype(str)
    trial_df.loc[trial_df['user_id'] == '-1', 'user_id'] = ''
    #########

    round_df = excel_file.parse('round')  
    round_df['round'] = round_df['round_num'].copy()
    
    round_df['group_id'] = round_df['group_id'].fillna(-1)  # Handle any NaN values first
    round_df['group_id'] = round_df['group_id'].astype(int).astype(str)
    round_df.loc[round_df['group_id'] == '-1', 'group_id'] = ''
    
    # only need round information of first status (demo tests generated); others are mostly repetitions
    round_df = round_df[round_df['status']=='demo_tests_generated']  # rounds are saved for different stages of the round
    round_df = round_df.drop_duplicates(subset=['group_id', 'domain', 'kc_id', 'round_num'])
    ########

    group_df = excel_file.parse('group')
    group_df['group_id'] = group_df['id'].copy()
    
    group_df['group_id'] = group_df['group_id'].fillna(-1)  # Handle any NaN values first
    group_df['group_id'] = group_df['group_id'].astype(int).astype(str)
    group_df.loc[group_df['group_id'] == '-1', 'group_id'] = ''
    
    group_df.loc[:, 'domain_order'] = group_df.apply(lambda x: 'at-sb' if x['domain_1'] == 'at' else 'sb-at', axis=1)
    #######
    
    group_conditions = group_df[['group_id', 'experimental_condition', 'domain_order']].copy()


    # ###############################
    ## 3. Process additional trial measures
    print('Processing additional trial data....', flush=True)
    
    trial_df = trial_df.merge(round_df[['group_id', 'round', 'domain', 'kc_id']], on=['group_id', 'domain', 'round'], how='left')

    trial_df['domain_name'] = trial_df['domain'].copy()

    # Add reward_ft_weights to all trials in domain
    trial_df = trial_df.merge(
        domain_df[['user_id', 'group_id', 'domain_name', 'reward_ft_weights']],
        on=['user_id', 'group_id', 'domain_name'],
        how='left'
    )

    trial_df = trial_df.drop_duplicates(subset=['user_id', 'group_id', 'domain_name', 'round', 'iteration'])


    # ## Process and add Regret metrics to trial data
    
    # Process and save regret data
    trial_df_with_metrics_05_15 = pd.read_excel('../results/trial_df_with_metrics_05_15.xlsx')
    trial_df_with_metrics = add_trial_regret_metrics(trial_df, trial_df_with_metrics_05_15)
    trial_df_with_metrics.to_excel(f"../results/trial_rewards_merged_{file_prefix}")
    
    # load processed regret data
    trial_df_with_metrics = pd.read_excel(f"../results/trial_rewards_merged_{file_prefix}")
    
    trial_df = trial_df.merge(
        trial_df_with_metrics[['user_id', 'group_id', 'domain', 'round', 'iteration', 'interaction_type', 'opt_reward_gt_mdp',	
                              'human_reward_gt_mdp', 'opt_reward_est_mdp', 'human_reward_est_mdp', 'traj_regret_norm', 'est_regret_norm',
                              'sign_agreement', 'phi_opt', 'phi_human', 'phi_est', 'est_traj']],
        on=['user_id', 'group_id', 'domain', 'round', 'iteration', 'interaction_type'],
        how='left'
    )
    print('Trial df len after adding metrics:', len(trial_df))
    

    
    
    
    

    def extract_float_mixed(x):
        try:
            # Case 1: string that looks like a list (e.g., "[[-2.755]]")
            if isinstance(x, str):
                x = ast.literal_eval(x)

            # Case 2: already float
            if isinstance(x, (float, int)):
                return float(x)

            # Case 3: list or nested list
            while isinstance(x, list) and len(x) > 0:
                x = x[0]
            if isinstance(x, (float, int)):
                return float(x)
        except Exception:
            pass
        return None

    
    columns_to_fix = ['opt_reward_gt_mdp', 'human_reward_gt_mdp', 'opt_reward_est_mdp', 'human_reward_est_mdp', 'traj_regret_norm', 'est_regret_norm']

    for col in columns_to_fix:
        trial_df[col] = trial_df[col].apply(extract_float_mixed)


    trial_df.to_excel(f"../results/trial_df_with_metrics_{file_prefix}.xlsx", index=False)
    
    # Load processed data
    trial_df.to_excel(f"../results/trial_rewards_merged_{file_prefix}")
    

    #####################################   

    # ## 4. Process Round data by kc_id
    # print('Procesing round data...', flush=True)
    round_df_w_metrics = process_round_data(round_df, trial_df, user_df)


    round_df_w_metrics = round_df_w_metrics.merge(
        group_conditions,
        on='group_id',
        how='left'
    )
    
    # save processed round data
    round_df_w_metrics.to_excel(f"../results/round_{file_prefix}", index=False)
    
    # read already processed round data
    # round_df_w_metrics = pd.read_excel('../results/round_df_w_metrics.xlsx')

    # #####################################

    ## 5. Process domain dataset - attention, usability, and understanding
    print('Processing domain metrics....', flush=True)
    
    domain_df_w_metrics = process_domain_metrics(domain_df, group_df, trial_df)
    
    print("domain_df_w_metrics columns:", domain_df_w_metrics.columns.tolist())
    print("group_conditions columns:", group_conditions.columns.tolist())

    domain_df_w_metrics = domain_df_w_metrics.merge(
        group_conditions,
        on='group_id',
        how='left'
    )
    
    domain_df_w_metrics.to_excel(f"../results/domain_metrics_{file_prefix}", index=False)

    # #####################################

    # ## 6. Process diagnostic data (diagnostic test performance)
    print('Processing diagnostic data...', flush=True)
    process_diagnostic_data(trial_df_with_metrics, group_df)

    # ####################################

    # ## 7. Process final tests
    # print('Processing final tests...', flush=True)
    process_final_tests(trial_df_with_metrics, group_df, valid_user_ids)

    ####################################.
    

    ## 8. Process learning metrics
    merged_domain_df = add_learning_metrics(domain_df_w_metrics, round_df_w_metrics)
    merged_domain_df.to_excel('../results/domain_df_w_learning_metrics_05_15.xlsx', index=False)


################################################################# 

process_bf_data('../results/output_full_data_06_04.xlsx')
