# %% [markdown]
# ## Process database files

# %%
## Setup
import sqlite3
from typing import List, Dict
import os, sys
import dill as pickle
from pathlib import Path
from datetime import datetime
import ast
import copy



import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import array
import seaborn as sns

import logging
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger()


# Add the directory where 'app/' lives to sys.path
root_path = Path.cwd().resolve()
if str(root_path) not in sys.path:
    sys.path.insert(0, str(root_path))

logger.info(f"Added to sys.path:  {root_path}")
logger.info(f"sys.path[-1]: {sys.path[-1]}")

try:
    from app.group_teaching.codes.simple_rl.utils import mdp_helpers
    from app.group_teaching.codes.simple_rl.planning import ValueIteration
    from app.group_teaching.codes.simple_rl.utils.make_mdp import make_custom_mdp
    from app.group_teaching.codes.policy_summarization.BEC_helpers import calc_solid_angles
    logger.info("Imported simple_rl successfully")
except Exception as e:
    logger.info(f"Failed to import simple_rl: {e}")

logger.info(f"Functions in mdp_helpers: {dir(mdp_helpers)}")
# Out:
# Added to sys.path:  /home/sureshkj/Projects/flask_closed_loop_teaching/simple_game_test
# sys.path[-1]: /home/sureshkj/.ipython
# Loaded packages....
# Db, migrate, login initialized....
# Socketio initialized....
# Models loaded....
# Routes: Loaded flask apps...
# Routes: Loaded "App"...
# Routes: Loaded python apps...
# /home/sureshkj/anaconda3/envs/aug_taxi/lib/python3.9/site-packages/tensorflow/python/framework/dtypes.py:246: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
# ...
# Routes: Loaded group teaching apps...
# Global db lock:  <unlocked _thread.lock object at 0x7e929b1a5cf0>
# Routes loaded....
# Migrate initialized....
# Login initialized....
# Using 24 processes
# Lock initialized....
# Conditions initialized....
# Groups initialized....
# Db committed....
# Imported simple_rl successfully
# ...

# %%
## Combine all the different sql databases and filter only valid user data

def find_valid_user_and_group_ids(conn, user_table_name='user', group_table_name='group'):
    
    cursor = conn.cursor()
    
    
    try:
        user_df = read_table_with_pickle_handling(cursor, user_table_name)
        group_df = read_table_with_pickle_handling(cursor, group_table_name)
    except Exception as e:
        print(f"Failed to read '{user_table_name}': {e}")
        print(f"Failed to read '{group_table_name}': {e}")
        return [], []
    
#     print('User df: ', user_df)
#     print('Group df: ', group_df)

    group_col = 'group'
    # process user df
    user_df['group_id'] = user_df.get(group_col, pd.Series([-1]*len(user_df))).copy()
    user_df['group_id'] = user_df['group_id'].fillna(-1).astype(int).astype(str)
    user_df.loc[user_df['group_id'] == '-1', 'group_id'] = ''

    user_df['id'] = user_df['id'].fillna(-1).astype(int).astype(str)
    user_df.loc[user_df['id'] == '-1', 'id'] = ''
    


    username_col = next((col for col in ['username'] if col in user_df.columns), None)
    if username_col:
        print("Filtering user ids for ", username_col)
        user_df[username_col] = user_df[username_col].astype(str)
        print("User df len before: ", len(user_df))
        print(user_df[username_col].str.len())
        filtered_users = user_df[user_df[username_col].str.len() > 15].copy()
        print("User df len after: ", len(filtered_users))
    else:
        filtered_users = user_df.copy()

    if 'curr_progress_time' in filtered_users.columns:
        print("Filtering rounds after 2025-04-01")
        filtered_users['curr_progress_time'] = pd.to_datetime(
            filtered_users['curr_progress_time'], errors='coerce'
        )
        print("User df len before: ", len(filtered_users))
        filtered_users = filtered_users[filtered_users['curr_progress_time'] >= pd.Timestamp('2025-04-01')]
        print("User df len after: ", len(filtered_users))


    valid_user_ids = filtered_users['id'].astype(str).tolist()
    print('valid_user_ids: ', valid_user_ids)
    
    print(group_df['member_user_ids'])
    # get valid group ids
    valid_group_ids = []
    for _, row in group_df.iterrows():
        
        print(row['member_user_ids'])
        if row['member_user_ids'] is not None:
            all_user_in_group_valid = True
            for member in row['member_user_ids']:
                if str(member) not in valid_user_ids:
                    all_user_in_group_valid = False
                    break
        else:
            all_user_in_group_valid = False
            
        if all_user_in_group_valid:
            valid_group_ids.append(str(row['id']))
        
    
    print("valid_group_ids: ", valid_group_ids)



    return list(set(valid_user_ids)), list(set(valid_group_ids))



def merge_sqlite_dbs(db_paths: List[str], output_path: str = "merged_valid.sqlite"):
    
    if len(db_paths) < 1:
        raise ValueError("Provide at least one database path.")

    output_conn = sqlite3.connect(output_path)
    group_suffix = len(db_paths)
    for db_path in db_paths:
        
        conn = sqlite3.connect(db_path)

        print(f"\n Processing DB: {db_path}")
        table_names = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)['name'].tolist()
        print('Db: ', db_path, 'Table names: ', table_names)
        
        #
        valid_users, valid_groups = find_valid_user_and_group_ids(conn)

        if not valid_groups:
            print(f" No valid users/groups found in {db_path}, skipping this DB.")
            conn.close()
            continue

        print("Valid groups:", valid_groups)
        print("Valid users:", valid_users)

        for table in table_names:
            if table != 'group':
                try:
                    df = pd.read_sql(f"SELECT * FROM {table}", conn)
                    print(f" Read table '{table}'")
                except Exception as e:
                    print(f" Could not read table '{table}': {e}", flush=True)
                    continue
            else:
                try:
                    df = pd.read_sql(f'SELECT * FROM "{table}"', conn)
                    print(f" Read table '{table}'")
                except Exception as e:
                    print(f" Could not read table '{table}': {e}", flush=True)
                    continue
            
            # Filter by group if such column exists
            group_col = next((col for col in ['group', 'group_id'] if col in df.columns), None)
            if group_col:
                print(f"Filtering table {table} with column {group_col}")
                df[group_col] = pd.to_numeric(df[group_col], errors='coerce')  # turns 'nan', 'inf', etc. into np.nan
                df[group_col] = df[group_col].fillna('').apply(lambda x: str(int(x)) if x != '' else '')

                # print('Groups list:', df[group_col].unique())
                print("Len df before valid group filtering: ", len(df))
                df = df[df[group_col].isin(valid_groups)]
                print("Len df after valid group filtering: ", len(df))

            elif table == 'group':
                print(f"Filtering table {table} with column id")
                df['id'] = pd.to_numeric(df['id'], errors='coerce')  # turns 'nan', 'inf', etc. into np.nan
                df['id'] = df['id'].fillna('').apply(lambda x: str(int(x)) if x != '' else '')

                # print('Groups list:', df['id'].unique())
                print("Len df before valid group filtering: ", len(df))
                df = df[df['id'].isin(valid_groups)]
                print("Len df after valid group filtering: ", len(df))


            # --- Apply group_id modifier across all relevant fields ---
            for col in df.columns:
                if col in ['group', 'group_id', 'user_id'] or (table == 'group' and col=='id') or (table == 'user' and col=='id'):
                    print('Table:', table, 'Column:', col)
                    df[col] = df[col].apply(lambda x: f"{x}_{group_suffix}" if x else '')
                        
            
            
            print('Length of df: ', len(df))

            if df.empty:
                continue

            # Align columns with existing (if exists)
            try:
                existing = pd.read_sql(f'SELECT * FROM "{table}" LIMIT 0', output_conn)
                print(f" Read existing table '{table}'")
                df = df[[col for col in df.columns if col in existing.columns]]
            except:
                pass

            df.to_sql(table, output_conn, if_exists='append', index=False)
            print(f" Appended {len(df)} rows to table '{table}'", flush=True)


        group_suffix -= 1

        conn.close()

    output_conn.close()
    print(f"\n Merged database created at: {output_path}", flush=True)

######################################

## Convert db files to excel for easy viz and quick debugs


def print_table_data(database_file):
    try:
        
        print("Database file exists:", os.path.exists(database_file))

        
        # Connect to the database
        conn = sqlite3.connect(database_file)
        cursor = conn.cursor()

        # Fetch all table names
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        # cursor.execute("SELECT * FROM [group]")   # Since group is a reserved keyword, you need to escape it in queries.
        # cursor.execute("SELECT * FROM [1]")  


        tables = cursor.fetchall()

        if not tables:
            print("No tables found in the database.")
            return

        # Iterate through each table and print its data
        for table in tables:
            table_name = table[0]
            print(f"\nTable: {table_name}")
            cursor.execute(f"SELECT * FROM [{table_name}]")
            rows = cursor.fetchall()

            # Fetch column names
            column_names = [description[0] for description in cursor.description]
            print(" | ".join(column_names))  # Print column headers


    except sqlite3.Error as e:
        print(f"Database error: {e}")
    except Exception as e:
        print(f"Unexpected error: {e}")
    finally:
        # Close the database connection
        if conn:
            conn.close()


            
def read_table_with_pickle_handling(cursor, table_name):
    """Read a table and deserialize any pickled byte columns."""
    cursor.execute(f'SELECT * FROM [{table_name}]')
    rows = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]

    processed_rows = []
    for row in rows:
        processed_row = []
        for value in row:
            if isinstance(value, bytes):
                try:
                    processed_value = pickle.loads(value)
                except (pickle.UnpicklingError, EOFError, AttributeError):
                    processed_value = value
            else:
                processed_value = value
            processed_row.append(processed_value)
        processed_rows.append(processed_row)

    df = pd.DataFrame(processed_rows, columns=columns)
    return df



def convert_db_to_dataframes(database_file: str) -> Dict[str, pd.DataFrame]:
    """Return a dictionary of table_name -> DataFrame for all tables in the database."""
    dataframes = {}
    try:
        conn = sqlite3.connect(database_file)
        cursor = conn.cursor()

        # Get all table names
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()

        if not tables:
            print("No tables found in the database.")
            return dataframes

        for table in tables:
            table_name = table[0]
            print(f"Reading table: {table_name}")
            try:
                df = read_table_with_pickle_handling(cursor, table_name)
                dataframes[table_name] = df
            except Exception as e:
                print(f"Failed to read table '{table_name}': {e}")
    except Exception as e:
        print(f"Error reading database: {e}")
    finally:
        conn.close()
    
    return dataframes



def convert_db_to_excel(database_file: str, output_excel_file: str, save_pickles: bool = False):
    """Convert a database to an Excel file, optionally saving tables as pickles."""
    dataframes = convert_db_to_dataframes(database_file)

    if not dataframes:
        print("No valid dataframes to write.")
        return

    os.makedirs(os.path.dirname(output_excel_file), exist_ok=True)

    with pd.ExcelWriter(output_excel_file, engine='openpyxl') as writer:
        for table_name, df in dataframes.items():
            print(f"Exporting table: {table_name} | Rows: {len(df)}")
            df.to_excel(writer, sheet_name=table_name[:31], index=False)  # Excel sheet name max length = 31
            if save_pickles:
                df.to_pickle(f"{table_name}.pkl")
    
    
    
    print(f"Exported database to Excel: {output_excel_file}")

#################################################################

databases = ['../data/app_db_bf_07_07_p1.db', '../data/app_db_bf_04_17_1.db']

merge_sqlite_dbs(databases, output_path='../data/full_data_07_07.db')

# Replace 'app.db' with your database file and 'output.xlsx' with the desired Excel file name
convert_db_to_excel('../data/full_data_07_07.db', '../results/output_full_data_07_07.xlsx')

# %%
def rollout_policy_recursive_2(mdp, agent, cur_state, trajs, cur_traj=[], cur_action_seq=[], max_depth=25, max_num_of_trajs=np.inf,  visited_states=None, max_repeats=4):
    # cap the maximum number of recursive trajectories that'll be returned (can be unreasonable to enumerate all
    # equally rewarding trajectories sometimes)
    
    if visited_states is None:
        visited_states = {}

    state_key = str(cur_state)

    visited_states[state_key] = visited_states.get(state_key, 0) + 1
    
    if visited_states[state_key] > max_repeats:
        # print(f"State {cur_state} visited too often. Aborting this branch.")
        return
    
    if len(trajs) > max_num_of_trajs:
        # print("Max number of trajectories reached.")
        return

    if cur_state.is_terminal() or len(cur_traj) >= max_depth:
        # print("Terminal state reached or max depth reached.")
        trajs.append(cur_traj)
        return

    # print('Getting maxq actions for state: {}'.format(cur_state))
    maxq_actions = agent.get_max_q_actions(cur_state)
    took_step = False
    for action in maxq_actions:
        # print('cur action seq: {}'.format(cur_action_seq))
        # print('maxq actions: {}'.format(maxq_actions))
        # print('action: {}'.format(action))

        # mdp has a memory of its current state that needs to be adjusted accordingly
        mdp.set_curr_state(cur_state)

        # deepcopy of state occurs within transition function
        reward, next_state = mdp.execute_agent_action(action)

        if next_state != cur_state:
            took_step = True
            next_traj = cur_traj.copy()
            next_traj.append((cur_state, action, next_state))
            next_action_seq = cur_action_seq.copy() # for debugging
            next_action_seq.append(action)

            rollout_policy_recursive_2(mdp, agent, next_state, trajs, cur_traj=next_traj, cur_action_seq=next_action_seq, visited_states=visited_states)

        if not took_step:
            print('No actions available for state: {}'.format(cur_state))

    return trajs

# %%
import os
import pickle

# Choose domain
domain = 'sb'  # or 'at'
mdp_class = 'augmented_taxi2' if domain == 'at' else 'skateboard2'

# Iterate through all 64 environments
for idx in range(64):
    filename = f"./app/group_teaching/models/{mdp_class}/gt_policies/wt_vi_traj_params_env{str(idx).zfill(5)}.pickle"
    if not os.path.exists(filename):
        print(f"Missing file for env {idx}")
        continue
    try:
        with open(filename, 'rb') as f:
            data = pickle.load(f)
            mdp_dict = data[0][3]
            print(f"env_idx: {idx:02d} | mdp_dict: {mdp_dict}")
    except Exception as e:
        print(f"Error reading {filename}: {e}")

# %%
import os
import pickle
import ast
import numpy as np
import pandas as pd

# Assuming these are external classes/functions from your environment
# If they are part of your project, ensure their definitions are accessible.
# from your_module import ValueIteration, rollout_policy_recursive_2, make_custom_mdp, calc_solid_angles

domain_map = {
    'at': 'augmented_taxi2',
    'sb': 'skateboard2'
}

def match_by_common_keys(dict1, dict2):
    """
    Compares two dictionaries for equality of values associated with common keys.

    Args:
        dict1 (dict): The first dictionary.
        dict2 (dict): The second dictionary.

    Returns:
        bool: True if all common keys have matching values, False otherwise.
    """
    common_keys = set(dict1.keys()) & set(dict2.keys())
    # print(f"Common keys: {common_keys}") # Consider removing or making this a debug print

    for key in common_keys:
        if dict1[key] != dict2[key]:
            return False
    return True


def check_env_files(mdp_class, target_dict):
    """
    Searches through environment pickle files for a dictionary that matches
    a target dictionary based on common keys.

    Args:
        mdp_class (str): The MDP class (e.g., 'augmented_taxi2', 'skateboard2').
        target_dict (dict): The dictionary to match against.

    Returns:
        int or None: The index of the matching environment file, or None if no match is found.
    """
    print(f"Checking for matching environment files for {mdp_class}...")

    base_path = f"./app/group_teaching/models/{mdp_class}/gt_policies/"
    for idx in range(64):
        file_path = os.path.join(base_path, f"wt_vi_traj_params_env{str(idx).zfill(5)}.pickle")

        if not os.path.exists(file_path):
            continue

        try:
            with open(file_path, 'rb') as f:
                data = pickle.load(f)
                # Assuming data structure: data[0][3] is the dictionary to compare
                candidate_mdp_dict = data[0][3]
                if match_by_common_keys(target_dict, candidate_mdp_dict):
                    print(f"Match found: env_idx = {idx}")
                    return idx
        except Exception as e:
            # Be more specific with exception handling if possible (e.g., FileNotFoundError, pickle.UnpicklingError)
            print(f"Error loading or processing environment file {file_path} at index {idx}: {e}")

    print("No matching environment file found.")
    return None


def normalize_reward_weights(weights):
    """
    Normalizes reward weights. Converts string representation of weights to a numpy array
    and then normalizes the L2 norm of the first row to 1.

    Args:
        weights (list or str): A list of weights or a string representation of a list.

    Returns:
        np.ndarray: The normalized weights.

    Raises:
        ValueError: If weights are not valid or cannot be converted.
    """
    if isinstance(weights, str):
        try:
            weights = ast.literal_eval(weights)
        except (ValueError, SyntaxError) as e:
            raise ValueError(f"Invalid string representation for weights: {weights}. Error: {e}")

    if not isinstance(weights, (list, tuple)) or len(weights) != 3:
        raise ValueError("Weights must be a list or tuple of 3 numerical values.")

    try:
        normalized_weights = np.array([[float(weights[0]), float(weights[1]), float(weights[2])]])
    except ValueError as e:
        raise ValueError(f"Weights must contain numerical values. Error: {e}")

    # Ensure the third element is always -1 as per original logic, if that's the intent.
    # Otherwise, it should be based on the input 'weights' directly.
    # The original code hardcoded -1 for the third element, which might be an intentional design.
    # If not, remove the direct assignment of -1.
    normalized_weights[0, 2] = -1

    norm = np.linalg.norm(normalized_weights[0, :], ord=2)
    if norm == 0:
        return normalized_weights # Avoid division by zero, return as is or raise error
    return normalized_weights / norm


def check_rewards_correct_sign(final_test_data):
    """
    Checks if the sign of the scaled reward feature weights matches
    the ground truth weights for a given domain.

    Args:
        final_test_data (dict): A dictionary containing 'domain' and 'reward_ft_weights'.

    Returns:
        bool: True if signs match, False otherwise.
    """
    sb_gt_weights = np.array([[0.59565914, 0.3519804, -0.72201107]])
    at_gt_weights = np.array([[-0.63599873, 0.74199852, -0.21199958]])

    domain = final_test_data.get('domain')
    if domain == 'at':
        gt_weights = at_gt_weights
    elif domain == 'sb':
        gt_weights = sb_gt_weights
    else:
        # Handle cases where domain is not 'at' or 'sb'
        print(f"Warning: Unknown domain '{domain}'. Cannot check reward sign correctness.")
        return False

    try:
        final_test_data['scaled_reward_ft_weights'] = normalize_reward_weights(
            final_test_data['reward_ft_weights']
        )
    except ValueError as e:
        print(f"Error normalizing reward weights for domain '{domain}': {e}")
        return False

    gt_sign = np.sign(gt_weights)
    return (np.sign(final_test_data['scaled_reward_ft_weights']) == gt_sign).all()


def load_mdp_from_file(domain, env_idx):
    """
    Loads an MDP and agent object from a pickled environment file.

    Args:
        domain (str): The domain ('at' for augmented_taxi2, 'sb' for skateboard2).
        env_idx (int): The environment index.

    Returns:
        tuple: A tuple containing the MDP object and the agent object.

    Raises:
        ValueError: If an unknown domain is provided.
        FileNotFoundError: If the specified pickle file does not exist.
        Exception: For other errors during file loading or unpickling.
    """
    if domain == 'at':
        mdp_class = 'augmented_taxi2'
    elif domain == 'sb':
        mdp_class = 'skateboard2'
    else:
        raise ValueError(f"Unknown domain: {domain}")

    # Use os.path.join for robust path construction
    file_path = os.path.join(
        os.getcwd(),
        "app", "group_teaching", "models", mdp_class, "gt_policies",
        f"wt_vi_traj_params_env{str(env_idx).zfill(5)}.pickle"
    )

    try:
        with open(file_path, 'rb') as f:
            wt_vi_traj_env = pickle.load(f)

        # Assuming the structure wt_vi_traj_env[0][1] contains the agent,
        # and wt_vi_traj_env[0][1].mdp contains the mdp.
        mdp = wt_vi_traj_env[0][1].mdp
        agent = wt_vi_traj_env[0][1]
        return mdp, agent
    except FileNotFoundError:
        raise FileNotFoundError(f"Environment file not found: {file_path}")
    except Exception as e:
        raise Exception(f"Error loading MDP from file '{file_path}': {e}")


def parse_trial_mdp_info(domain, trial_str):
    """
    Parses trial MDP information from a string, extracting environment index,
    optimal moves, and the parsed MDP dictionary.

    Args:
        domain (str): The domain ('at' or 'sb').
        trial_str (str): A string representation of the trial MDP dictionary.

    Returns:
        tuple: (env_idx, opt_moves, trial_mdp_dict). env_idx can be None.
    """
    if domain == 'at':
        mdp_class = 'augmented_taxi2'
    elif domain == 'sb':
        mdp_class = 'skateboard2'
    else:
        raise ValueError(f"Unknown domain: {domain}")

    try:
        trial_mdp_dict = ast.literal_eval(trial_str)
        env_idx = trial_mdp_dict.get('env_traj_idxs', [None])[0]
        opt_moves = trial_mdp_dict.get('opt_actions', [])
        return env_idx, opt_moves, trial_mdp_dict
    except (ValueError, SyntaxError) as e:
        print(f"Warning: Could not parse trial_str '{trial_str}'. Attempting fallback. Error: {e}")
        # Fallback if direct parsing fails, try to find an environment file
        # This part of the original logic seems a bit ambiguous.
        # If the `trial_str` is truly malformed, `ast.literal_eval` will fail again.
        # Re-evaluating `trial_str` within the except block is redundant if it failed once.
        # The original code's commented out section suggests attempting `check_env_files` here,
        # but it was commented out. For clarity, I'll keep the current behavior but note the ambiguity.
        # If `check_env_files` is truly intended as a fallback for missing `env_traj_idxs`,
        # it should be called after successful `ast.literal_eval` but before the return.

        # If trial_str is truly unparseable as a dict, this will likely fail again.
        # Consider a more robust parsing or simply returning defaults if it's consistently malformed.
        try:
            trial_mdp_dict = ast.literal_eval(trial_str)
            opt_moves = trial_mdp_dict.get('opt_actions', [])
            env_idx = check_env_files(mdp_class, trial_mdp_dict) # Call the helper function
            return env_idx, opt_moves, trial_mdp_dict
        except (ValueError, SyntaxError) as e:
            print(f"Failed to parse trial info again: {e}")
            return None, [], {} # Return safe defaults if parsing completely fails


def calc_opt_traj_from_mdp(mdp, current_state, weights):
    """
    Calculates the optimal trajectory and its reward features from an MDP
    using Value Iteration.

    Args:
        mdp (object): The MDP object.
        current_state (object): The initial state for trajectory rollout.
        weights (np.ndarray): The reward weights.

    Returns:
        tuple: (best_human_traj, best_reward_features).
               Returns empty lists if Value Iteration does not converge.
    """
    # Ensure ValueIteration, rollout_policy_recursive_2 are imported or defined
    vi_human = ValueIteration(mdp, sample_rate=1)
    vi_human.run_vi()

    best_reward_features = []
    best_human_traj = []

    if vi_human.stabilized:
        human_opt_trajs = rollout_policy_recursive_2(vi_human.mdp, vi_human, current_state, [], max_num_of_trajs=1)

        current_best_reward = float('-inf')
        for traj in human_opt_trajs:
            # The human and agent should be working with identical MDPs
            mu_sb = mdp.accumulate_reward_features(traj, discount=True)
            reward_hyp = weights.dot(mu_sb.T)
            if reward_hyp > current_best_reward:
                current_best_reward = reward_hyp
                best_reward_features = mu_sb
                best_human_traj = traj
    else:
        print("Value iteration did not converge.") # Log a warning if not stabilized

    return best_human_traj, best_reward_features


def get_traj_from_mdp(mdp, current_state, moves_list, weights=None):
    """
    Generates a trajectory by executing a sequence of moves in an MDP.

    Args:
        mdp (object): The MDP object.
        current_state (object): The initial state.
        moves_list (list): A list of actions to execute.
        weights (np.ndarray, optional): Reward weights to set on the MDP. Defaults to None.

    Returns:
        list: The generated trajectory, a list of (state, action, next_state) tuples.
    """
    if weights is not None:
        mdp.weights = weights

    trajectory = []
    for move in moves_list:
        # Assumes that the user study only allows actions that change the state of the MDP
        # and that mdp.execute_agent_action updates the internal state of mdp.
        reward, next_state = mdp.execute_agent_action(move)
        trajectory.append((current_state, move, next_state))
        current_state = next_state # Update current_state for the next iteration

    return trajectory


def calculate_regret_metrics(trial_data):
    """
    Calculates regret metrics for a given trial, comparing human and optimal trajectories
    under ground truth MDP.

    Args:
        trial_data (dict): A dictionary containing trial-specific information.

    Returns:
        dict: A dictionary of calculated regret metrics.
    """
    domain = trial_data['domain']

    # Define ground truth weights
    gt_weights_map = {
        'at': np.array([[-0.63599873, 0.74199852, -0.21199958]]),
        'sb': np.array([[0.59565914, 0.3519804, -0.72201107]])
    }

    gt_weights = gt_weights_map.get(domain)
    if gt_weights is None:
        raise ValueError(f"Unknown domain for ground truth weights: {domain}")

    # Parse trial MDP info and moves
    env_idx, opt_moves, trial_mdp_dict = parse_trial_mdp_info(domain, trial_data['mdp_parameters'])
    human_moves = ast.literal_eval(trial_data['moves'])
    # human_est_weights = normalize_reward_weights(trial_data['reward_ft_weights']) # Not used in final return, so commented out

    # Make custom MDP (assuming make_custom_mdp handles different classes)
    trial_mdp_dict['weights'] = gt_weights # Set weights for MDP creation
    mdp = make_custom_mdp(domain_map.get(domain), trial_mdp_dict) # Use a clearer domain map

    current_state = mdp.get_init_state()

    # Get optimal and human trajectories under ground truth MDP
    opt_traj = get_traj_from_mdp(mdp, current_state, opt_moves, weights=gt_weights)
    mdp.reset() # Reset MDP state for the next trajectory calculation
    human_traj = get_traj_from_mdp(mdp, current_state, human_moves, weights=gt_weights)
    mdp.reset()

    # Feature counts
    phi_opt = mdp.accumulate_reward_features(opt_traj, discount=True)
    mdp.reset()
    phi_human = mdp.accumulate_reward_features(human_traj, discount=True)
    mdp.reset()

    # Rewards
    human_reward_gt_mdp = gt_weights.dot(phi_human.T)
    opt_reward_gt_mdp = gt_weights.dot(phi_opt.T)

    # Regret metrics
    # Added a small epsilon to the denominator to prevent DivisionByZeroError if opt_reward_gt_mdp is 0
    traj_regret_norm = (opt_reward_gt_mdp - human_reward_gt_mdp) / (opt_reward_gt_mdp + 1e-6)

    return {
        "opt_reward_gt_mdp": opt_reward_gt_mdp,
        "human_reward_gt_mdp": human_reward_gt_mdp,
        "traj_regret_norm": traj_regret_norm
    }


def is_valid_weights(val):
    """
    Checks if a given value represents valid weights.

    Args:
        val: The value to check.

    Returns:
        bool: True if valid, False otherwise.
    """
    if val is None:
        return False
    if isinstance(val, float) and np.isnan(val):
        return False
    # This assumes that if it has a length, it should be greater than 0.
    # It might be more robust to check for specific types like list or numpy array.
    if hasattr(val, '__len__'):
        return len(val) > 0
    return False


def add_trial_regret_metrics(trial_df, existing_data=None):
    """
    Adds regret metrics to a DataFrame of trial data.

    Args:
        trial_df (pd.DataFrame): DataFrame containing trial data.
        existing_data (pd.DataFrame, optional): DataFrame of already processed data
                                               to avoid re-calculation. Defaults to None.

    Returns:
        pd.DataFrame: The trial DataFrame with added regret metrics.
    """
    print('Adding trial regret metrics...')

    enriched_rows = []

    # Compile regret data
    for idx, row in trial_df.iterrows():
        user_existing = None
        
        print('Regret for user: ', row['user_id'], ' ', row['domain'], ' ', row['round'], ' ', 
              row['iteration'], '. Valid weights? ', is_valid_weights(row['reward_ft_weights']))

        if is_valid_weights(row['reward_ft_weights']):
            # Check if regret is already processed for user+domain+round+iteration
            user_id = row['user_id']
            domain = row['domain']
            round_id = row['round']
            iteration = row['iteration']

            if existing_data is not None:
                user_existing_match = existing_data[
                    (existing_data['user_id'] == user_id) &
                    (existing_data['domain'] == domain) &
                    (existing_data['round'] == round_id) &
                    (existing_data['iteration'] == iteration)
                ]
                if not user_existing_match.empty:
                    user_existing = user_existing_match.iloc[0].to_dict()

            if user_existing is None:
                # Calculate regret if not already existing
                try:
                    regret = calculate_regret_metrics(row)

                    regret_flat = {
                        k: (
                            regret[k].tolist()
                            if isinstance(regret[k], np.ndarray)
                            else regret[k]
                        )
                        for k in regret
                    }
                    
                    print('regret_flat:', regret_flat)
                    
                    enriched_row = {**row.to_dict(), **regret_flat}
                    enriched_rows.append(enriched_row)
                except Exception as e:
                    print(f"Error calculating regret for trial {idx} (User: {user_id}, Domain: {domain}, Round: {round_id}, Iteration: {iteration}): {e}")
                    # If error, append the original row without regret metrics
                    enriched_rows.append(row.to_dict())
            else:
                # If existing data found, use it
                enriched_rows.append(user_existing)
        else:
            # If weights are not valid, append original row without regret metrics
            enriched_rows.append(row.to_dict())

    return pd.DataFrame(enriched_rows)


def process_domain_metrics(domain_df, group_df, trial_df_w_metrics):
    """
    Processes and consolidates domain-level metrics, including survey data and
    final test correctness by difficulty.

    Args:
        domain_df (pd.DataFrame): DataFrame with raw domain survey data.
        group_df (pd.DataFrame): DataFrame with group information (not directly used in this snippet's output, but might be for other merges).
        trial_df_w_metrics (pd.DataFrame): DataFrame of trial data including regret metrics.

    Returns:
        pd.DataFrame: Merged DataFrame with consolidated domain metrics.
    """
    # Filter for final tests
    final_tests_df = trial_df_w_metrics[trial_df_w_metrics['interaction_type'] == 'final test'].copy()

    # Assign difficulty levels
    difficulty_conditions = [
        (final_tests_df['iteration'] <= 2),
        (final_tests_df['iteration'] >= 3) & (final_tests_df['iteration'] <= 4),
        (final_tests_df['iteration'] >= 5)
    ]
    final_tests_df['difficulty_level'] = np.select(
        difficulty_conditions,
        ['easy', 'medium', 'hard'],
        default='unknown'
    )

    # Compute difficulty-wise correctness
    summary = final_tests_df.groupby(['user_id', 'domain', 'difficulty_level'])['is_opt_response'].agg(
        total='count', correct='sum'
    ).reset_index()

    pivot_df = summary.pivot(index=['user_id', 'domain'], columns='difficulty_level', values=['total', 'correct'])
    pivot_df.columns = [f"{lvl}_{stat}" for stat, lvl in pivot_df.columns]
    pivot_df = pivot_df.reset_index()

    # Get unique domain entries by user_id and domain_name
    unique_domain_df = domain_df.drop_duplicates(subset=['user_id', 'domain_name']).copy()

    # Create long format dataframe for domain metrics
    domain_metrics_list = []

    for _, row in unique_domain_df.iterrows():
        domain_name = row.get('domain_name')
        user_id = row.get('user_id')
        group_id = row.get('group_id') # Ensure group_id is available in domain_df if needed

        # Calculate average attention and use
        attn_cols = ['attn1', 'attn2', 'attn3']
        use_cols = ['use1', 'use2', 'use3']

        attn_values = [row[col] for col in attn_cols if col in row and pd.notnull(row[col])]
        avg_attn = sum(attn_values) / len(attn_values) if attn_values else np.nan

        use_values = [row[col] for col in use_cols if col in row and pd.notnull(row[col])]
        avg_use = sum(use_values) / len(use_values) if use_values else np.nan

        # Process final tests for the current domain and user
        domain_tests = final_tests_df[(final_tests_df['user_id'] == user_id) & (final_tests_df['domain'] == domain_name)]

        total_tests = len(domain_tests)
        correct_tests = domain_tests['is_opt_response'].sum() if 'is_opt_response' in domain_tests.columns else 0

        # Calculate average regret norms for final tests
        avg_traj_regret_norm_final = trial_df_w_metrics[
            (trial_df_w_metrics['user_id'] == user_id) &
            (trial_df_w_metrics['group_id'] == group_id) &
            (trial_df_w_metrics['domain'] == domain_name) &
            (trial_df_w_metrics['interaction_type'] == 'final test')
        ]['traj_regret_norm'].mean()

        avg_traj_regret_norm_diagnostic = trial_df_w_metrics[
            (trial_df_w_metrics['user_id'] == user_id) &
            (trial_df_w_metrics['group_id'] == group_id) &
            (trial_df_w_metrics['domain'] == domain_name) &
            (trial_df_w_metrics['interaction_type'] == 'diagnostic test')
        ]['traj_regret_norm'].mean()

        domain_metrics_list.append({
            'user_id': user_id,
            'domain_name': domain_name,
            'avg_attn': avg_attn,
            'avg_use': avg_use,
            'N_correct_final_tests': correct_tests,
            'avg_traj_regret_norm_final': avg_traj_regret_norm_final,
            'avg_traj_regret_norm_diagnostic': avg_traj_regret_norm_diagnostic
        })

    domain_metrics_df = pd.DataFrame(domain_metrics_list)

    # Merge base metrics
    merged_df = unique_domain_df.merge(
        domain_metrics_df, on=['user_id', 'domain_name'], how='left'
    )

    # Merge difficulty-wise test stats
    merged_df = merged_df.merge(
        pivot_df, left_on=['user_id', 'domain_name'], right_on=['user_id', 'domain'], how='left'
    )
    # Drop the redundant 'domain' column created by the merge
    merged_df.drop(columns='domain', inplace=True)

    return merged_df


def process_final_tests(trial_df, domain_df_w_metrics):
    """
    Processes final test data, assigns difficulty levels, and merges correctness
    metrics with the domain-level DataFrame.

    Args:
        trial_df (pd.DataFrame): The DataFrame containing all trial data.
        domain_df_w_metrics (pd.DataFrame): The domain-level DataFrame with existing metrics.

    Returns:
        pd.DataFrame: The domain-level DataFrame enriched with final test correctness by difficulty.
    """
    final_tests_df = trial_df[trial_df['interaction_type'] == 'final test'].copy()

    # Map iterations to difficulty levels: 1-2 easy, 3-4 medium, 5-6 hard
    conditions = [
        (final_tests_df['iteration'] <= 2),
        (final_tests_df['iteration'] >= 3) & (final_tests_df['iteration'] <= 4),
        (final_tests_df['iteration'] >= 5) & (final_tests_df['iteration'] <= 6)
    ]
    choices = ['easy', 'medium', 'hard']
    final_tests_df['difficulty_level'] = np.select(conditions, choices, default='unknown')

    print(f"Assigned difficulty levels based on iteration values: "
          f"{final_tests_df['difficulty_level'].value_counts().to_dict()}")

    # Compute correctness by difficulty level
    summary = final_tests_df.groupby(['user_id', 'domain', 'difficulty_level'])['is_opt_response'].agg(
        total='count', correct='sum'
    ).reset_index()

    # Pivot to wide format for merging
    pivot_df = summary.pivot(index=['user_id', 'domain'], columns='difficulty_level', values=['total', 'correct'])
    pivot_df.columns = [f"{lvl}_{stat}" for stat, lvl in pivot_df.columns]
    pivot_df = pivot_df.reset_index()

    # Merge with domain_df
    domain_df_merged = domain_df_w_metrics.merge(
        pivot_df,
        left_on=['user_id', 'domain_name'],
        right_on=['user_id', 'domain'],
        how='left'
    )
    domain_df_merged.drop(columns='domain', inplace=True) # Drop duplicate merge key

    return domain_df_merged


def process_round_data(round_df, trial_df_w_metrics, user_df):
    """
    Processes round-level data, extracting information about demos, tests,
    constraints, and learning metrics per round.

    Args:
        round_df (pd.DataFrame): DataFrame containing raw round data.
        trial_df_w_metrics (pd.DataFrame): DataFrame of trial data with metrics.
        user_df (pd.DataFrame): DataFrame with user information, including group_id.

    Returns:
        pd.DataFrame: The round DataFrame enriched with calculated metrics.
    """
    # Remove 'final_tests_generated' status rounds
    round_df_filtered = round_df[round_df['status'] != 'final_tests_generated'].copy()
    round_metrics = round_df_filtered.drop_duplicates(subset=['group_id', 'domain', 'round_num']).copy()
    

    # Helper functions for parsing and flattening
    def _extract_counts(round_info):
        """Extracts counts of demos and diagnostic tests from round_info."""
        if isinstance(round_info, str):
            try:
                interactions = ast.literal_eval(round_info)
            except (ValueError, SyntaxError):
                return 0, 0
        elif isinstance(round_info, list):
            interactions = round_info
        else:
            return 0, 0

        num_demos = sum(1 for entry in interactions if entry.get('interaction type') == 'demo')
        num_tests = sum(1 for entry in interactions if entry.get('interaction type') == 'diagnostic test')
        return num_demos, num_tests

    def _is_valid_constraint(c):
        """Checks if a constraint list is valid (not None or empty/all None)."""
        if c is None:
            return False
        # Flatten and check if any element is not None
        flat_list = []
        for item in c:
            if isinstance(item, list):
                for sub_item in item:
                    flat_list.append(sub_item)
            else:
                flat_list.append(item)
        return any(x is not None for x in flat_list)

    def _flatten_one_more_level(nested_list):
        """Flattens a list of lists one level deeper if sub-elements are also lists."""
        flattened = []
        for item in nested_list:
            if isinstance(item, list) and all(isinstance(sub, list) for sub in item):
                flattened.extend(item)
            else:
                flattened.append(item)
        return flattened

    def _extract_constraints(round_info):
        """Extracts and flattens demo and test constraints from round_info."""
        if isinstance(round_info, str):
            try:
                interactions = ast.literal_eval(round_info)
            except (ValueError, SyntaxError):
                return [], []
        elif isinstance(round_info, list):
            interactions = round_info
        else:
            return [], []

        demo_constraints = [entry['params'].get('constraints') for entry in interactions if entry.get('interaction type') == 'demo']
        test_constraints = [entry['params'].get('constraints') for entry in interactions if entry.get('interaction type') == 'diagnostic test']

        # Filter out None and empty lists, then flatten
        demo_constraints_cleaned = [c for c in demo_constraints if _is_valid_constraint(c)]
        demo_constraints_flat = _flatten_one_more_level(demo_constraints_cleaned) if demo_constraints_cleaned else []

        test_constraints_cleaned = [c for c in test_constraints if _is_valid_constraint(c)]
        test_constraints_flat = _flatten_one_more_level(test_constraints_cleaned) if test_constraints_cleaned else []

        return demo_constraints_flat, test_constraints_flat

    # Apply the functions to create new columns
    round_metrics[['num_demos', 'num_tests']] = round_metrics['round_info'].apply(
        lambda x: pd.Series(_extract_counts(x))
    )
    round_metrics[['demo_constraints', 'test_constraints']] = round_metrics['round_info'].apply(
        lambda x: pd.Series(_extract_constraints(x))
    )
    print('Number of unique round metrics entries:', len(round_metrics))

    round_learning_metrics = []
    
    print('Unique user df groups: ', user_df['group'].unique())

    # Calculate round metrics for each user in each relevant group/domain/round
    for _, row in round_metrics.iterrows():
        group_id = row['group_id']
        domain = row['domain']
        round_num = row['round_num']
        
        # Get user IDs for the current group
        user_ids = user_df[user_df['group'] == group_id]['id'].tolist()
        
        for user_id in user_ids:
            # Filter trial data for current user, domain, round, and interaction type
            diagnostic_tests = trial_df_w_metrics[
                (trial_df_w_metrics['user_id'] == user_id) &
                (trial_df_w_metrics['domain'] == domain) &
                (trial_df_w_metrics['round'] == round_num) &
                (trial_df_w_metrics['interaction_type'] == 'diagnostic test')
            ]

            demos = trial_df_w_metrics[
                (trial_df_w_metrics['user_id'] == user_id) &
                (trial_df_w_metrics['domain'] == domain) &
                (trial_df_w_metrics['round'] == round_num) &
                (trial_df_w_metrics['interaction_type'] == 'demo')
            ]

            feedback = trial_df_w_metrics[
                (trial_df_w_metrics['user_id'] == user_id) &
                (trial_df_w_metrics['domain'] == domain) &
                (trial_df_w_metrics['round'] == round_num) &
                (trial_df_w_metrics['interaction_type'] == 'diagnostic feedback')
            ]

            N_correct_diagnostic_tests = diagnostic_tests['is_opt_response'].sum()
            num_tests_in_round = row['num_tests'] # Use the counts from round_metrics
            proportion_correct_diagnostic_tests = N_correct_diagnostic_tests / num_tests_in_round if num_tests_in_round > 0 else 0

            # Define 'lesson_learned' based on proportion_correct_diagnostic_tests
            lesson_learned = bool(proportion_correct_diagnostic_tests > 0.98)

            per_util_demos = demos['likert'].mean()
            per_util_tests = diagnostic_tests['likert'].mean()
            per_util_incorrect_tests = diagnostic_tests[diagnostic_tests['is_opt_response'] == 0]['likert'].mean()
            per_util_correct_tests = diagnostic_tests[diagnostic_tests['is_opt_response'] == 1]['likert'].mean()
            per_util_feedback = feedback['likert'].mean()

            # Calculate BEC areas, handling cases where constraints might be empty/invalid
            demo_BEC_area = np.nan
            if _is_valid_constraint(row['demo_constraints']):
                try:
                    # calc_solid_angles expects a list of constraint sets
                    demo_BEC_area = float(calc_solid_angles([row['demo_constraints']])[0])
                except Exception as e:
                    print(f"Error calculating demo_BEC_area for {user_id}, {domain}, round {round_num}: {e}")

            test_BEC_area = np.nan
            if _is_valid_constraint(row['test_constraints']):
                try:
                    test_BEC_area = float(calc_solid_angles([row['test_constraints']])[0])
                except Exception as e:
                    print(f"Error calculating test_BEC_area for {user_id}, {domain}, round {round_num}: {e}")

            avg_traj_regret_norm = diagnostic_tests['traj_regret_norm'].mean()

            round_learning_metrics.append({
                'user_id': user_id,
                'group_id': group_id,
                'domain': domain,
                'round_num': round_num,
                'N_diagnostic_tests': num_tests_in_round,
                'N_correct_diagnostic_tests': N_correct_diagnostic_tests,
                'proportion_correct_diagnostic_tests': proportion_correct_diagnostic_tests,
                'lesson_learned': lesson_learned,
                'demo_BEC_area': demo_BEC_area,
                'test_BEC_area': test_BEC_area,
                'avg_traj_regret_norm': avg_traj_regret_norm,
                'per_util_demos': per_util_demos,
                'per_util_tests': per_util_tests,
                'per_util_incorrect_tests': per_util_incorrect_tests,
                'per_util_correct_tests': per_util_correct_tests,
                'per_util_feedback': per_util_feedback
            })

    round_learning_metrics_df = pd.DataFrame(round_learning_metrics)
    
    print('Size of round learning metrics df: ', round_learning_metrics_df)
    print('Round learning metrics df columns: ', round_learning_metrics_df.columns)
    print('Round metrics df columns: ', round_metrics.columns)


    # Merge with initial round_metrics (which contains num_demos, num_tests etc.)
    round_learning_metrics_df = round_learning_metrics_df.merge(
        round_metrics,
        on=['group_id', 'domain', 'round_num'],
        how='left',
        suffixes=('', '_round_info') # Add suffix to avoid conflicting column names
    )
    return round_learning_metrics_df


def process_kc_data(round_df, domain_df_w_metrics, group_df, user_df):
    """
    Processes Knowledge Component (KC) data, linking rounds to KCs and calculating
    total rounds per group and domain.

    Args:
        round_df (pd.DataFrame): DataFrame containing raw round data.
        domain_df_w_metrics (pd.DataFrame): DataFrame with domain-level metrics.
        group_df (pd.DataFrame): DataFrame with group information.
        user_df (pd.DataFrame): DataFrame with user information.

    Returns:
        pd.DataFrame: The domain-level DataFrame enriched with KC-related total round counts.
    """
    group_conditions = group_df[['group_id', 'experimental_condition', 'domain_order']].copy()

    if 'kc_id' in round_df.columns and 'round_num' in round_df.columns: # Changed 'round' to 'round_num' for consistency
        print('Analyzing rounds by kc_id...')

        # Count the number of unique rounds for each domain-kc_id combination
        kc_round_counts = (round_df
                           .groupby(['group_id', 'domain', 'kc_id'])
                           .size()
                           .reset_index(name='count'))

        # Limit the count to a maximum of 4 (as per original logic)
        kc_round_counts['count'] = kc_round_counts['count'].apply(lambda x: min(x, 4))

        # Merge experimental condition from group_df
        kc_round_counts = kc_round_counts.merge(
            group_conditions,
            on='group_id',
            how='left'
        )
        print(f"Merged experimental conditions with kc_round_counts. Shape: {kc_round_counts.shape}")

        # Save to excel (for debugging/inspection, could be removed in production)
        # kc_round_counts.to_excel('kc_round_counts.xlsx', index=False)

        print('Calculating total rounds taken by each user...')

        # Sum up counts for all KCs to get total rounds per group and domain
        group_domain_rounds = kc_round_counts.groupby(['group_id', 'domain'])['count'].sum().reset_index()
        group_domain_rounds.rename(columns={'count': 'total_rounds'}, inplace=True)
        print(f"Group-domain total rounds shape: {group_domain_rounds.shape}")

        # Merge total rounds with domain_df_w_metrics
        domain_df_w_metrics = domain_df_w_metrics.merge(
            group_domain_rounds,
            on=['group_id', 'domain'], # Ensure 'domain' exists in domain_df_w_metrics for merging
            how='left'
        )
        return domain_df_w_metrics
    else:
        print("Skipping KC data processing: 'kc_id' or 'round_num' column missing in round_df.")
        return domain_df_w_metrics # Return original if KC data is not applicable


def add_learning_metrics(domain_df, round_df):
    """
    Adds learning-related metrics to the domain DataFrame based on round data.
    Analyzes whether KCs were "learned" and if "unlearning" occurred.

    Args:
        domain_df (pd.DataFrame): The domain-level DataFrame.
        round_df (pd.DataFrame): The round-level DataFrame with 'lesson_learned' information.

    Returns:
        pd.DataFrame: The domain DataFrame enriched with KC learning metrics.
    """
    # Ensure domain column is consistent for merging
    round_df['domain_name'] = round_df['domain'].copy()

    # Only keep relevant columns for learning analysis
    lesson_df = round_df[['user_id', 'group_id', 'domain_name', 'kc_id', 'round_num', 'lesson_learned']].copy() # Used round_num

    def analyze_learning(group):
        """Helper function to analyze learning status for a group of KC rounds."""
        group = group.sort_values('round_num') # Sort by round_num
        group = group.head(4)  # Only consider up to 4 rounds

        learned = False
        unlearned = False
        N_rounds = len(group)

        # Check if the KC was learned by the end of the observed rounds
        if not group['lesson_learned'].empty and group['lesson_learned'].iloc[-1] == True:
            learned = True
            # Check for "unlearning" (learned, then didn't learn again)
            first_learned_round = group[group['lesson_learned']].iloc[0]['round_num']
            post_learning_rounds = group[group['round_num'] >= first_learned_round]
            if not post_learning_rounds['lesson_learned'].all():
                unlearned = True

        return pd.Series({
            'learned': learned,
            'unlearned': unlearned,
            'number_rounds': N_rounds
        })

    # Step 1: Analyze learning per KC
    # Using 'round_num' as the grouping key for rounds
    summary = lesson_df.groupby(['user_id', 'group_id', 'domain_name', 'kc_id']).apply(analyze_learning).reset_index()

    # Step 2: Pivot to wide format
    pivoted = summary.pivot(index=['user_id', 'group_id', 'domain_name'],
                            columns='kc_id',
                            values=['learned', 'unlearned', 'number_rounds'])

    # Rename columns for clarity (e.g., KC_0_learned, KC_1_unlearned)
    pivoted.columns = [f"KC_{kc}_{stat}" for stat, kc in pivoted.columns]
    pivoted = pivoted.reset_index()

    # Step 3: Compute domain-level summary
    def compute_overall_flags(row):
        """Computes overall learning flags and total KC rounds for a domain."""
        kc_learned = [row.get(f"KC_{i}_learned") for i in range(3)]
        kc_unlearned = [row.get(f"KC_{i}_unlearned") for i in range(3)]
        kc_rounds = [row.get(f"KC_{i}_number_rounds") for i in range(3)]

        # 'overall_domain_learned' is true if all KCs were learned (and not NaN)
        learned_flags = [val for val in kc_learned if pd.notna(val)]
        overall_learned = int(all(learned_flags) and len(learned_flags) == 3) # Assumes 3 KCs total

        # 'overall_domain_unlearned' is true if any KC showed unlearning (and not NaN)
        unlearned_flags = [val for val in kc_unlearned if pd.notna(val)]
        overall_unlearned = int(any(unlearned_flags))

        total_rounds = sum(val for val in kc_rounds if pd.notna(val))

        return pd.Series({
            'overall_domain_learned': overall_learned,
            'overall_domain_unlearned': overall_unlearned,
            'total_KC_rounds': total_rounds
        })

    overall_flags = pivoted.apply(compute_overall_flags, axis=1)
    pivoted = pd.concat([pivoted, overall_flags], axis=1)

    # Step 4: Merge with domain_df
    merged = pd.merge(domain_df, pivoted, how='left', on=['user_id', 'group_id', 'domain_name'])

    return merged


def compute_domain_order(row):
    """
    Determines the domain order (at-sb or sb-at) based on 'domain_1' column.

    Args:
        row (pd.Series): A row from a DataFrame expected to have 'domain_1'.

    Returns:
        str: The domain order ('at-sb', 'sb-at', or 'unknown').
    """
    domain_1 = row.get('domain_1')
    if domain_1 == 'at':
        return 'at-sb'
    elif domain_1 == 'sb':
        return 'sb-at'
    else:
        return 'unknown'

# %%
# Define file paths and prefixes as constants for easier modification
RESULTS_DIR = '../results/'
OUTPUT_FILENAME_PREFIX = 'metrics_data_'

def _standardize_id_column(df, column_name):
    """
    Helper function to standardize ID columns: fill NaNs, convert to int then str,
    and replace '-1' with an empty string.

    Args:
        df (pd.DataFrame): The DataFrame to modify.
        column_name (str): The name of the column to standardize.

    Returns:
        pd.DataFrame: The DataFrame with the standardized column.
    """
    # Ensure a copy to avoid SettingWithCopyWarning
    df_copy = df.copy()
    df_copy[column_name] = df_copy[column_name].fillna(-1).astype(int).astype(str)
    df_copy.loc[df_copy[column_name] == '-1', column_name] = ''
    return df_copy


def _extract_float_mixed(value):
    """
    Extracts a float from a value that might be a float, int, string representation
    of a float, or a nested list containing a float.

    Args:
        value: The input value to extract a float from.

    Returns:
        float or None: The extracted float, or None if extraction fails.
    """
    try:
        # Case 1: string that looks like a list (e.g., "[[-2.755]]") or a single number string
        if isinstance(value, str):
            value = ast.literal_eval(value)

        # Case 2: already float or int
        if isinstance(value, (float, int)):
            return float(value)

        # Case 3: list or nested list
        # Iterate until a non-list item or an empty list is encountered
        while isinstance(value, list) and len(value) > 0:
            value = value[0]

        if isinstance(value, (float, int)):
            return float(value)
    except (ValueError, SyntaxError):
        # Catch errors from ast.literal_eval or float conversion
        pass
    return None


def process_bf_data(file_path):
    """
    Processes raw Excel data from a specified file path, performing data cleaning,
    merging, and calculation of various metrics.

    Parameters:
    file_path (str): Path to the Excel file containing the data.

    Returns:
    dict: Dictionary containing the processed dataframes (currently not returning,
          but saving to Excel). This part of the docstring should reflect actual behavior.
    """
    print("Running process_bf_data...", flush=True)

    filename = os.path.basename(file_path)
    print(f'Processing file: {filename}')

    # Determine file suffix for output naming
    file_suffix = filename[len('output_'):] if filename.startswith('output_') else filename
    print(f'File suffix: {file_suffix}')

    # Read all sheets from the Excel file
    excel_file = pd.ExcelFile(file_path)
    print('Parsing all data from Excel sheets...', flush=True)

    # --- Load and Clean DataFrames ---
    user_df = excel_file.parse('user')
    user_df = _standardize_id_column(user_df, 'group')
    user_df = _standardize_id_column(user_df, 'id')

    domain_df = excel_file.parse('domain')
    domain_df = _standardize_id_column(domain_df, 'group_id')
    domain_df = _standardize_id_column(domain_df, 'user_id')

    trial_df = excel_file.parse('trial')
    trial_df['group_id'] = trial_df['group'].copy() # Create 'group_id' from 'group'
    trial_df = _standardize_id_column(trial_df, 'group_id')
    trial_df = _standardize_id_column(trial_df, 'user_id')

    round_df = excel_file.parse('round')
    round_df['round'] = round_df['round_num'].copy() # Create 'round' from 'round_num'
    round_df = _standardize_id_column(round_df, 'group_id')
    # Filter and drop duplicates for round data
    round_df = round_df[round_df['status'] == 'demo_tests_generated']
    round_df = round_df.drop_duplicates(subset=['group_id', 'domain', 'kc_id', 'round_num'])

    group_df = excel_file.parse('group')
    group_df['group_id'] = group_df['id'].copy() # Create 'group_id' from 'id'
    group_df = _standardize_id_column(group_df, 'group_id')
    
    # Determine domain order for groups
    group_df['domain_order'] = group_df.apply(
        lambda x: 'at-sb' if x['domain_1'] == 'at' else 'sb-at', axis=1
    )
    group_conditions = group_df[['group_id', 'experimental_condition', 'domain_order']].copy()

    # --- Process Trial Data ---
    print('Processing additional trial data....', flush=True)

    # Merge KC ID from round_df into trial_df
    # Note: 'round' in trial_df should match 'round_num' in round_df for the merge to work as intended.
    # The original code uses 'round' directly, assuming 'round_num' was copied to 'round'.
    trial_df = trial_df.merge(
        round_df[['group_id', 'round', 'domain', 'kc_id']],
        on=['group_id', 'domain', 'round'],
        how='left'
    )
    trial_df['domain_name'] = trial_df['domain'].copy()

    # Add 'reward_ft_weights' from domain_df to trial_df
    # This assumes 'reward_ft_weights' is specific to user, group, and domain.
    trial_df = trial_df.merge(
        domain_df[['user_id', 'group_id', 'domain_name', 'reward_ft_weights']],
        on=['user_id', 'group_id', 'domain_name'],
        how='left'
    )
    # Ensure unique trial entries after merging
    trial_df = trial_df.drop_duplicates(subset=['user_id', 'group_id', 'domain_name', 'round', 'iteration'])

    # Process and add Regret metrics to trial data
    # The original code commented out loading from a file and directly calls add_trial_regret_metrics.
    # This suggests that `add_trial_regret_metrics` is expected to re-calculate if not present.
    # If a large dataset, consider making this idempotent or checking for existence more robustly.
    trial_df_with_metrics = add_trial_regret_metrics(trial_df)

    # Merge selected regret metrics back into the main trial_df
    # Removed commented-out columns for clarity, only keeping the ones used.
    regret_cols = ['opt_reward_gt_mdp', 'human_reward_gt_mdp', 'traj_regret_norm']
    trial_df = trial_df.merge(
        trial_df_with_metrics[['user_id', 'group_id', 'domain', 'round', 'iteration', 'interaction_type'] + regret_cols],
        on=['user_id', 'group_id', 'domain', 'round', 'iteration', 'interaction_type'],
        how='left'
    )
    print(f'Trial DataFrame length after adding metrics: {len(trial_df)}')

    # Apply float extraction to specific columns that might have mixed types
    for col in regret_cols:
        trial_df[col] = trial_df[col].apply(_extract_float_mixed)

    # Save processed trial data
    trial_df.to_excel(os.path.join(RESULTS_DIR, f"trial_df_with_metrics_{file_suffix}"), index=False)

    # --- Process Round Data ---
    print('Processing round data...', flush=True)
    round_df_w_metrics = process_round_data(round_df, trial_df, user_df)
    

    # Merge group conditions into round_df_w_metrics
    round_df_w_metrics = round_df_w_metrics.merge(
        group_conditions,
        on='group_id',
        how='left'
    )
    # Save processed round data
    round_df_w_metrics.to_excel(os.path.join(RESULTS_DIR, f"{OUTPUT_FILENAME_PREFIX}round_{file_suffix}"), index=False)

    # --- Process Domain Data ---
    print('Processing domain metrics....', flush=True)
    domain_df_w_metrics = process_domain_metrics(domain_df, group_df, trial_df)

    print(f"Domain DataFrame with metrics columns: {domain_df_w_metrics.columns.tolist()}")
    print(f"Group conditions columns: {group_conditions.columns.tolist()}")

    # Merge group conditions into domain_df_w_metrics
    domain_df_w_metrics = domain_df_w_metrics.merge(
        group_conditions,
        on='group_id',
        how='left'
    )

    # --- Process Learning Metrics ---
    merged_domain_df = add_learning_metrics(domain_df_w_metrics, round_df_w_metrics)
    merged_domain_df.to_excel(os.path.join(RESULTS_DIR, f"{OUTPUT_FILENAME_PREFIX}domain_{file_suffix}"), index=False)

    # The function currently doesn't return anything, but saves files.
    # If processed dataframes are needed by calling code, they should be returned here.
    # return {
    #     'user_df': user_df,
    #     'domain_df': merged_domain_df, # This is the final domain df with all metrics
    #     'trial_df': trial_df,
    #     'round_df': round_df_w_metrics,
    #     'group_df': group_df
    # }




process_bf_data('../results/output_full_data_07_07.xlsx')


print(f"Processed data saved to {RESULTS_DIR}")
# Clean up dummy file
# os.remove(dummy_file_path)
